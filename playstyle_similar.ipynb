# %%
import pandas as pd
# Out:
# /Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv('data/players_18.csv')

# %%
df.query('sofifa_id == 41')
# Out:
# Empty DataFrame
# ...

# %%
df = pd.read_csv('data/players_20.csv')

# %%
df.query('sofifa_id == 41')
# Out:
# Empty DataFrame
# ...

# %%
df = pd.read_csv('data/players_15.csv')

# %%
df.query('sofifa_id == 41')
# Out:
# Empty DataFrame
# ...

# %%
kagawa = df.query('sofifa_id == 189358')

# %%
kagawa
# Out:
#     sofifa_id                                         player_url short_name  \
# 98     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#    long_name  age         dob  height_cm  weight_kg nationality  \
# 98     香川 真司   25  1989-03-17        172         64       Japan
#
#                  club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 98  Borussia Dortmund  ...  61+1  61+1  61+1  61+1  61+1  52+1  41+1  41+1
#
#      rcb    rb
# 98  41+1  52+1
#
# [1 rows x 104 columns]

# %%
kagawa['overaLL']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'overaLL'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
kagawa['overall']
# Out:
# 98    83
# Name: overall, dtype: int64

# %%
kagawa['vision']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vision'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-97635948dca3> in <module>
# ...

# %%
kagawa
# Out:
#     sofifa_id                                         player_url short_name  \
# 98     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#    long_name  age         dob  height_cm  weight_kg nationality  \
# 98     香川 真司   25  1989-03-17        172         64       Japan
#
#                  club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 98  Borussia Dortmund  ...  61+1  61+1  61+1  61+1  61+1  52+1  41+1  41+1
#
#      rcb    rb
# 98  41+1  52+1
#
# [1 rows x 104 columns]

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
list(df.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
kagawa['passing']
# Out:
# 98    76.0
# Name: passing, dtype: float64

# %%
kagawa['attacking_short_passing']
# Out:
# 98    85
# Name: attacking_short_passing, dtype: object

# %%
kagawa['skill_dribbling']
# Out:
# 98    88
# Name: skill_dribbling, dtype: object

# %%
kagawa['dribbling']
# Out:
# 98    88.0
# Name: dribbling, dtype: float64

# %%
kagawa['movement_balance']
# Out:
# 98    93+2
# Name: movement_balance, dtype: object

# %%
df = pd.read_csv('data/players_18.csv')

# %%
kagawa = df.query('sofifa_id == 41')

# %%
kagawa
# Out:
# Empty DataFrame
# ...

# %%
kagawa['overall']
# Out:
# Series([], Name: overall, dtype: int64)

# %%
kagawa = df.query('sofifa_id == 41')

# %%
df = pd.read_csv('data/players_18.csv')

# %%
kagawa = df.query('sofifa_id == 189358')

# %%
kagawa
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 190  Borussia Dortmund  ...  62+2  60+2  60+2  60+2  62+2  56+2  44+2  44+2
#
#       rcb    rb
# 190  44+2  56+2
#
# [1 rows x 104 columns]

# %%
kagawa['overall']
# Out:
# 190    83
# Name: overall, dtype: int64

# %%
kagawa['kagawa['passing']']
# Out:
#   File "<ipython-input-33-1fe46eba9144>", line 1
#     kagawa['kagawa['passing']']
#                     ^
# SyntaxError: invalid syntax

# %%
kagawa['passing']z
# Out:
#   File "<ipython-input-34-d3816eaf6b7f>", line 1
#     kagawa['passing']z
#                      ^
# SyntaxError: invalid syntax

# %%
kagawa['passing']
# Out:
# 190    76.0
# Name: passing, dtype: float64

# %%
kagawa['skill_dribbling']
# Out:
# 190    87
# Name: skill_dribbling, dtype: object

# %%
kagawa['movement_balance']
# Out:
# 190    88-4
# Name: movement_balance, dtype: object

# %%
kagawa['dribbling']
# Out:
# 190    87.0
# Name: dribbling, dtype: float64

# %%
kagawa['movement_reactions']
# Out:
# 190    81
# Name: movement_reactions, dtype: object

# %%
kagawa['mentality_vision']
# Out:
# 190    82+2
# Name: mentality_vision, dtype: object

# %%
kagawa
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 190  Borussia Dortmund  ...  62+2  60+2  60+2  60+2  62+2  56+2  44+2  44+2
#
#       rcb    rb
# 190  44+2  56+2
#
# [1 rows x 104 columns]

# %%
for k in kagawa:
    print(k)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
for k in kagawa:
    print(k, kagawa[k])
# Out:
# sofifa_id 190    189358
# Name: sofifa_id, dtype: int64
# player_url 190    https://sofifa.com/player/189358/shinji-kagawa...
# Name: player_url, dtype: object
# short_name 190    S. Kagawa
# Name: short_name, dtype: object
# long_name 190    香川 真司
# Name: long_name, dtype: object
# age 190    28
# Name: age, dtype: int64
# dob 190    1989-03-17
# Name: dob, dtype: object
# height_cm 190    175
# Name: height_cm, dtype: int64
# weight_kg 190    68
# Name: weight_kg, dtype: int64
# nationality 190    Japan
# Name: nationality, dtype: object
# club 190    Borussia Dortmund
# Name: club, dtype: object
# overall 190    83
# Name: overall, dtype: int64
# potential 190    83
# Name: potential, dtype: int64
# value_eur 190    26000000
# Name: value_eur, dtype: int64
# wage_eur 190    75000
# Name: wage_eur, dtype: int64
# player_positions 190    CAM, CF
# Name: player_positions, dtype: object
# preferred_foot 190    Right
# Name: preferred_foot, dtype: object
# ...

# %%
df.query('sofifa_id == 168542')
# Out:
#     sofifa_id                                         player_url   short_name  \
# 39     168542  https://sofifa.com/player/168542/david-josue-j...  David Silva
#
#                     long_name  age         dob  height_cm  weight_kg  \
# 39  David Josué Jiménez Silva   31  1986-01-08        173         67
#
#    nationality             club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 39       Spain  Manchester City  ...  65+3  64+3  64+3  64+3  65+3  60+3
#
#      lcb    cb   rcb    rb
# 39  50+3  50+3  50+3  60+3
#
# [1 rows x 104 columns]

# %%
david_silva = df.query('sofifa_id == 168542')

# %%
shiji_kagawa = df.query('sofifa_id == 189358')

# %%
david_silva
# Out:
#     sofifa_id                                         player_url   short_name  \
# 39     168542  https://sofifa.com/player/168542/david-josue-j...  David Silva
#
#                     long_name  age         dob  height_cm  weight_kg  \
# 39  David Josué Jiménez Silva   31  1986-01-08        173         67
#
#    nationality             club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 39       Spain  Manchester City  ...  65+3  64+3  64+3  64+3  65+3  60+3
#
#      lcb    cb   rcb    rb
# 39  50+3  50+3  50+3  60+3
#
# [1 rows x 104 columns]

# %%
shiji_kagawa
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 190  Borussia Dortmund  ...  62+2  60+2  60+2  60+2  62+2  56+2  44+2  44+2
#
#       rcb    rb
# 190  44+2  56+2
#
# [1 rows x 104 columns]

# %%
pd.set_option('display.max_columns', 150)

# %%
david_silva
# Out:
#     sofifa_id                                         player_url   short_name  \
# 39     168542  https://sofifa.com/player/168542/david-josue-j...  David Silva
#
#                     long_name  age         dob  height_cm  weight_kg  \
# 39  David Josué Jiménez Silva   31  1986-01-08        173         67
#
#    nationality             club  overall  potential  value_eur  wage_eur  \
# 39       Spain  Manchester City       87         87   44000000    220000
#
#    player_positions preferred_foot  international_reputation  weak_foot  \
# 39      CAM, CM, LM           Left                         4          2
#
#     skill_moves work_rate body_type real_face  release_clause_eur  \
# 39            4  High/Low    Normal       Yes          81400000.0
#
#                player_tags team_position  team_jersey_number loaned_from  \
# 39  #Playmaker  , #Acrobat           LCM                21.0         NaN
#
#         joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
shiji_kagawa
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
list(df.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
unneeded_columns = [
     'sofifa_id',
     'player_url',
     'short_name',
     'long_name',
     'gk_diving',
     'gk_handling',
     'gk_kicking',
     'gk_reflexes',
     'gk_speed',
     'gk_positioning',
     'goalkeeping_diving',
     'goalkeeping_handling',
     'goalkeeping_kicking',
     'goalkeeping_positioning',
     'goalkeeping_reflexes',
     'ls',
     'st',
     'rs',
     'lw',
     'lf',
     'cf',
     'rf',
     'rw',
     'lam',
     'cam',
     'ram',
     'lm',
     'lcm',
     'cm',
     'rcm',
     'rm',
     'lwb',
     'ldm',
     'cdm',
     'rdm',
     'rwb',
     'lb',
     'lcb',
     'cb',
     'rcb',
     'rb'
]

# %%
# shinji_kagawa.drop(columns='state')

# %%
unneeded_columns
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb']

# %%
shinji_kagawa.drop(columns=unneeded_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-47426bb5071b> in <module>
# ----> 1 shinji_kagawa.drop(columns=unneeded_columns)
#
# NameError: name 'shinji_kagawa' is not defined

# %%
shinji_kagawa = df.query('sofifa_id == 189358')

# %%
shinji_kagawa.drop(columns=unneeded_columns)
# Out:
#      age         dob  height_cm  weight_kg nationality               club  \
# 190   28  1989-03-17        175         68       Japan  Borussia Dortmund
#
#      overall  potential  value_eur  wage_eur player_positions preferred_foot  \
# 190       83         83   26000000     75000          CAM, CF          Right
#
#      international_reputation  weak_foot  skill_moves      work_rate  \
# 190                         3          4            4  Medium/Medium
#
#     body_type real_face  release_clause_eur          player_tags  \
# 190      Lean       Yes          44200000.0  #Dribbler, #Acrobat
#
#     team_position  team_jersey_number loaned_from      joined  \
# 190           SUB                23.0         NaN  2014-08-31
#
#      contract_valid_until nation_position  nation_jersey_number  pace  \
# 190                2020.0             NaN                   NaN  70.0
#
#      shooting  passing  dribbling  defending  physic  \
# ...

# %%
unneeded_columns + ['test']
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'test']

# %%
unneeded_columns.drop('test')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-294accf69f6f> in <module>
# ----> 1 unneeded_columns.drop('test')
#
# AttributeError: 'list' object has no attribute 'drop'

# %%
unneeded_columns.delete('test')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-829db422417d> in <module>
# ----> 1 unneeded_columns.delete('test')
#
# AttributeError: 'list' object has no attribute 'delete'

# %%
unneeded_columns.remove('test')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-6ceb6a069e05> in <module>
# ----> 1 unneeded_columns.remove('test')
#
# ValueError: list.remove(x): x not in list

# %%
unneeded_columns
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb']

# %%
unneeded_columns += ['age']

# %%
unneeded_columns
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'age']

# %%
shinji_kagawa
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
unneeded_columns += ['dob', 'nationality', 'club', 'value_eur', 'wage_eur']

# %%
shinji_kagawa.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-53ff411904b1> in <module>
# ----> 1 shinji_kagawa.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
shinji_kagawa
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
david_silva
# Out:
#     sofifa_id                                         player_url   short_name  \
# 39     168542  https://sofifa.com/player/168542/david-josue-j...  David Silva
#
#                     long_name  age         dob  height_cm  weight_kg  \
# 39  David Josué Jiménez Silva   31  1986-01-08        173         67
#
#    nationality             club  overall  potential  value_eur  wage_eur  \
# 39       Spain  Manchester City       87         87   44000000    220000
#
#    player_positions preferred_foot  international_reputation  weak_foot  \
# 39      CAM, CM, LM           Left                         4          2
#
#     skill_moves work_rate body_type real_face  release_clause_eur  \
# 39            4  High/Low    Normal       Yes          81400000.0
#
#                player_tags team_position  team_jersey_number loaned_from  \
# 39  #Playmaker  , #Acrobat           LCM                21.0         NaN
#
#         joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
shinji_kagawa['attacking_crossing']
# Out:
# 190    60
# Name: attacking_crossing, dtype: object

# %%
shinji_kagawa['attacking_finishing']
# Out:
# 190    76
# Name: attacking_finishing, dtype: object

# %%
attacking_finishing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-cf97a0f4ca78> in <module>
# ----> 1 attacking_finishing
#
# NameError: name 'attacking_finishing' is not defined

# %%
shinji_kagawa
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
shinji_kagawa['shinji_kagawa']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'shinji_kagawa'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
shinji_kagawa['power_shot_power']
# Out:
# 190    56+9
# Name: power_shot_power, dtype: object

# %%
power_shot_power = shinji_kagawa['power_shot_power']

# %%
power_shot_power.split('+')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-eeb529497841> in <module>
# ----> 1 power_shot_power.split('+')
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
str(power_shot_power).split('+')
# Out:
# ['190    56', '9\nName: power_shot_power, dtype: object']

# %%
power_shot_power.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-83ba2a978dd6> in <module>
# ----> 1 power_shot_power.text
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'text'

# %%
test = shinji_kagawa.copy()

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
test['sofifa_id'].replace(189358, 100)
# Out:
# 190    100
# Name: sofifa_id, dtype: int64

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
a = test['sofifa_id'].replace(189358, 100)

# %%
a
# Out:
# 190    100
# Name: sofifa_id, dtype: int64

# %%
a
# Out:
# 190    100
# Name: sofifa_id, dtype: int64

# %%
a
# Out:
# 190    100
# Name: sofifa_id, dtype: int64

# %%
test.sofifa_id.replace(189358, 100)
# Out:
# 190    100
# Name: sofifa_id, dtype: int64

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
test.sofifa_id = test.sofifa_id.replace(189358, 100)

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190        100  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
test.sofifa_id = test['sofifa_id'].replace(100, 200)

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190        200  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
test['sofifa_id'] = test['sofifa_id'].replace(200, 450)

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190        450  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
test['sofifa_id'] = test['sofifa_id'].replace(450, 30000)

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190      30000  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
str(test['sofifa_id'])
# Out:
# '190    30000\nName: sofifa_id, dtype: int64'

# %%
test['sofifa_id']
# Out:
# 190    30000
# Name: sofifa_id, dtype: int64

# %%
test['sofifa_id'].value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-647421696c11> in <module>
# ----> 1 test['sofifa_id'].value
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
test.values
# Out:
# array([[30000,
#         'https://sofifa.com/player/189358/shinji-kagawa/18/158855',
#         'S. Kagawa', '香川 真司', 28, '1989-03-17', 175, 68, 'Japan',
#         'Borussia Dortmund', 83, 83, 26000000, 75000, 'CAM, CF', 'Right',
#         3, 4, 4, 'Medium/Medium', 'Lean', 'Yes', 44200000.0,
#         '#Dribbler, #Acrobat', 'SUB', 23.0, nan, '2014-08-31', 2020.0,
#         nan, nan, 70.0, 68.0, 76.0, 87.0, 34.0, 49.0, nan, nan, nan, nan,
#         nan, nan,
#         'Flair, Technical Dribbler (CPU AI Only), Backs Into Player',
#         '60', '76', '42-2', '84', '75', '87', '74', '63', '73', '85+1',
#         '76-7', '65-1', '92', '81', '88-4', '56+9', '66', '80', '39',
#         '55', '30', '56', '80', '82+2', '78', '81', '30', '24', '27',
#         '11', '9', '8', '9', '13', '71+2', '71+2', '71+2', '79+2',
#         '78+2', '78+2', '78+2', '79+2', '81+2', '81+2', '81+2', '79+2',
#         '77+2', '77+2', '77+2', '79+2', '62+2', '60+2', '60+2', '60+2',
# ...

# %%
test['sofifa_id'].values
# Out:
# array([30000])

# %%
str(test['sofifa_id'].value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-e37dd5465e75> in <module>
# ----> 1 str(test['sofifa_id'].value)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
test['sofifa_id'].values
# Out:
# array([30000])

# %%
test['sofifa_id'].columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-cbe9ccc906bb> in <module>
# ----> 1 test['sofifa_id'].columns
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
test['sofifa_id'].
# Out:
#   File "<ipython-input-108-4789f2842a27>", line 1
#     test['sofifa_id'].
#                       ^
# SyntaxError: invalid syntax

# %%
test['sofifa_id']
# Out:
# 190    30000
# Name: sofifa_id, dtype: int64

# %%
df.loc('189358')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-eeb4d91550f0> in <module>
# ----> 1 df.loc('189358')
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     576
#     577         if axis is not None:
# --> 578             axis = self.obj._get_axis_number(axis)
#     579         new_self.axis = axis
#     580         return new_self
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named 189358 for object type <class 'pandas.core.frame.DataFrame'>

# %%
df.loc('sofifa_id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-5af4709bccf0> in <module>
# ----> 1 df.loc('sofifa_id')
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     576
#     577         if axis is not None:
# --> 578             axis = self.obj._get_axis_number(axis)
#     579         new_self.axis = axis
#     580         return new_self
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named sofifa_id for object type <class 'pandas.core.frame.DataFrame'>

# %%
df.loc['sofifa_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'sofifa_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-59e310e5fc03> in <module>
# ----> 1 df.loc['sofifa_id']
#
# ...

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 17587     237463  https://sofifa.com/player/237463/adam-kelsey/1...
# 17588     231381  https://sofifa.com/player/231381/jordan-young/...
# 17589     240404  https://sofifa.com/player/240404/jack-keeble/1...
# 17590      11728  https://sofifa.com/player/11728/barry-richards...
# 17591     235352  https://sofifa.com/player/235352/tommy-kassemo...
#
#               short_name                            long_name  age  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32
# ...

# %%
shinji_kagawa
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
unneeded_columns
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'age',
#  'dob',
#  'nationality',
#  'club',
#  'value_eur',
#  'wage_eur']

# %%
shinji_kagawa.drop(columns=unneeded_columns)
# Out:
#      height_cm  weight_kg  overall  potential player_positions preferred_foot  \
# 190        175         68       83         83          CAM, CF          Right
#
#      international_reputation  weak_foot  skill_moves      work_rate  \
# 190                         3          4            4  Medium/Medium
#
#     body_type real_face  release_clause_eur          player_tags  \
# 190      Lean       Yes          44200000.0  #Dribbler, #Acrobat
#
#     team_position  team_jersey_number loaned_from      joined  \
# 190           SUB                23.0         NaN  2014-08-31
#
#      contract_valid_until nation_position  nation_jersey_number  pace  \
# 190                2020.0             NaN                   NaN  70.0
#
#      shooting  passing  dribbling  defending  physic  \
# 190      68.0     76.0       87.0       34.0    49.0
#
#                                          player_traits attacking_crossing  \
# ...

# %%
test['preferred_foot'] = test['preferred_foot'].replace('Left', 1)

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190      30000  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
for colum in unneeded_columns:
        print(colum)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb
# age
# dob
# nationality
# club
# value_eur
# wage_eur

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190      30000  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
test.drop(columns=unneeded_columns)
# Out:
#      height_cm  weight_kg  overall  potential player_positions preferred_foot  \
# 190        175         68       83         83          CAM, CF          Right
#
#      international_reputation  weak_foot  skill_moves      work_rate  \
# 190                         3          4            4  Medium/Medium
#
#     body_type real_face  release_clause_eur          player_tags  \
# 190      Lean       Yes          44200000.0  #Dribbler, #Acrobat
#
#     team_position  team_jersey_number loaned_from      joined  \
# 190           SUB                23.0         NaN  2014-08-31
#
#      contract_valid_until nation_position  nation_jersey_number  pace  \
# 190                2020.0             NaN                   NaN  70.0
#
#      shooting  passing  dribbling  defending  physic  \
# 190      68.0     76.0       87.0       34.0    49.0
#
#                                          player_traits attacking_crossing  \
# ...

# %%
test = test.drop(columns=unneeded_columns)

# %%
test
# Out:
#      height_cm  weight_kg  overall  potential player_positions preferred_foot  \
# 190        175         68       83         83          CAM, CF          Right
#
#      international_reputation  weak_foot  skill_moves      work_rate  \
# 190                         3          4            4  Medium/Medium
#
#     body_type real_face  release_clause_eur          player_tags  \
# 190      Lean       Yes          44200000.0  #Dribbler, #Acrobat
#
#     team_position  team_jersey_number loaned_from      joined  \
# 190           SUB                23.0         NaN  2014-08-31
#
#      contract_valid_until nation_position  nation_jersey_number  pace  \
# 190                2020.0             NaN                   NaN  70.0
#
#      shooting  passing  dribbling  defending  physic  \
# 190      68.0     76.0       87.0       34.0    49.0
#
#                                          player_traits attacking_crossing  \
# ...

# %%
test.drop(columns=['player_positions', 'international_reputation', 'body_type', 'real_face', ''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-eceaf8d7e809> in <module>
# ----> 1 test.drop(columns=['player_positions', 'international_reputation', 'body_type', 'real_face', ''])
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
test
# Out:
#      height_cm  weight_kg  overall  potential player_positions preferred_foot  \
# 190        175         68       83         83          CAM, CF          Right
#
#      international_reputation  weak_foot  skill_moves      work_rate  \
# 190                         3          4            4  Medium/Medium
#
#     body_type real_face  release_clause_eur          player_tags  \
# 190      Lean       Yes          44200000.0  #Dribbler, #Acrobat
#
#     team_position  team_jersey_number loaned_from      joined  \
# 190           SUB                23.0         NaN  2014-08-31
#
#      contract_valid_until nation_position  nation_jersey_number  pace  \
# 190                2020.0             NaN                   NaN  70.0
#
#      shooting  passing  dribbling  defending  physic  \
# 190      68.0     76.0       87.0       34.0    49.0
#
#                                          player_traits attacking_crossing  \
# ...

# %%
columns = ['player_positions', 'international_reputation', 'body_type', 'real_face', 'team_position', 'team_jersey_number', 'loaned_from', 'joined']

# %%
test = test.drop(columns=columns)

# %%
test
# Out:
#      height_cm  weight_kg  overall  potential preferred_foot  weak_foot  \
# 190        175         68       83         83          Right          4
#
#      skill_moves      work_rate  release_clause_eur          player_tags  \
# 190            4  Medium/Medium          44200000.0  #Dribbler, #Acrobat
#
#      contract_valid_until nation_position  nation_jersey_number  pace  \
# 190                2020.0             NaN                   NaN  70.0
#
#      shooting  passing  dribbling  defending  physic  \
# 190      68.0     76.0       87.0       34.0    49.0
#
#                                          player_traits attacking_crossing  \
# 190  Flair, Technical Dribbler (CPU AI Only), Backs...                 60
#
#     attacking_finishing attacking_heading_accuracy attacking_short_passing  \
# 190                  76                       42-2                      84
#
#     attacking_volleys skill_dribbling skill_curve skill_fk_accuracy  \
# ...

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
list(df.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
shinji_kagawa
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
test
# Out:
#      height_cm  weight_kg  overall  potential preferred_foot  weak_foot  \
# 190        175         68       83         83          Right          4
#
#      skill_moves      work_rate  release_clause_eur          player_tags  \
# 190            4  Medium/Medium          44200000.0  #Dribbler, #Acrobat
#
#      contract_valid_until nation_position  nation_jersey_number  pace  \
# 190                2020.0             NaN                   NaN  70.0
#
#      shooting  passing  dribbling  defending  physic  \
# 190      68.0     76.0       87.0       34.0    49.0
#
#                                          player_traits attacking_crossing  \
# 190  Flair, Technical Dribbler (CPU AI Only), Backs...                 60
#
#     attacking_finishing attacking_heading_accuracy attacking_short_passing  \
# 190                  76                       42-2                      84
#
#     attacking_volleys skill_dribbling skill_curve skill_fk_accuracy  \
# ...

# %%
test = shinji_kagawa.copy()

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
columns = []

# %%
height_cm
weight_kg
preferred_foot
weak_foot
skill_moves
work_rate
player_tags

pace
shooting
passing
dribbling
defending
physic
player_traits

attacking_crossing
attacking_finishing
attacking_heading_accuracy
attacking_short_passing
attacking_volleys

skill_dribbling
skill_curve
skill_fk_accuracy
skill_long_passing
skill_ball_control

movement_acceleration
movement_sprint_speed
movement_agility
movement_reactions
movement_balance

power_shot_power
power_jumping
power_stamina
power_strength
power_long_shots

mentality_aggression
mentality_interceptions
mentality_positioning
mentality_vision
mentality_penalties
mentality_composure

defending_marking
defending_standing_tackle
defending_sliding_tackle
]
# Out:
#   File "<ipython-input-136-560961f24095>", line 51
#     ]
#     ^
# SyntaxError: unmatched ']'

# %%
height_cm
weight_kg
preferred_foot
weak_foot
skill_moves
work_rate
player_tags

pace
shooting
passing
dribbling
defending
physic
player_traits

attacking_crossing
attacking_finishing
attacking_heading_accuracy
attacking_short_passing
attacking_volleys

skill_dribbling
skill_curve
skill_fk_accuracy
skill_long_passing
skill_ball_control

movement_acceleration
movement_sprint_speed
movement_agility
movement_reactions
movement_balance

power_shot_power
power_jumping
power_stamina
power_strength
power_long_shots

mentality_aggression
mentality_interceptions
mentality_positioning
mentality_vision
mentality_penalties
mentality_composure

defending_marking
defending_standing_tackle
defending_sliding_tackle
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-947c5f7d628a> in <module>
# ----> 1 height_cm
#       2 weight_kg
#       3 preferred_foot
#       4 weak_foot
#       5 skill_moves
#
# NameError: name 'height_cm' is not defined

# %%
columns = [
    'height_cm',
    'weight_kg',
    'preferred_foot',
    'weak_foot',
    'skill_moves',
    'work_rate',
    'player_tags'
]

# %%
columns += [
    'pace',
    'shooting',
    'passing',
    'dribbling',
    'defending',
    'physic',
    'player_traits'
]

# %%
columns
# Out:
# ['height_cm',
#  'weight_kg',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'player_tags',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'player_traits']

# %%
## attacking_crossing
attacking_finishing
attacking_heading_accuracy
attacking_short_passing
attacking_volleys

skill_dribbling
skill_curve
skill_fk_accuracy
skill_long_passing
skill_ball_control

movement_acceleration
movement_sprint_speed
movement_agility
movement_reactions
movement_balance

power_shot_power
power_jumping
power_stamina
power_strength
power_long_shots

mentality_aggression
mentality_interceptions
mentality_positioning
mentality_vision
mentality_penalties
mentality_composure

defending_marking
defending_standing_tackle
defending_sliding_tackle
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-eaa929fe9559> in <module>
#       1 ## attacking_crossing
# ----> 2 attacking_finishing
#       3 attacking_heading_accuracy
#       4 attacking_short_passing
#       5 attacking_volleys
#
# NameError: name 'attacking_finishing' is not defined

# %%
attacking_crossing
attacking_finishing
attacking_heading_accuracy
attacking_short_passing
attacking_volleys

skill_dribbling
skill_curve
skill_fk_accuracy
skill_long_passing
skill_ball_control

movement_acceleration
movement_sprint_speed
movement_agility
movement_reactions
movement_balance

power_shot_power
power_jumping
power_stamina
power_strength
power_long_shots

mentality_aggression
mentality_interceptions
mentality_positioning
mentality_vision
mentality_penalties
mentality_composure

defending_marking
defending_standing_tackle
defending_sliding_tackle
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-921a593687b6> in <module>
# ----> 1 attacking_crossing
#       2 attacking_finishing
#       3 attacking_heading_accuracy
#       4 attacking_short_passing
#       5 attacking_volleys
#
# NameError: name 'attacking_crossing' is not defined

# %%
columns += [
    'attacking_crossing',
    'attacking_finishing',
    'attacking_heading_accuracy',
    'attacking_short_passing',
    'attacking_volleys'
]

# %%
columns
# Out:
# ['height_cm',
#  'weight_kg',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'player_tags',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys']

# %%
columns += [
'skill_dribbling',
'skill_curve',
'skill_fk_accuracy',
'skill_long_passing',
'skill_ball_control',
]

# %%
columns
# Out:
# ['height_cm',
#  'weight_kg',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'player_tags',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control']

# %%
movement_acceleration
movement_sprint_speed
movement_agility
movement_reactions
movement_balance

power_shot_power
power_jumping
power_stamina
power_strength
power_long_shots

mentality_aggression
mentality_interceptions
mentality_positioning
mentality_vision
mentality_penalties
mentality_composure

defending_marking
defending_standing_tackle
defending_sliding_tackle
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-bf6e4956ab0f> in <module>
# ----> 1 movement_acceleration
#       2 movement_sprint_speed
#       3 movement_agility
#       4 movement_reactions
#       5 movement_balance
#
# NameError: name 'movement_acceleration' is not defined

# %%
columns += [
    'movement_acceleration',
    'movement_sprint_speed',
    'movement_agility',
    'movement_reactions',
    'movement_balance'
]

# %%
columns
# Out:
# ['height_cm',
#  'weight_kg',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'player_tags',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance']

# %%
power_shot_power
power_jumping
power_stamina
power_strength
power_long_shots

mentality_aggression
mentality_interceptions
mentality_positioning
mentality_vision
mentality_penalties
mentality_composure

defending_marking
defending_standing_tackle
defending_sliding_tackle
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-f42b8b6b12ee> in <module>
#       1 power_shot_power
# ----> 2 power_jumping
#       3 power_stamina
#       4 power_strength
#       5 power_long_shots
#
# NameError: name 'power_jumping' is not defined

# %%
columns += [
'power_shot_power',
'power_jumping',
'power_stamina',
'power_strength',
'power_long_shots'
]

# %%
columns
# Out:
# ['height_cm',
#  'weight_kg',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'player_tags',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots']

# %%
columns
# Out:
# ['height_cm',
#  'weight_kg',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'player_tags',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots']

# %%
columns += [
'mentality_aggression',
'mentality_interceptions',
'mentality_positioning',
'mentality_vision',
'mentality_penalties',
'mentality_composure',

'defending_marking',
'defending_standing_tackle',
'defending_sliding_tackle'
]

# %%
columns
# Out:
# ['height_cm',
#  'weight_kg',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'player_tags',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle']

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
test[columns]
# Out:
#      height_cm  weight_kg preferred_foot  weak_foot  skill_moves  \
# 190        175         68          Right          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic                                      player_traits  \
# 190       34.0    49.0  Flair, Technical Dribbler (CPU AI Only), Backs...
#
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# ...

# %%
test
# Out:
#      sofifa_id                                         player_url short_name  \
# 190     189358  https://sofifa.com/player/189358/shinji-kagawa...  S. Kagawa
#
#     long_name  age         dob  height_cm  weight_kg nationality  \
# 190     香川 真司   28  1989-03-17        175         68       Japan
#
#                   club  overall  potential  value_eur  wage_eur  \
# 190  Borussia Dortmund       83         83   26000000     75000
#
#     player_positions preferred_foot  international_reputation  weak_foot  \
# 190          CAM, CF          Right                         3          4
#
#      skill_moves      work_rate body_type real_face  release_clause_eur  \
# 190            4  Medium/Medium      Lean       Yes          44200000.0
#
#              player_tags team_position  team_jersey_number loaned_from  \
# 190  #Dribbler, #Acrobat           SUB                23.0         NaN
#
#          joined  contract_valid_until nation_position  nation_jersey_number  \
# ...

# %%
test = test[columns]

# %%
test
# Out:
#      height_cm  weight_kg preferred_foot  weak_foot  skill_moves  \
# 190        175         68          Right          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic                                      player_traits  \
# 190       34.0    49.0  Flair, Technical Dribbler (CPU AI Only), Backs...
#
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# ...

# %%
test['weak_foot']
# Out:
# 190    4
# Name: weak_foot, dtype: int64

# %%
weak_foot = test['weak_foot']

# %%
weak_foot
# Out:
# 190    4
# Name: weak_foot, dtype: int64

# %%
weak_foot.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-e107472ca1fb> in <module>
# ----> 1 weak_foot.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
weak_foot.values
# Out:
# array([4])

# %%
weak_foot.values[0]
# Out:
# 4

# %%
weak_foot = int(weak_foot.values[0])

# %%
weak_foot
# Out:
# 4

# %%
weak_foot
# Out:
# 4

# %%
weak_foot
# Out:
# 4

# %%
preferred_foot = test['preferred_foot'].values[0]

# %%
preferred_foot
# Out:
# 'Right'

# %%
test['preferred_foot'] = test['preferred_foot'].replace('R', 1)
# Out:
# <ipython-input-173-892bda324a79>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['preferred_foot'] = test['preferred_foot'].replace('R', 1)

# %%
test
# Out:
#      height_cm  weight_kg preferred_foot  weak_foot  skill_moves  \
# 190        175         68          Right          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic                                      player_traits  \
# 190       34.0    49.0  Flair, Technical Dribbler (CPU AI Only), Backs...
#
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# ...

# %%
test['preferred_foot'] = test['preferred_foot'].replace('Right', 1)
# Out:
# <ipython-input-175-39a65a837c65>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['preferred_foot'] = test['preferred_foot'].replace('Right', 1)

# %%
test['preferred_foot'].replace('Right', 1)
# Out:
# 190    1
# Name: preferred_foot, dtype: int64

# %%
test
# Out:
#      height_cm  weight_kg  preferred_foot  weak_foot  skill_moves  \
# 190        175         68               1          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic                                      player_traits  \
# 190       34.0    49.0  Flair, Technical Dribbler (CPU AI Only), Backs...
#
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# ...

# %%
test['preferred_foot'].replace('Left', 2)
# Out:
# 190    1
# Name: preferred_foot, dtype: int64

# %%
test
# Out:
#      height_cm  weight_kg  preferred_foot  weak_foot  skill_moves  \
# 190        175         68               1          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic                                      player_traits  \
# 190       34.0    49.0  Flair, Technical Dribbler (CPU AI Only), Backs...
#
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# ...

# %%
num_values = [
    'pace',
    'shooting',
    'passing',
    'dribbling',
    'defending',
    'physic'
]

# %%
test[[]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [190]

# %%
test[[
 'attacking_crossing',
 'attacking_finishing',
 'attacking_heading_accuracy',
 'attacking_short_passing',
 'attacking_volleys',
 'skill_dribbling',
 'skill_curve',
 'skill_fk_accuracy',
 'skill_long_passing',
 'skill_ball_control',
 'movement_acceleration',
 'movement_sprint_speed',
 'movement_agility',
 'movement_reactions',
 'movement_balance',
 'power_shot_power',
 'power_jumping',
 'power_stamina',
 'power_strength',
 'power_long_shots',
 'mentality_aggression',
 'mentality_interceptions',
 'mentality_positioning',
 'mentality_vision',
 'mentality_penalties',
 'mentality_composure',
 'defending_marking',
 'defending_standing_tackle',
 'defending_sliding_tackle'
]]
# Out:
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# 190                  76-7                  65-1               92
#
#     movement_reactions movement_balance power_shot_power power_jumping  \
# 190                 81             88-4             56+9            66
#
#     power_stamina power_strength power_long_shots mentality_aggression  \
# 190            80             39               55                   30
#
#     mentality_interceptions mentality_positioning mentality_vision  \
# ...

# %%
num_values += [
 'attacking_crossing',
 'attacking_finishing',
 'attacking_heading_accuracy',
 'attacking_short_passing',
 'attacking_volleys',
 'skill_dribbling',
 'skill_curve',
 'skill_fk_accuracy',
 'skill_long_passing',
 'skill_ball_control',
 'movement_acceleration',
 'movement_sprint_speed',
 'movement_agility',
 'movement_reactions',
 'movement_balance',
 'power_shot_power',
 'power_jumping',
 'power_stamina',
 'power_strength',
 'power_long_shots',
 'mentality_aggression',
 'mentality_interceptions',
 'mentality_positioning',
 'mentality_vision',
 'mentality_penalties',
 'mentality_composure',
 'defending_marking',
 'defending_standing_tackle',
 'defending_sliding_tackle'
]

# %%
num_values
# Out:
# ['pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle']

# %%
for v in num_values:
        print(v)
# Out:
# pace
# shooting
# passing
# dribbling
# defending
# physic
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle

# %%
for v in num_values:
        print(test[v])
# Out:
# 190    70.0
# Name: pace, dtype: float64
# 190    68.0
# Name: shooting, dtype: float64
# 190    76.0
# Name: passing, dtype: float64
# 190    87.0
# Name: dribbling, dtype: float64
# 190    34.0
# Name: defending, dtype: float64
# 190    49.0
# Name: physic, dtype: float64
# 190    60
# Name: attacking_crossing, dtype: object
# 190    76
# Name: attacking_finishing, dtype: object
# 190    42-2
# Name: attacking_heading_accuracy, dtype: object
# 190    84
# Name: attacking_short_passing, dtype: object
# 190    75
# Name: attacking_volleys, dtype: object
# 190    87
# Name: skill_dribbling, dtype: object
# 190    74
# Name: skill_curve, dtype: object
# 190    63
# Name: skill_fk_accuracy, dtype: object
# 190    73
# Name: skill_long_passing, dtype: object
# 190    85+1
# Name: skill_ball_control, dtype: object
# 190    76-7
# Name: movement_acceleration, dtype: object
# 190    65-1
# Name: movement_sprint_speed, dtype: object
# 190    92
# Name: movement_agility, dtype: object
# ...

# %%
for v in num_values:
        print(test[v].values[0])
# Out:
# 70.0
# 68.0
# 76.0
# 87.0
# 34.0
# 49.0
# 60
# 76
# 42-2
# 84
# 75
# 87
# 74
# 63
# 73
# 85+1
# 76-7
# 65-1
# 92
# 81
# 88-4
# 56+9
# 66
# 80
# 39
# 55
# 30
# 56
# 80
# 82+2
# 78
# 81
# 30
# 24
# 27

# %%
for v in num_values:
        value = test[v].values[0]

# %%
for v in num_values:
        value = value.split('+')[0] if '+' in value else float(value)
        value = value.split('-')[0] if '-' in value else float(value)

        print(value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-7ed63f0dd4d5> in <module>
#       1 for v in num_values:
#       2         value = value.split('+')[0] if '+' in value else float(value)
# ----> 3         value = value.split('-')[0] if '-' in value else float(value)
#       4
#       5         print(value)
#
# TypeError: argument of type 'float' is not iterable

# %%
for v in num_values:
        value = value.split('+')[0] if '+' in value else int(value)
        value = value.split('-')[0] if '-' in value else int(value)

        print(value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-76ab911b169e> in <module>
#       1 for v in num_values:
# ----> 2         value = value.split('+')[0] if '+' in value else int(value)
#       3         value = value.split('-')[0] if '-' in value else int(value)
#       4
#       5         print(value)
#
# TypeError: argument of type 'float' is not iterable

# %%
for v in num_values:
        value = test[v].values[0]

        value = value.split('+')[0] if '+' in value else value
        value = value.split('-')[0] if '-' in value else value

        print(value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-191-733d3d030878> in <module>
#       2         value = test[v].values[0]
#       3
# ----> 4         value = value.split('+')[0] if '+' in value else value
#       5         value = value.split('-')[0] if '-' in value else value
#       6
#
# TypeError: argument of type 'numpy.float64' is not iterable

# %%
for v in num_values:
        value = test[v].values[0]
        print(value)
#         value = value.split('+')[0] if '+' in value else value
#         value = value.split('-')[0] if '-' in value else value

#         print(value)
# Out:
# 70.0
# 68.0
# 76.0
# 87.0
# 34.0
# 49.0
# 60
# 76
# 42-2
# 84
# 75
# 87
# 74
# 63
# 73
# 85+1
# 76-7
# 65-1
# 92
# 81
# 88-4
# 56+9
# 66
# 80
# 39
# 55
# 30
# 56
# 80
# 82+2
# 78
# 81
# 30
# 24
# 27

# %%
for v in num_values:
        value = test[v].values[0]
        # print(value)

        # value = str(value).split('+')[0] if '+' in value else value
        # value = str(value).split('-')[0] if '-' in value else value

        print(value, type(value))
# Out:
# 70.0 <class 'numpy.float64'>
# 68.0 <class 'numpy.float64'>
# 76.0 <class 'numpy.float64'>
# 87.0 <class 'numpy.float64'>
# 34.0 <class 'numpy.float64'>
# 49.0 <class 'numpy.float64'>
# 60 <class 'str'>
# 76 <class 'str'>
# 42-2 <class 'str'>
# 84 <class 'str'>
# 75 <class 'str'>
# 87 <class 'str'>
# 74 <class 'str'>
# 63 <class 'str'>
# 73 <class 'str'>
# 85+1 <class 'str'>
# 76-7 <class 'str'>
# 65-1 <class 'str'>
# 92 <class 'str'>
# 81 <class 'str'>
# 88-4 <class 'str'>
# 56+9 <class 'str'>
# 66 <class 'str'>
# 80 <class 'str'>
# 39 <class 'str'>
# 55 <class 'str'>
# 30 <class 'str'>
# 56 <class 'str'>
# 80 <class 'str'>
# 82+2 <class 'str'>
# 78 <class 'str'>
# 81 <class 'str'>
# 30 <class 'str'>
# 24 <class 'str'>
# 27 <class 'str'>

# %%
for v in num_values:
        value = test[v].values[0]
        # print(value)

        # value = str(value).split('+')[0] if '+' in value else value
        # value = str(value).split('-')[0] if '-' in value else value

        # print(value, type(value))
        print(test[v].values.astype(str))
# Out:
# ['70.0']
# ['68.0']
# ['76.0']
# ['87.0']
# ['34.0']
# ['49.0']
# ['60']
# ['76']
# ['42-2']
# ['84']
# ['75']
# ['87']
# ['74']
# ['63']
# ['73']
# ['85+1']
# ['76-7']
# ['65-1']
# ['92']
# ['81']
# ['88-4']
# ['56+9']
# ['66']
# ['80']
# ['39']
# ['55']
# ['30']
# ['56']
# ['80']
# ['82+2']
# ['78']
# ['81']
# ['30']
# ['24']
# ['27']

# %%
for v in num_values:
        value = test[v].values.astype(str)
        # print(value)

        # value = str(value).split('+')[0] if '+' in value else value
        # value = str(value).split('-')[0] if '-' in value else value

        # print(value, type(value))
        print(value)
# Out:
# ['70.0']
# ['68.0']
# ['76.0']
# ['87.0']
# ['34.0']
# ['49.0']
# ['60']
# ['76']
# ['42-2']
# ['84']
# ['75']
# ['87']
# ['74']
# ['63']
# ['73']
# ['85+1']
# ['76-7']
# ['65-1']
# ['92']
# ['81']
# ['88-4']
# ['56+9']
# ['66']
# ['80']
# ['39']
# ['55']
# ['30']
# ['56']
# ['80']
# ['82+2']
# ['78']
# ['81']
# ['30']
# ['24']
# ['27']

# %%
for v in num_values:
        value = test[v].values.astype(str)[0]

        value = str(value).split('+')[0] if '+' in value else value
        value = str(value).split('-')[0] if '-' in value else value

        print(float(value))
# Out:
# 70.0
# 68.0
# 76.0
# 87.0
# 34.0
# 49.0
# 60.0
# 76.0
# 42.0
# 84.0
# 75.0
# 87.0
# 74.0
# 63.0
# 73.0
# 85.0
# 76.0
# 65.0
# 92.0
# 81.0
# 88.0
# 56.0
# 66.0
# 80.0
# 39.0
# 55.0
# 30.0
# 56.0
# 80.0
# 82.0
# 78.0
# 81.0
# 30.0
# 24.0
# 27.0

# %%
test
# Out:
#      height_cm  weight_kg  preferred_foot  weak_foot  skill_moves  \
# 190        175         68               1          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic                                      player_traits  \
# 190       34.0    49.0  Flair, Technical Dribbler (CPU AI Only), Backs...
#
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# ...

# %%
player_traits = test['player_traits']

# %%
player_traits
# Out:
# 190    Flair, Technical Dribbler (CPU AI Only), Backs...
# Name: player_traits, dtype: object

# %%
player_traits.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-6e1d00963740> in <module>
# ----> 1 player_traits.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
player_traits.values
# Out:
# array(['Flair, Technical Dribbler (CPU AI Only), Backs Into Player'],
#       dtype=object)

# %%
list(player_traits.values)
# Out:
# ['Flair, Technical Dribbler (CPU AI Only), Backs Into Player']

# %%
traits_list = [
'Bicycle Kicks',
'Chip Shot',
'Dives Into Tackles',
'Early Crosser',
'Fancy Passes',
'Finesse Shot',
'Flair',
'Giant Throw-In',
'GK Cautious With Crosses',
'GK Comes For Crosses',
'GK Flat Kick'
]

# %%
trais_list
# Out:
# ['Bicycle Kicks',
#  'Chip Shot',
#  'Dives Into Tackles',
#  'Early Crosser',
#  'Fancy Passes',
#  'Finesse Shot',
#  'Flair',
#  'Giant Throw-In',
#  'GK Cautious With Crosses',
#  'GK Comes For Crosses',
#  'GK Flat Kick']

# %%
traits_list += [
'GK Long Thrower',
'GK Save With Foot',
'Injury Prone',
'Leadership',
'Long Passer',
'Long Shot Taker',
'Long Throw-In',
'One Club Player',
'Outside Foot Shot',
'Play Maker'
]

# %%
trais_list
# Out:
# ['Bicycle Kicks',
#  'Chip Shot',
#  'Dives Into Tackles',
#  'Early Crosser',
#  'Fancy Passes',
#  'Finesse Shot',
#  'Flair',
#  'Giant Throw-In',
#  'GK Cautious With Crosses',
#  'GK Comes For Crosses',
#  'GK Flat Kick',
#  'GK Long Thrower',
#  'GK Save With Foot',
#  'Injury Prone',
#  'Leadership',
#  'Long Passer',
#  'Long Shot Taker',
#  'Long Throw-In',
#  'One Club Player',
#  'Outside Foot Shot',
#  'Play Maker']

# %%
traits_list += [
'Power Header',
'Rushes Out Of Goal',
'Second Wind',
'Set Play Specialist',
'Solid Player',
'Speed Dribbler',
'Swerve',
'Takes Powerful Driven Free Kicks',
'Team Player',
'Technical Dribbler'
]

# %%
trais_list
# Out:
# ['Bicycle Kicks',
#  'Chip Shot',
#  'Dives Into Tackles',
#  'Early Crosser',
#  'Fancy Passes',
#  'Finesse Shot',
#  'Flair',
#  'Giant Throw-In',
#  'GK Cautious With Crosses',
#  'GK Comes For Crosses',
#  'GK Flat Kick',
#  'GK Long Thrower',
#  'GK Save With Foot',
#  'Injury Prone',
#  'Leadership',
#  'Long Passer',
#  'Long Shot Taker',
#  'Long Throw-In',
#  'One Club Player',
#  'Outside Foot Shot',
#  'Play Maker',
#  'Power Header',
#  'Rushes Out Of Goal',
#  'Second Wind',
#  'Set Play Specialist',
#  'Solid Player',
#  'Speed Dribbler',
#  'Swerve',
#  'Takes Powerful Driven Free Kicks',
#  'Team Player',
#  'Technical Dribbler']

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 17587     237463  https://sofifa.com/player/237463/adam-kelsey/1...
# 17588     231381  https://sofifa.com/player/231381/jordan-young/...
# 17589     240404  https://sofifa.com/player/240404/jack-keeble/1...
# 17590      11728  https://sofifa.com/player/11728/barry-richards...
# 17591     235352  https://sofifa.com/player/235352/tommy-kassemo...
#
#               short_name                            long_name  age  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32
# ...

# %%
test
# Out:
#      height_cm  weight_kg  preferred_foot  weak_foot  skill_moves  \
# 190        175         68               1          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic                                      player_traits  \
# 190       34.0    49.0  Flair, Technical Dribbler (CPU AI Only), Backs...
#
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# ...

# %%
player_traits
# Out:
# 190    Flair, Technical Dribbler (CPU AI Only), Backs...
# Name: player_traits, dtype: object

# %%
list(player_traits)
# Out:
# ['Flair, Technical Dribbler (CPU AI Only), Backs Into Player']

# %%
'Technical Dribbler' in list(player_traits)
# Out:
# False

# %%
for trait in traits_list:
    for p_trait in player_traits.values[0].split(','):
            print(p_trait, '--', trait)
    print('---' * 20)
# Out:
# Flair -- Bicycle Kicks
#  Technical Dribbler (CPU AI Only) -- Bicycle Kicks
#  Backs Into Player -- Bicycle Kicks
# ------------------------------------------------------------
# Flair -- Chip Shot
#  Technical Dribbler (CPU AI Only) -- Chip Shot
#  Backs Into Player -- Chip Shot
# ------------------------------------------------------------
# Flair -- Dives Into Tackles
#  Technical Dribbler (CPU AI Only) -- Dives Into Tackles
#  Backs Into Player -- Dives Into Tackles
# ------------------------------------------------------------
# Flair -- Early Crosser
#  Technical Dribbler (CPU AI Only) -- Early Crosser
#  Backs Into Player -- Early Crosser
# ------------------------------------------------------------
# Flair -- Fancy Passes
#  Technical Dribbler (CPU AI Only) -- Fancy Passes
#  Backs Into Player -- Fancy Passes
# ------------------------------------------------------------
# Flair -- Finesse Shot
#  Technical Dribbler (CPU AI Only) -- Finesse Shot
# ...

# %%
for p_trait in list(player_traits):
        print(p_trait)
# Out:
# Flair, Technical Dribbler (CPU AI Only), Backs Into Player

# %%
list(player_traits)
# Out:
# ['Flair, Technical Dribbler (CPU AI Only), Backs Into Player']

# %%
str(player_traits)
# Out:
# '190    Flair, Technical Dribbler (CPU AI Only), Backs...\nName: player_traits, dtype: object'

# %%
player_traits.values
# Out:
# array(['Flair, Technical Dribbler (CPU AI Only), Backs Into Player'],
#       dtype=object)

# %%
list(player_traits.values)
# Out:
# ['Flair, Technical Dribbler (CPU AI Only), Backs Into Player']

# %%
player_traits.values[0]
# Out:
# 'Flair, Technical Dribbler (CPU AI Only), Backs Into Player'

# %%
player_traits.values[0].split(',')
# Out:
# ['Flair', ' Technical Dribbler (CPU AI Only)', ' Backs Into Player']

# %%
for trait in traits_list:
    for p_trait in player_traits.values[0].split(','):
            print(p_trait, '--', trait)
    print('---' * 20)
# Out:
# Flair -- Bicycle Kicks
#  Technical Dribbler (CPU AI Only) -- Bicycle Kicks
#  Backs Into Player -- Bicycle Kicks
# ------------------------------------------------------------
# Flair -- Chip Shot
#  Technical Dribbler (CPU AI Only) -- Chip Shot
#  Backs Into Player -- Chip Shot
# ------------------------------------------------------------
# Flair -- Dives Into Tackles
#  Technical Dribbler (CPU AI Only) -- Dives Into Tackles
#  Backs Into Player -- Dives Into Tackles
# ------------------------------------------------------------
# Flair -- Early Crosser
#  Technical Dribbler (CPU AI Only) -- Early Crosser
#  Backs Into Player -- Early Crosser
# ------------------------------------------------------------
# Flair -- Fancy Passes
#  Technical Dribbler (CPU AI Only) -- Fancy Passes
#  Backs Into Player -- Fancy Passes
# ------------------------------------------------------------
# Flair -- Finesse Shot
#  Technical Dribbler (CPU AI Only) -- Finesse Shot
# ...

# %%
traits_list
# Out:
# ['Bicycle Kicks',
#  'Chip Shot',
#  'Dives Into Tackles',
#  'Early Crosser',
#  'Fancy Passes',
#  'Finesse Shot',
#  'Flair',
#  'Giant Throw-In',
#  'GK Cautious With Crosses',
#  'GK Comes For Crosses',
#  'GK Flat Kick',
#  'GK Long Thrower',
#  'GK Save With Foot',
#  'Injury Prone',
#  'Leadership',
#  'Long Passer',
#  'Long Shot Taker',
#  'Long Throw-In',
#  'One Club Player',
#  'Outside Foot Shot',
#  'Play Maker',
#  'Power Header',
#  'Rushes Out Of Goal',
#  'Second Wind',
#  'Set Play Specialist',
#  'Solid Player',
#  'Speed Dribbler',
#  'Swerve',
#  'Takes Powerful Driven Free Kicks',
#  'Team Player',
#  'Technical Dribbler']

# %%
'Flair' in traits_list
# Out:
# True

# %%
for trait in traits_list:
    trait_value = 0
    for p_trait in player_traits.values[0].split(','):
            # print(p_trait, '--', trait in p_trait)
            if  trait in p_trait:
                trait_value = 1
                break
    test[trait] = trait_value
    print('---' * 20)
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ...

# %%
test
# Out:
#      height_cm  weight_kg  preferred_foot  weak_foot  skill_moves  \
# 190        175         68               1          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic                                      player_traits  \
# 190       34.0    49.0  Flair, Technical Dribbler (CPU AI Only), Backs...
#
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# ...

# %%
test.drop(columns='player_traits')
# Out:
#      height_cm  weight_kg  preferred_foot  weak_foot  skill_moves  \
# 190        175         68               1          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic attacking_crossing attacking_finishing  \
# 190       34.0    49.0                 60                  76
#
#     attacking_heading_accuracy attacking_short_passing attacking_volleys  \
# 190                       42-2                      84                75
#
#     skill_dribbling skill_curve skill_fk_accuracy skill_long_passing  \
# 190              87          74                63                 73
#
#     skill_ball_control movement_acceleration movement_sprint_speed  \
# 190               85+1                  76-7                  65-1
#
#     movement_agility movement_reactions movement_balance power_shot_power  \
# ...

# %%
test
# Out:
#      height_cm  weight_kg  preferred_foot  weak_foot  skill_moves  \
# 190        175         68               1          4            4
#
#          work_rate          player_tags  pace  shooting  passing  dribbling  \
# 190  Medium/Medium  #Dribbler, #Acrobat  70.0      68.0     76.0       87.0
#
#      defending  physic                                      player_traits  \
# 190       34.0    49.0  Flair, Technical Dribbler (CPU AI Only), Backs...
#
#     attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 190                 60                  76                       42-2
#
#     attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# 190                      84                75              87          74
#
#     skill_fk_accuracy skill_long_passing skill_ball_control  \
# 190                63                 73               85+1
#
#     movement_acceleration movement_sprint_speed movement_agility  \
# ...
