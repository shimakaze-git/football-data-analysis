# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
# Out:
# /Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv(
    '../data/players_20.csv'
)

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2              Neymar Jr        Neymar da Silva Santos Junior   27
# 3               J. Oblak                            Jan Oblak   26
# 4              E. Hazard                          Eden Hazard   28
# ...                  ...                                  ...  ...
# 18273         Shao Shuai                                   邵帅   22
# 18274       Xiao Mingjie                         Mingjie Xiao   22
# 18275          Zhang Wei                                   张威   19
# 18276       Wang Haijian                                  汪海健   18
# 18277         Pan Ximing                                  潘喜明   26
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# 2      1992-02-05        175         68      Brazil
# 3      1993-01-07        188         87    Slovenia
# 4      1991-01-07        175         74     Belgium
# ...           ...        ...        ...         ...
# 18273  1997-03-10        186         79    China PR
# 18274  1997-01-01        177         66    China PR
# 18275  2000-05-16        186         75    China PR
# 18276  2000-08-02        185         74    China PR
# 18277  1993-01-11        182         78    China PR
#
#                                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 0                       FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2  63+2
# 1                           Juventus  ...  65+3  61+3  61+3  61+3  65+3  61+3
# 2                Paris Saint-Germain  ...  66+3  61+3  61+3  61+3  66+3  61+3
# 3                    Atlético Madrid  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4                        Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3
# ...                              ...  ...   ...   ...   ...   ...   ...   ...
# 18273               Beijing Renhe FC  ...  43+2  42+2  42+2  42+2  43+2  45+2
# 18274               Shanghai SIPG FC  ...  44+2  43+2  43+2  43+2  44+2  46+2
# 18275         Hebei China Fortune FC  ...  47+2  49+2  49+2  49+2  47+2  47+2
# 18276  Shanghai Greenland Shenhua FC  ...  48+2  48+2  48+2  48+2  48+2  48+2
# 18277         Hebei China Fortune FC  ...  48+2  49+2  49+2  49+2  48+2  48+2
#
#         lcb    cb   rcb    rb
# 0      52+2  52+2  52+2  63+2
# 1      53+3  53+3  53+3  61+3
# 2      46+3  46+3  46+3  61+3
# 3       NaN   NaN   NaN   NaN
# 4      49+3  49+3  49+3  61+3
# ...     ...   ...   ...   ...
# 18273  46+2  46+2  46+2  45+2
# 18274  47+2  47+2  47+2  46+2
# 18275  49+2  49+2  49+2  47+2
# 18276  49+2  49+2  49+2  48+2
# 18277  50+2  50+2  50+2  48+2
#
# [18278 rows x 104 columns]

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
list(df.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb']

# %%
ten_young = df.query('age < 20 & 80 <= potential')

# %%
ten_young
# Out:
#        sofifa_id                                         player_url  \
# 73        235243  https://sofifa.com/player/235243/matthijs-de-l...
# 108       233049  https://sofifa.com/player/233049/jadon-sancho/...
# 411       242444  https://sofifa.com/player/242444/joao-felix-se...
# 568       238794  https://sofifa.com/player/238794/vinicius-jose...
# 1254      237692  https://sofifa.com/player/237692/phil-foden/20...
# ...          ...                                                ...
# 15872     251752  https://sofifa.com/player/251752/lucas-chevali...
# 15873     252276  https://sofifa.com/player/252276/raul-prada-lo...
# 16357     246601  https://sofifa.com/player/246601/james-rowland...
# 16717     252072  https://sofifa.com/player/252072/santiago-ramo...
# 17077     243353  https://sofifa.com/player/243353/bali-mumba/20...
#
#            short_name                         long_name  age         dob  \
# 73         M. de Ligt                  Matthijs de Ligt   19  1999-08-12
# 108         J. Sancho                      Jadon Sancho   19  2000-03-25
# 411        João Félix               João Félix Sequeira   19  1999-11-10
# 568      Vinícius Jr.  Vinícius José de Oliveira Júnior   18  2000-07-12
# 1254         P. Foden                      Philip Foden   19  2000-05-28
# ...               ...                               ...  ...         ...
# 15872    L. Chevalier                   Lucas Chevalier   17  2001-11-06
# 15873      Raúl Prada                 Raúl Prada Lozano   18  2001-01-01
# 16357      J. Rowland                     James Rowland   17  2001-12-03
# 16717  S. Ramos Mingo              Santiago Ramos Mingo   17  2001-11-21
# 17077        B. Mumba                        Bali Mumba   17  2001-10-08
#
#        height_cm  weight_kg  nationality               club  ...   lwb   ldm  \
# 73           189         89  Netherlands           Juventus  ...  74+3  79+3
# 108          180         76      England  Borussia Dortmund  ...  64+2  58+2
# 411          181         70     Portugal    Atlético Madrid  ...  62+2  59+2
# 568          176         73       Brazil        Real Madrid  ...  58+2  53+2
# 1254         171         69      England    Manchester City  ...  66+2  66+2
# ...          ...        ...          ...                ...  ...   ...   ...
# 15872        187         78       France         LOSC Lille  ...   NaN   NaN
# 15873        180         68        Spain       RCD Mallorca  ...  52+2  52+2
# 16357        165         65      England         Shrewsbury  ...  49+2  46+2
# 16717        185         74    Argentina       Boca Juniors  ...  49+2  48+2
# 17077        163         57      England         Sunderland  ...  54+2  55+2
#
#         cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 73     79+3  79+3  74+3  76+3  82+3  82+3  82+3  76+3
# 108    58+2  58+2  64+2  59+2  47+2  47+2  47+2  59+2
# 411    59+2  59+2  62+2  59+2  53+2  53+2  53+2  59+2
# 568    53+2  53+2  58+2  53+2  43+2  43+2  43+2  53+2
# 1254   66+2  66+2  66+2  63+2  56+2  56+2  56+2  63+2
# ...     ...   ...   ...   ...   ...   ...   ...   ...
# 15872   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15873  52+2  52+2  52+2  54+2  57+2  57+2  57+2  54+2
# 16357  46+2  46+2  49+2  47+2  40+2  40+2  40+2  47+2
# 16717  48+2  48+2  49+2  52+2  55+2  55+2  55+2  52+2
# 17077  55+2  55+2  54+2  54+2  54+2  54+2  54+2  54+2
#
# [344 rows x 104 columns]

# %%
teens = df.query('age < 20 & 80 <= potential')

# %%
teens_nationalities = teens['nationality']

# %%
teens_nationalities
# Out:
# 73       Netherlands
# 108          England
# 411         Portugal
# 568           Brazil
# 1254         England
#             ...
# 15872         France
# 15873          Spain
# 16357        England
# 16717      Argentina
# 17077        England
# Name: nationality, Length: 344, dtype: object

# %%
teens_nationalities.value_counts(sort=True).to_dict()
# Out:
# {'France': 50,
#  'England': 40,
#  'Spain': 31,
#  'Netherlands': 23,
#  'Italy': 21,
#  'Germany': 18,
#  'Argentina': 18,
#  'Portugal': 12,
#  'Belgium': 10,
#  'Brazil': 9,
#  'Colombia': 9,
#  'Scotland': 9,
#  'United States': 8,
#  'Turkey': 6,
#  'Wales': 4,
#  'Republic of Ireland': 4,
#  'Venezuela': 4,
#  'Croatia': 4,
#  'Russia': 4,
#  'Poland': 3,
#  'Norway': 3,
#  'Sweden': 3,
#  'Mexico': 3,
#  'Denmark': 3,
#  'Switzerland': 3,
#  'Georgia': 2,
#  'FYR Macedonia': 2,
#  'Korea Republic': 2,
#  'Mali': 2,
#  'Burkina Faso': 2,
#  'Nigeria': 2,
#  'Czech Republic': 2,
#  'Serbia': 2,
#  'Senegal': 2,
#  'Ivory Coast': 2,
#  'Austria': 2,
#  'Ukraine': 2,
#  'Japan': 2,
#  'Canada': 2,
#  'Luxembourg': 1,
#  'New Zealand': 1,
#  'Australia': 1,
#  'Chile': 1,
#  'Bulgaria': 1,
#  'Hungary': 1,
#  'DR Congo': 1,
#  'Iran': 1,
#  'Ghana': 1,
#  'Romania': 1,
#  'Ecuador': 1,
#  'Israel': 1,
#  'Uruguay': 1,
#  'South Africa': 1}

# %%
df.query('age < 20 & 80 <= potentia & nationality == "Japan"l')
# Out:
# Traceback (most recent call last):
#
#   File "/Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-12-f74e95c1b312>", line 1, in <module>
#     df.query('age < 20 & 80 <= potentia & nationality == "Japan"l')
#
#   File "/Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py", line 3231, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py", line 3346, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/eval.py", line 332, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 764, in __init__
#     self.terms = self.parse()
#
#   File "/Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 781, in parse
#     return self._visitor.visit(self.expr)
#
#   File "/Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 371, in visit
#     raise e
#
#   File "/Users/oshima/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 367, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File "/Users/oshima/.pyenv/versions/3.8.0/lib/python3.8/ast.py", line 47, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     age <20 and 80 <=potentia and nationality =="Japan"l
#                                                        ^
# SyntaxError: Python keyword not valid identifier in numexpr query

# %%
df.query('age < 20 & 80 <= potentia & nationality == Japanl')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __getitem__(self, key)
#     890                 pass
# --> 891         return self.__missing__(key)            # support subclasses that define __missing__
#     892
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __missing__(self, key)
#     882     def __missing__(self, key):
# --> 883         raise KeyError(key)
#     884
#
# KeyError: 'potentia'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     197                 # e.g., df[df > 0]
# --> 198                 return self.temps[key]
#     199             except KeyError:
#
# KeyError: 'potentia'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-13-55b0c2078b46> in <module>
# ----> 1 df.query('age < 20 & 80 <= potentia & nationality == Japanl')
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     330         )
#     331
# --> 332         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     333
#     334         # construct the engine and evaluate the parsed expression
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     762         self.parser = parser
#     763         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 764         self.terms = self.parse()
#     765
#     766     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in parse(self)
#     779     def parse(self):
#     780         """Parse an expression"""
# --> 781         return self._visitor.visit(self.expr)
#     782
#     783     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     379             raise SyntaxError("only a single expression is allowed")
#     380         expr = node.body[0]
# --> 381         return self.visit(expr, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
# --> 384         return self.visit(node.value, **kwargs)
#     385
#     386     def _rewrite_membership_op(self, node, left, right):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_BoolOp(self, node, **kwargs)
#     701
#     702         operands = node.values
# --> 703         return reduce(visitor, operands)
#     704
#     705
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visitor(x, y)
#     695         def visitor(x, y):
#     696             lhs = self._try_visit_binop(x)
# --> 697             rhs = self._try_visit_binop(y)
#     698
#     699             op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in _try_visit_binop(self, bop)
#     690         if isinstance(bop, (Op, Term)):
#     691             return bop
# --> 692         return self.visit(bop)
#     693
#     694     def visit_BoolOp(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     674             op = self.translate_In(ops[0])
#     675             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 676             return self.visit(binop)
#     677
#     678         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     495
#     496     def visit_BinOp(self, node, **kwargs):
# --> 497         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     498         left, right = self._maybe_downcast_constants(left, right)
#     499         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     416             left = self.visit(node.left, side="left")
#     417         if right is None:
# --> 418             right = self.visit(node.right, side="right")
#     419         op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     420         return op, op_class, left, right
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     508
#     509     def visit_Name(self, node, **kwargs):
# --> 510         return self.term_type(node.id, self.env, **kwargs)
#     511
#     512     def visit_NameConstant(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      80         tname = str(name)
#      81         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 82         self._value = self._resolve_name()
#      83         self.encoding = encoding
#      84
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#      97
#      98     def _resolve_name(self):
# ---> 99         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     100         self.update(res)
#     101
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     201                 from pandas.core.computation.ops import UndefinedVariableError
#     202
# --> 203                 raise UndefinedVariableError(key, is_local)
#     204
#     205     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'potentia' is not defined

# %%
df.query('age < 20 & 80 <= potentia').query('nationality = Japanl')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __getitem__(self, key)
#     890                 pass
# --> 891         return self.__missing__(key)            # support subclasses that define __missing__
#     892
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __missing__(self, key)
#     882     def __missing__(self, key):
# --> 883         raise KeyError(key)
#     884
#
# KeyError: 'potentia'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     197                 # e.g., df[df > 0]
# --> 198                 return self.temps[key]
#     199             except KeyError:
#
# KeyError: 'potentia'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-14-b7b59f4bd7d5> in <module>
# ----> 1 df.query('age < 20 & 80 <= potentia').query('nationality = Japanl')
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     330         )
#     331
# --> 332         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     333
#     334         # construct the engine and evaluate the parsed expression
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     762         self.parser = parser
#     763         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 764         self.terms = self.parse()
#     765
#     766     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in parse(self)
#     779     def parse(self):
#     780         """Parse an expression"""
# --> 781         return self._visitor.visit(self.expr)
#     782
#     783     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     379             raise SyntaxError("only a single expression is allowed")
#     380         expr = node.body[0]
# --> 381         return self.visit(expr, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
# --> 384         return self.visit(node.value, **kwargs)
#     385
#     386     def _rewrite_membership_op(self, node, left, right):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_BoolOp(self, node, **kwargs)
#     701
#     702         operands = node.values
# --> 703         return reduce(visitor, operands)
#     704
#     705
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visitor(x, y)
#     695         def visitor(x, y):
#     696             lhs = self._try_visit_binop(x)
# --> 697             rhs = self._try_visit_binop(y)
#     698
#     699             op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in _try_visit_binop(self, bop)
#     690         if isinstance(bop, (Op, Term)):
#     691             return bop
# --> 692         return self.visit(bop)
#     693
#     694     def visit_BoolOp(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     674             op = self.translate_In(ops[0])
#     675             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 676             return self.visit(binop)
#     677
#     678         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     495
#     496     def visit_BinOp(self, node, **kwargs):
# --> 497         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     498         left, right = self._maybe_downcast_constants(left, right)
#     499         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     416             left = self.visit(node.left, side="left")
#     417         if right is None:
# --> 418             right = self.visit(node.right, side="right")
#     419         op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     420         return op, op_class, left, right
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     508
#     509     def visit_Name(self, node, **kwargs):
# --> 510         return self.term_type(node.id, self.env, **kwargs)
#     511
#     512     def visit_NameConstant(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      80         tname = str(name)
#      81         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 82         self._value = self._resolve_name()
#      83         self.encoding = encoding
#      84
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#      97
#      98     def _resolve_name(self):
# ---> 99         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     100         self.update(res)
#     101
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     201                 from pandas.core.computation.ops import UndefinedVariableError
#     202
# --> 203                 raise UndefinedVariableError(key, is_local)
#     204
#     205     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'potentia' is not defined

# %%
df.query('age < 20 & 80 <= potentia').query('nationality == Japanl')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __getitem__(self, key)
#     890                 pass
# --> 891         return self.__missing__(key)            # support subclasses that define __missing__
#     892
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __missing__(self, key)
#     882     def __missing__(self, key):
# --> 883         raise KeyError(key)
#     884
#
# KeyError: 'potentia'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     197                 # e.g., df[df > 0]
# --> 198                 return self.temps[key]
#     199             except KeyError:
#
# KeyError: 'potentia'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-15-52e159829a04> in <module>
# ----> 1 df.query('age < 20 & 80 <= potentia').query('nationality == Japanl')
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     330         )
#     331
# --> 332         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     333
#     334         # construct the engine and evaluate the parsed expression
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     762         self.parser = parser
#     763         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 764         self.terms = self.parse()
#     765
#     766     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in parse(self)
#     779     def parse(self):
#     780         """Parse an expression"""
# --> 781         return self._visitor.visit(self.expr)
#     782
#     783     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     379             raise SyntaxError("only a single expression is allowed")
#     380         expr = node.body[0]
# --> 381         return self.visit(expr, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
# --> 384         return self.visit(node.value, **kwargs)
#     385
#     386     def _rewrite_membership_op(self, node, left, right):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_BoolOp(self, node, **kwargs)
#     701
#     702         operands = node.values
# --> 703         return reduce(visitor, operands)
#     704
#     705
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visitor(x, y)
#     695         def visitor(x, y):
#     696             lhs = self._try_visit_binop(x)
# --> 697             rhs = self._try_visit_binop(y)
#     698
#     699             op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in _try_visit_binop(self, bop)
#     690         if isinstance(bop, (Op, Term)):
#     691             return bop
# --> 692         return self.visit(bop)
#     693
#     694     def visit_BoolOp(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     674             op = self.translate_In(ops[0])
#     675             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 676             return self.visit(binop)
#     677
#     678         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     495
#     496     def visit_BinOp(self, node, **kwargs):
# --> 497         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     498         left, right = self._maybe_downcast_constants(left, right)
#     499         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     416             left = self.visit(node.left, side="left")
#     417         if right is None:
# --> 418             right = self.visit(node.right, side="right")
#     419         op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     420         return op, op_class, left, right
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     508
#     509     def visit_Name(self, node, **kwargs):
# --> 510         return self.term_type(node.id, self.env, **kwargs)
#     511
#     512     def visit_NameConstant(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      80         tname = str(name)
#      81         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 82         self._value = self._resolve_name()
#      83         self.encoding = encoding
#      84
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#      97
#      98     def _resolve_name(self):
# ---> 99         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     100         self.update(res)
#     101
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     201                 from pandas.core.computation.ops import UndefinedVariableError
#     202
# --> 203                 raise UndefinedVariableError(key, is_local)
#     204
#     205     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'potentia' is not defined

# %%
df.query('age < 20 & 80 <= potentia')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __getitem__(self, key)
#     890                 pass
# --> 891         return self.__missing__(key)            # support subclasses that define __missing__
#     892
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __missing__(self, key)
#     882     def __missing__(self, key):
# --> 883         raise KeyError(key)
#     884
#
# KeyError: 'potentia'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     197                 # e.g., df[df > 0]
# --> 198                 return self.temps[key]
#     199             except KeyError:
#
# KeyError: 'potentia'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-16-f16308024381> in <module>
# ----> 1 df.query('age < 20 & 80 <= potentia')
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     330         )
#     331
# --> 332         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     333
#     334         # construct the engine and evaluate the parsed expression
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     762         self.parser = parser
#     763         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 764         self.terms = self.parse()
#     765
#     766     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in parse(self)
#     779     def parse(self):
#     780         """Parse an expression"""
# --> 781         return self._visitor.visit(self.expr)
#     782
#     783     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     379             raise SyntaxError("only a single expression is allowed")
#     380         expr = node.body[0]
# --> 381         return self.visit(expr, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
# --> 384         return self.visit(node.value, **kwargs)
#     385
#     386     def _rewrite_membership_op(self, node, left, right):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_BoolOp(self, node, **kwargs)
#     701
#     702         operands = node.values
# --> 703         return reduce(visitor, operands)
#     704
#     705
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visitor(x, y)
#     695         def visitor(x, y):
#     696             lhs = self._try_visit_binop(x)
# --> 697             rhs = self._try_visit_binop(y)
#     698
#     699             op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in _try_visit_binop(self, bop)
#     690         if isinstance(bop, (Op, Term)):
#     691             return bop
# --> 692         return self.visit(bop)
#     693
#     694     def visit_BoolOp(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     674             op = self.translate_In(ops[0])
#     675             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 676             return self.visit(binop)
#     677
#     678         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     495
#     496     def visit_BinOp(self, node, **kwargs):
# --> 497         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     498         left, right = self._maybe_downcast_constants(left, right)
#     499         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     416             left = self.visit(node.left, side="left")
#     417         if right is None:
# --> 418             right = self.visit(node.right, side="right")
#     419         op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     420         return op, op_class, left, right
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     508
#     509     def visit_Name(self, node, **kwargs):
# --> 510         return self.term_type(node.id, self.env, **kwargs)
#     511
#     512     def visit_NameConstant(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      80         tname = str(name)
#      81         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 82         self._value = self._resolve_name()
#      83         self.encoding = encoding
#      84
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#      97
#      98     def _resolve_name(self):
# ---> 99         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     100         self.update(res)
#     101
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     201                 from pandas.core.computation.ops import UndefinedVariableError
#     202
# --> 203                 raise UndefinedVariableError(key, is_local)
#     204
#     205     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'potentia' is not defined

# %%
df.query('age < 20 & 80 <= potential')
# Out:
#        sofifa_id                                         player_url  \
# 73        235243  https://sofifa.com/player/235243/matthijs-de-l...
# 108       233049  https://sofifa.com/player/233049/jadon-sancho/...
# 411       242444  https://sofifa.com/player/242444/joao-felix-se...
# 568       238794  https://sofifa.com/player/238794/vinicius-jose...
# 1254      237692  https://sofifa.com/player/237692/phil-foden/20...
# ...          ...                                                ...
# 15872     251752  https://sofifa.com/player/251752/lucas-chevali...
# 15873     252276  https://sofifa.com/player/252276/raul-prada-lo...
# 16357     246601  https://sofifa.com/player/246601/james-rowland...
# 16717     252072  https://sofifa.com/player/252072/santiago-ramo...
# 17077     243353  https://sofifa.com/player/243353/bali-mumba/20...
#
#            short_name                         long_name  age         dob  \
# 73         M. de Ligt                  Matthijs de Ligt   19  1999-08-12
# 108         J. Sancho                      Jadon Sancho   19  2000-03-25
# 411        João Félix               João Félix Sequeira   19  1999-11-10
# 568      Vinícius Jr.  Vinícius José de Oliveira Júnior   18  2000-07-12
# 1254         P. Foden                      Philip Foden   19  2000-05-28
# ...               ...                               ...  ...         ...
# 15872    L. Chevalier                   Lucas Chevalier   17  2001-11-06
# 15873      Raúl Prada                 Raúl Prada Lozano   18  2001-01-01
# 16357      J. Rowland                     James Rowland   17  2001-12-03
# 16717  S. Ramos Mingo              Santiago Ramos Mingo   17  2001-11-21
# 17077        B. Mumba                        Bali Mumba   17  2001-10-08
#
#        height_cm  weight_kg  nationality               club  ...   lwb   ldm  \
# 73           189         89  Netherlands           Juventus  ...  74+3  79+3
# 108          180         76      England  Borussia Dortmund  ...  64+2  58+2
# 411          181         70     Portugal    Atlético Madrid  ...  62+2  59+2
# 568          176         73       Brazil        Real Madrid  ...  58+2  53+2
# 1254         171         69      England    Manchester City  ...  66+2  66+2
# ...          ...        ...          ...                ...  ...   ...   ...
# 15872        187         78       France         LOSC Lille  ...   NaN   NaN
# 15873        180         68        Spain       RCD Mallorca  ...  52+2  52+2
# 16357        165         65      England         Shrewsbury  ...  49+2  46+2
# 16717        185         74    Argentina       Boca Juniors  ...  49+2  48+2
# 17077        163         57      England         Sunderland  ...  54+2  55+2
#
#         cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 73     79+3  79+3  74+3  76+3  82+3  82+3  82+3  76+3
# 108    58+2  58+2  64+2  59+2  47+2  47+2  47+2  59+2
# 411    59+2  59+2  62+2  59+2  53+2  53+2  53+2  59+2
# 568    53+2  53+2  58+2  53+2  43+2  43+2  43+2  53+2
# 1254   66+2  66+2  66+2  63+2  56+2  56+2  56+2  63+2
# ...     ...   ...   ...   ...   ...   ...   ...   ...
# 15872   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15873  52+2  52+2  52+2  54+2  57+2  57+2  57+2  54+2
# 16357  46+2  46+2  49+2  47+2  40+2  40+2  40+2  47+2
# 16717  48+2  48+2  49+2  52+2  55+2  55+2  55+2  52+2
# 17077  55+2  55+2  54+2  54+2  54+2  54+2  54+2  54+2
#
# [344 rows x 104 columns]

# %%
df.query('age < 20 & 80 <= potential').query('nationality == Japan')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __getitem__(self, key)
#     890                 pass
# --> 891         return self.__missing__(key)            # support subclasses that define __missing__
#     892
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/collections/__init__.py in __missing__(self, key)
#     882     def __missing__(self, key):
# --> 883         raise KeyError(key)
#     884
#
# KeyError: 'Japan'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     197                 # e.g., df[df > 0]
# --> 198                 return self.temps[key]
#     199             except KeyError:
#
# KeyError: 'Japan'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-18-aa7af82e8639> in <module>
# ----> 1 df.query('age < 20 & 80 <= potential').query('nationality == Japan')
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     330         )
#     331
# --> 332         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     333
#     334         # construct the engine and evaluate the parsed expression
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     762         self.parser = parser
#     763         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 764         self.terms = self.parse()
#     765
#     766     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in parse(self)
#     779     def parse(self):
#     780         """Parse an expression"""
# --> 781         return self._visitor.visit(self.expr)
#     782
#     783     @property
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     379             raise SyntaxError("only a single expression is allowed")
#     380         expr = node.body[0]
# --> 381         return self.visit(expr, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
# --> 384         return self.visit(node.value, **kwargs)
#     385
#     386     def _rewrite_membership_op(self, node, left, right):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     674             op = self.translate_In(ops[0])
#     675             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 676             return self.visit(binop)
#     677
#     678         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     495
#     496     def visit_BinOp(self, node, **kwargs):
# --> 497         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     498         left, right = self._maybe_downcast_constants(left, right)
#     499         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     416             left = self.visit(node.left, side="left")
#     417         if right is None:
# --> 418             right = self.visit(node.right, side="right")
#     419         op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     420         return op, op_class, left, right
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     508
#     509     def visit_Name(self, node, **kwargs):
# --> 510         return self.term_type(node.id, self.env, **kwargs)
#     511
#     512     def visit_NameConstant(self, node, **kwargs):
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      80         tname = str(name)
#      81         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 82         self._value = self._resolve_name()
#      83         self.encoding = encoding
#      84
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#      97
#      98     def _resolve_name(self):
# ---> 99         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     100         self.update(res)
#     101
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     201                 from pandas.core.computation.ops import UndefinedVariableError
#     202
# --> 203                 raise UndefinedVariableError(key, is_local)
#     204
#     205     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'Japan' is not defined

# %%
df.query('age < 20 & 80 <= potential').query("nationality == 'Japan'")
# Out:
#        sofifa_id                                         player_url  \
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 12178     242914  https://sofifa.com/player/242914/keito-nakamur...
#
#         short_name long_name  age         dob  height_cm  weight_kg  \
# 4757       T. Kubo     久保 建英   18  2001-06-04        173         67
# 12178  K. Nakamura     中村 敬斗   18  2000-07-28        180         75
#
#       nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 4757        Japan  Real Madrid  ...  57+2  52+2  52+2  52+2  57+2  55+2  45+2
# 12178       Japan    FC Twente  ...  50+2  46+2  46+2  46+2  50+2  47+2  42+2
#
#          cb   rcb    rb
# 4757   45+2  45+2  55+2
# 12178  42+2  42+2  47+2
#
# [2 rows x 104 columns]

# %%
df.query('age < 20 & 75 <= potential').query("nationality == 'Japan'")
# Out:
#        sofifa_id                                         player_url  \
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 8896      244654  https://sofifa.com/player/244654/keisuke-osako...
# 12178     242914  https://sofifa.com/player/242914/keito-nakamur...
# 14051     252903  https://sofifa.com/player/252903/shinta-appelk...
# 14720     246854  https://sofifa.com/player/246854/kotaro-arima/...
# 15363     246852  https://sofifa.com/player/246852/ikuma-sekigaw...
# 15390     247730  https://sofifa.com/player/247730/daiki-matsuok...
#
#          short_name         long_name  age         dob  height_cm  weight_kg  \
# 4757        T. Kubo             久保 建英   18  2001-06-04        173         67
# 8896       K. Osako             大迫 圭介   19  1999-07-28        186         86
# 12178   K. Nakamura             中村 敬斗   18  2000-07-28        180         75
# 14051  S. Appelkamp  Shinta Appelkamp   18  2000-11-01        175         61
# 14720      K. Arima            有馬 幸太郎   18  2000-09-03        181         71
# 15363   I. Sekigawa             関川 郁万   18  2000-09-13        182         72
# 15390   D. Matsuoka             松岡 大起   18  2001-06-01        170         65
#
#       nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# 4757        Japan          Real Madrid  ...  57+2  52+2  52+2  52+2  57+2
# 8896        Japan  Sanfrecce Hiroshima  ...   NaN   NaN   NaN   NaN   NaN
# 12178       Japan            FC Twente  ...  50+2  46+2  46+2  46+2  50+2
# 14051       Japan   Fortuna Düsseldorf  ...  50+2  47+2  47+2  47+2  50+2
# 14720       Japan      Kashima Antlers  ...  46+2  43+2  43+2  43+2  46+2
# 15363       Japan      Kashima Antlers  ...  48+2  50+2  50+2  50+2  48+2
# 15390       Japan           Sagan Tosu  ...  50+2  49+2  49+2  49+2  50+2
#
#          lb   lcb    cb   rcb    rb
# 4757   55+2  45+2  45+2  45+2  55+2
# 8896    NaN   NaN   NaN   NaN   NaN
# 12178  47+2  42+2  42+2  42+2  47+2
# 14051  47+2  39+2  39+2  39+2  47+2
# 14720  44+2  37+2  37+2  37+2  44+2
# 15363  51+2  57+2  57+2  57+2  51+2
# 15390  48+2  44+2  44+2  44+2  48+2
#
# [7 rows x 104 columns]

# %%
pd.get_option("display.max_columns")
# Out:
# 20

# %%
df.query('age < 20 & 75 <= potential').query("nationality == 'Japan'")
# Out:
#        sofifa_id                                         player_url  \
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 8896      244654  https://sofifa.com/player/244654/keisuke-osako...
# 12178     242914  https://sofifa.com/player/242914/keito-nakamur...
# 14051     252903  https://sofifa.com/player/252903/shinta-appelk...
# 14720     246854  https://sofifa.com/player/246854/kotaro-arima/...
# 15363     246852  https://sofifa.com/player/246852/ikuma-sekigaw...
# 15390     247730  https://sofifa.com/player/247730/daiki-matsuok...
#
#          short_name         long_name  age         dob  height_cm  weight_kg  \
# 4757        T. Kubo             久保 建英   18  2001-06-04        173         67
# 8896       K. Osako             大迫 圭介   19  1999-07-28        186         86
# 12178   K. Nakamura             中村 敬斗   18  2000-07-28        180         75
# 14051  S. Appelkamp  Shinta Appelkamp   18  2000-11-01        175         61
# 14720      K. Arima            有馬 幸太郎   18  2000-09-03        181         71
# 15363   I. Sekigawa             関川 郁万   18  2000-09-13        182         72
# 15390   D. Matsuoka             松岡 大起   18  2001-06-01        170         65
#
#       nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# 4757        Japan          Real Madrid  ...  57+2  52+2  52+2  52+2  57+2
# 8896        Japan  Sanfrecce Hiroshima  ...   NaN   NaN   NaN   NaN   NaN
# 12178       Japan            FC Twente  ...  50+2  46+2  46+2  46+2  50+2
# 14051       Japan   Fortuna Düsseldorf  ...  50+2  47+2  47+2  47+2  50+2
# 14720       Japan      Kashima Antlers  ...  46+2  43+2  43+2  43+2  46+2
# 15363       Japan      Kashima Antlers  ...  48+2  50+2  50+2  50+2  48+2
# 15390       Japan           Sagan Tosu  ...  50+2  49+2  49+2  49+2  50+2
#
#          lb   lcb    cb   rcb    rb
# 4757   55+2  45+2  45+2  45+2  55+2
# 8896    NaN   NaN   NaN   NaN   NaN
# 12178  47+2  42+2  42+2  42+2  47+2
# 14051  47+2  39+2  39+2  39+2  47+2
# 14720  44+2  37+2  37+2  37+2  44+2
# 15363  51+2  57+2  57+2  57+2  51+2
# 15390  48+2  44+2  44+2  44+2  48+2
#
# [7 rows x 104 columns]

# %%
pd.set_option('display.max_rows', 150)

# %%
df.query('age < 20 & 75 <= potential').query("nationality == 'Japan'")
# Out:
#        sofifa_id                                         player_url  \
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 8896      244654  https://sofifa.com/player/244654/keisuke-osako...
# 12178     242914  https://sofifa.com/player/242914/keito-nakamur...
# 14051     252903  https://sofifa.com/player/252903/shinta-appelk...
# 14720     246854  https://sofifa.com/player/246854/kotaro-arima/...
# 15363     246852  https://sofifa.com/player/246852/ikuma-sekigaw...
# 15390     247730  https://sofifa.com/player/247730/daiki-matsuok...
#
#          short_name         long_name  age         dob  height_cm  weight_kg  \
# 4757        T. Kubo             久保 建英   18  2001-06-04        173         67
# 8896       K. Osako             大迫 圭介   19  1999-07-28        186         86
# 12178   K. Nakamura             中村 敬斗   18  2000-07-28        180         75
# 14051  S. Appelkamp  Shinta Appelkamp   18  2000-11-01        175         61
# 14720      K. Arima            有馬 幸太郎   18  2000-09-03        181         71
# 15363   I. Sekigawa             関川 郁万   18  2000-09-13        182         72
# 15390   D. Matsuoka             松岡 大起   18  2001-06-01        170         65
#
#       nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# 4757        Japan          Real Madrid  ...  57+2  52+2  52+2  52+2  57+2
# 8896        Japan  Sanfrecce Hiroshima  ...   NaN   NaN   NaN   NaN   NaN
# 12178       Japan            FC Twente  ...  50+2  46+2  46+2  46+2  50+2
# 14051       Japan   Fortuna Düsseldorf  ...  50+2  47+2  47+2  47+2  50+2
# 14720       Japan      Kashima Antlers  ...  46+2  43+2  43+2  43+2  46+2
# 15363       Japan      Kashima Antlers  ...  48+2  50+2  50+2  50+2  48+2
# 15390       Japan           Sagan Tosu  ...  50+2  49+2  49+2  49+2  50+2
#
#          lb   lcb    cb   rcb    rb
# 4757   55+2  45+2  45+2  45+2  55+2
# 8896    NaN   NaN   NaN   NaN   NaN
# 12178  47+2  42+2  42+2  42+2  47+2
# 14051  47+2  39+2  39+2  39+2  47+2
# 14720  44+2  37+2  37+2  37+2  44+2
# 15363  51+2  57+2  57+2  57+2  51+2
# 15390  48+2  44+2  44+2  44+2  48+2
#
# [7 rows x 104 columns]

# %%
pd.set_option('display.max_columns', 150)

# %%
df.query('age < 20 & 75 <= potential').query("nationality == 'Japan'")z
# Out:
#   File "<ipython-input-27-87ceaa07beb9>", line 1
#     df.query('age < 20 & 75 <= potential').query("nationality == 'Japan'")z
#                                                                           ^
# SyntaxError: invalid syntax

# %%
df.query('age < 20 & 75 <= potential').query("nationality == 'Japan'")
# Out:
#        sofifa_id                                         player_url  \
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 8896      244654  https://sofifa.com/player/244654/keisuke-osako...
# 12178     242914  https://sofifa.com/player/242914/keito-nakamur...
# 14051     252903  https://sofifa.com/player/252903/shinta-appelk...
# 14720     246854  https://sofifa.com/player/246854/kotaro-arima/...
# 15363     246852  https://sofifa.com/player/246852/ikuma-sekigaw...
# 15390     247730  https://sofifa.com/player/247730/daiki-matsuok...
#
#          short_name         long_name  age         dob  height_cm  weight_kg  \
# 4757        T. Kubo             久保 建英   18  2001-06-04        173         67
# 8896       K. Osako             大迫 圭介   19  1999-07-28        186         86
# 12178   K. Nakamura             中村 敬斗   18  2000-07-28        180         75
# 14051  S. Appelkamp  Shinta Appelkamp   18  2000-11-01        175         61
# 14720      K. Arima            有馬 幸太郎   18  2000-09-03        181         71
# 15363   I. Sekigawa             関川 郁万   18  2000-09-13        182         72
# 15390   D. Matsuoka             松岡 大起   18  2001-06-01        170         65
#
#       nationality                 club  overall  potential  value_eur  \
# 4757        Japan          Real Madrid       70         87    3700000
# 8896        Japan  Sanfrecce Hiroshima       66         76     800000
# 12178       Japan            FC Twente       63         81     750000
# 14051       Japan   Fortuna Düsseldorf       61         76     525000
# 14720       Japan      Kashima Antlers       60         76     425000
# 15363       Japan      Kashima Antlers       59         77     300000
# 15390       Japan           Sagan Tosu       59         75     325000
#
#        wage_eur player_positions preferred_foot  international_reputation  \
# 4757      21000           RM, CF           Left                         1
# 8896       1000               GK          Right                         1
# 12178      1000          LW, CAM          Right                         1
# 14051      2000              CAM          Right                         1
# 14720      1000       RM, ST, LM          Right                         1
# 15363      1000               CB          Right                         1
# 15390      1000      RM, CM, CAM          Right                         1
#
#        weak_foot  skill_moves      work_rate body_type real_face  \
# 4757           4            4    High/Medium      Lean        No
# 8896           2            1  Medium/Medium    Normal        No
# 12178          3            4    High/Medium      Lean        No
# 14051          3            3  Medium/Medium      Lean        No
# 14720          3            2  Medium/Medium      Lean        No
# 15363          2            2       Low/High    Normal        No
# 15390          3            3     Medium/Low      Lean        No
#
#        release_clause_eur player_tags team_position  team_jersey_number  \
# 4757            9800000.0         NaN           RES                26.0
# 8896            1200000.0         NaN            GK                38.0
# 12178                 NaN         NaN            LW                13.0
# 14051           1300000.0         NaN           RES                36.0
# 14720            797000.0         NaN           RES                34.0
# 15363            563000.0         NaN           RES                33.0
# 15390            609000.0         NaN           RCM                41.0
#
#        loaned_from      joined  contract_valid_until nation_position  \
# 4757           NaN  2019-07-01                2025.0             NaN
# 8896           NaN  2018-01-01                2019.0             NaN
# 12178  Gamba Osaka         NaN                2021.0             NaN
# 14051          NaN  2019-07-01                2021.0             NaN
# 14720          NaN  2019-01-01                2022.0             NaN
# 15363          NaN  2019-01-01                2022.0             NaN
# 15390          NaN  2019-03-02                2022.0             NaN
#
#        nation_jersey_number  pace  shooting  passing  dribbling  defending  \
# 4757                    NaN  82.0      60.0     62.0       78.0       39.0
# 8896                    NaN   NaN       NaN      NaN        NaN        NaN
# 12178                   NaN  76.0      54.0     53.0       71.0       31.0
# 14051                   NaN  66.0      45.0     60.0       68.0       35.0
# 14720                   NaN  67.0      52.0     54.0       64.0       31.0
# 15363                   NaN  56.0      31.0     31.0       42.0       58.0
# 15390                   NaN  60.0      43.0     57.0       64.0       38.0
#
#        physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 4757     52.0        NaN          NaN         NaN          NaN       NaN
# 8896      NaN       67.0         66.0        65.0         69.0      30.0
# 12178    64.0        NaN          NaN         NaN          NaN       NaN
# 14051    39.0        NaN          NaN         NaN          NaN       NaN
# 14720    49.0        NaN          NaN         NaN          NaN       NaN
# 15363    65.0        NaN          NaN         NaN          NaN       NaN
# 15390    56.0        NaN          NaN         NaN          NaN       NaN
#
#        gk_positioning                                  player_traits  \
# 4757              NaN                                Crowd Favourite
# 8896             63.0                                            NaN
# 12178             NaN  Speed Dribbler (CPU AI Only), Crowd Favourite
# 14051             NaN                                            NaN
# 14720             NaN                                            NaN
# 15363             NaN                                            NaN
# 15390             NaN                                            NaN
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 4757                   55                   64                          39
# 8896                   14                    7                          10
# 12178                  49                   59                          43
# 14051                  58                   49                          31
# 14720                  55                   60                          40
# 15363                  15                   26                          61
# 15390                  55                   43                          38
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 4757                        67                 57               79
# 8896                        18                  7               12
# 12178                       54                 47               74
# 14051                       64                 46               67
# 14720                       60                 45               70
# 15363                       49                 22               32
# 15390                       64                 44               64
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 4757            68                 72                  54                  78
# 8896            10                 10                  19                  20
# 12178           69                 69                  46                  67
# 14051           55                 42                  62                  66
# 14720           45                 45                  52                  62
# 15363           18                 26                  34                  51
# 15390           46                 44                  54                  60
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 4757                      89                     77                83
# 8896                      28                     32                27
# 12178                     75                     76                72
# 14051                     69                     64                77
# 14720                     64                     69                57
# 15363                     57                     56                54
# 15390                     63                     58                76
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 4757                   61                83                61             54
# 8896                   59                38                49             42
# 12178                  61                63                55             63
# 14051                  51                79                37             61
# 14720                  40                63                36             35
# 15363                  45                53                46             73
# 15390                  56                80                47             72
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 4757              72              45                52                    43
# 8896              22              68                 7                    19
# 12178             70              71                43                    41
# 14051             51              31                41                    36
# 14720             56              50                51                    41
# 15363             59              70                32                    58
# 15390             62              58                38                    41
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 4757                        29                     62                60
# 8896                         8                      7                38
# 12178                       31                     55                54
# 14051                       35                     54                59
# 14720                       18                     57                48
# 15363                       48                     23                20
# 15390                       34                     50                57
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 4757                    61                   64                 40
# 8896                    15                   45                 12
# 12178                   54                   64                 21
# 14051                   46                   57                 37
# 14720                   40                   50                 25
# 15363                   31                   39                 56
# 15390                   42                   57                 40
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 4757                          43                        48
# 8896                          14                        11
# 12178                         36                        30
# 14051                         32                        37
# 14720                         41                        34
# 15363                         64                        58
# 15390                         38                        35
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 4757                    6                     7                   15
# 8896                   67                    66                   65
# 12178                   7                    13                   15
# 14051                  10                     9                   11
# 14720                  10                    14                    7
# 15363                   7                    13                   13
# 15390                   7                    10                   14
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 4757                        10                    10  63+2  63+2  63+2  69+2
# 8896                        63                    69   NaN   NaN   NaN   NaN
# 12178                        8                     7  59+2  59+2  59+2  62+2
# 14051                       12                    10  50+2  50+2  50+2  60+2
# 14720                        5                     6  54+2  54+2  54+2  59+2
# 15363                       11                     7  41+2  41+2  41+2  37+2
# 15390                       10                    13  51+2  51+2  51+2  57+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 4757   68+2  68+2  68+2  69+2  68+2  68+2  68+2  69+2  62+2  62+2  62+2  69+2
# 8896    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12178  61+2  61+2  61+2  62+2  60+2  60+2  60+2  62+2  55+2  55+2  55+2  62+2
# 14051  57+2  57+2  57+2  60+2  60+2  60+2  60+2  60+2  56+2  56+2  56+2  60+2
# 14720  57+2  57+2  57+2  59+2  57+2  57+2  57+2  59+2  52+2  52+2  52+2  59+2
# 15363  38+2  38+2  38+2  37+2  38+2  38+2  38+2  38+2  40+2  40+2  40+2  38+2
# 15390  55+2  55+2  55+2  57+2  57+2  57+2  57+2  58+2  55+2  55+2  55+2  58+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 4757   57+2  52+2  52+2  52+2  57+2  55+2  45+2  45+2  45+2  55+2
# 8896    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12178  50+2  46+2  46+2  46+2  50+2  47+2  42+2  42+2  42+2  47+2
# 14051  50+2  47+2  47+2  47+2  50+2  47+2  39+2  39+2  39+2  47+2
# 14720  46+2  43+2  43+2  43+2  46+2  44+2  37+2  37+2  37+2  44+2
# 15363  48+2  50+2  50+2  50+2  48+2  51+2  57+2  57+2  57+2  51+2
# 15390  50+2  49+2  49+2  49+2  50+2  48+2  44+2  44+2  44+2  48+2

# %%
df.query('age <= 24 & 75 <= potential').query("nationality == 'Japan'")
# Out:
#        sofifa_id                                         player_url  \
# 614       232862  https://sofifa.com/player/232862/shoya-nakajim...
# 1739      226627  https://sofifa.com/player/226627/takumi-minami...
# 2141      232639  https://sofifa.com/player/232639/ritsu-doan/20...
# 2662      232938  https://sofifa.com/player/232938/takehiro-tomi...
# 2756      232730  https://sofifa.com/player/232730/daichi-kamada...
# 3428      233250  https://sofifa.com/player/233250/yuma-suzuki/2...
# 4212      239712  https://sofifa.com/player/239712/masaya-okugaw...
# 4245      241994  https://sofifa.com/player/241994/yuta-toyokawa...
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 4780      237823  https://sofifa.com/player/237823/hiroki-abe/20...
# 4959      242776  https://sofifa.com/player/242776/koki-anzai/20...
# 5886      232571  https://sofifa.com/player/232571/shinnosuke-na...
# 5887      232810  https://sofifa.com/player/232810/takuya-kida/2...
# 5888      232882  https://sofifa.com/player/232882/kento-misao/2...
# 5900      242087  https://sofifa.com/player/242087/hidemasa-mori...
# 6709      237749  https://sofifa.com/player/237749/daiki-suga/20...
# 6756      241240  https://sofifa.com/player/241240/tatsuya-ito/2...
# 6782      232786  https://sofifa.com/player/232786/keita-endo/20...
# 6838      233151  https://sofifa.com/player/233151/koji-miyoshi/...
# 6843      237739  https://sofifa.com/player/237739/ryosuke-shind...
# 7857      232985  https://sofifa.com/player/232985/takahiro-kuni...
# 7898      232623  https://sofifa.com/player/232623/yosuke-ideguc...
# 7900      233152  https://sofifa.com/player/233152/ko-itakura/20...
# 7924      246321  https://sofifa.com/player/246321/daizen-maeda/...
# 8896      244654  https://sofifa.com/player/244654/keisuke-osako...
# 10038     252162  https://sofifa.com/player/252162/ayase-ueda/20...
# 12178     242914  https://sofifa.com/player/242914/keito-nakamur...
# 14051     252903  https://sofifa.com/player/252903/shinta-appelk...
# 14720     246854  https://sofifa.com/player/246854/kotaro-arima/...
# 15363     246852  https://sofifa.com/player/246852/ikuma-sekigaw...
# 15390     247730  https://sofifa.com/player/247730/daiki-matsuok...
#
#          short_name         long_name  age         dob  height_cm  weight_kg  \
# 614     S. Nakajima             中島 翔哉   24  1994-08-23        164         64
# 1739    T. Minamino             南野 拓実   24  1995-01-16        174         67
# 2141        R. Doan              堂安 律   21  1998-06-16        172         70
# 2662    T. Tomiyasu             冨安 健洋   20  1998-11-05        188         84
# 2756      D. Kamada             鎌田 大地   22  1996-08-05        184         73
# 3428      Y. Suzuki             鈴木 優磨   23  1996-04-26        182         75
# 4212     M. Okugawa             奥川 雅也   23  1996-04-14        176         62
# 4245    Y. Toyokawa             豊川 雄太   24  1994-09-09        171         64
# 4757        T. Kubo             久保 建英   18  2001-06-04        173         67
# 4780         H. Abe             安部 裕葵   20  1999-01-28        171         65
# 4959       K. Anzai             安西 幸輝   24  1995-05-31        172         64
# 5886    S. Nakatani            中谷 进之介   23  1996-03-24        184         79
# 5887        T. Kida             喜田 拓也   24  1994-08-23        169         63
# 5888       K. Misao             三竿 健斗   23  1996-04-16        181         73
# 5900      H. Morita             守田 英正   24  1995-05-10        177         74
# 6709        D. Suga              菅 大輝   20  1998-09-10        171         69
# 6756         T. Itō             伊藤 達哉   22  1997-06-26        163         59
# 6782        K. Endo             遠藤 渓太   21  1997-11-22        175         66
# 6838     K. Miyoshi             三好 康児   22  1997-03-26        167         64
# 6843      R. Shindo             近藤 亮祐   23  1996-06-07        183         74
# 7857    T. Kunimoto             邦本 宜裕   21  1997-10-08        174         70
# 7898    Y. Ideguchi            井手 口陽介   22  1996-08-23        171         71
# 7900     K. Itakura              板仓 晃   22  1997-01-27        186         75
# 7924       D. Maeda      Daizen Maeda   21  1997-10-20        173         67
# 8896       K. Osako             大迫 圭介   19  1999-07-28        186         86
# 10038       A. Ueda             上田 綺世   20  1998-08-28        180         72
# 12178   K. Nakamura             中村 敬斗   18  2000-07-28        180         75
# 14051  S. Appelkamp  Shinta Appelkamp   18  2000-11-01        175         61
# 14720      K. Arima            有馬 幸太郎   18  2000-09-03        181         71
# 15363   I. Sekigawa             関川 郁万   18  2000-09-13        182         72
# 15390   D. Matsuoka             松岡 大起   18  2001-06-01        170         65
#
#       nationality                        club  overall  potential  value_eur  \
# 614         Japan                    FC Porto       79         84   17000000
# 1739        Japan        FC Red Bull Salzburg       75         80    9000000
# 2141        Japan                FC Groningen       74         84    9000000
# 2662        Japan                     Bologna       73         84    6500000
# 2756        Japan         Eintracht Frankfurt       73         79    5500000
# 3428        Japan           Sint-Truidense VV       72         78    4300000
# 4212        Japan        FC Red Bull Salzburg       71         76    3200000
# 4245        Japan                   KAS Eupen       71         75    3100000
# 4757        Japan                 Real Madrid       70         87    3700000
# 4780        Japan                FC Barcelona       70         83    3400000
# 4959        Japan             Portimonense SC       70         76    2200000
# 5886        Japan              Nagoya Grampus       69         75    1300000
# 5887        Japan         Yokohama F. Marinos       69         75    1300000
# 5888        Japan             Kashima Antlers       69         75    1400000
# 5900        Japan           Kawasaki Frontale       69         75    1300000
# 6709        Japan  Hokkaido Consadole Sapporo       68         78    1500000
# 6756        Japan                Hamburger SV       68         77    1400000
# 6782        Japan         Yokohama F. Marinos       68         76    1300000
# 6838        Japan           Kawasaki Frontale       68         75    1300000
# 6843        Japan  Hokkaido Consadole Sapporo       68         75    1100000
# 7857        Japan                Gyeongnam FC       67         76    1200000
# 7898        Japan                 Gamba Osaka       67         75    1000000
# 7900        Japan                FC Groningen       67         75    1000000
# 7924        Japan        Clube Sport Marítimo       67         75    1100000
# 8896        Japan         Sanfrecce Hiroshima       66         76     800000
# 10038       Japan             Kashima Antlers       65         76     950000
# 12178       Japan                   FC Twente       63         81     750000
# 14051       Japan          Fortuna Düsseldorf       61         76     525000
# 14720       Japan             Kashima Antlers       60         76     425000
# 15363       Japan             Kashima Antlers       59         77     300000
# 15390       Japan                  Sagan Tosu       59         75     325000
#
#        wage_eur player_positions preferred_foot  international_reputation  \
# 614       15000           LM, CF          Right                         1
# 1739      29000      CAM, ST, LM          Right                         1
# 2141       8000          CAM, RM           Left                         1
# 2662      16000          CB, CDM          Right                         1
# 2756      25000          CF, CAM          Right                         1
# 3428       9000       ST, LM, RM          Right                         1
# 4212      19000       RM, ST, LM           Left                         1
# 4245       8000          ST, CAM          Right                         1
# 4757      21000           RM, CF           Left                         1
# 4780      44000           LM, RM          Right                         1
# 4959       4000       LB, RB, LW          Right                         1
# 5886       3000               CB          Right                         1
# 5887       3000          CDM, CM          Right                         1
# 5888       4000          CM, CDM          Right                         1
# 5900       4000          CDM, RB          Right                         1
# 6709       2000      LM, LWB, LB           Left                         1
# 6756       5000           LM, RM           Left                         1
# 6782       2000           LM, RM          Right                         1
# 6838       4000      CAM, CM, CF           Left                         1
# 6843       2000               CB          Right                         1
# 7857       2000       CM, LM, ST           Left                         1
# 7898       4000          CDM, CM          Right                         1
# 7900       3000          CB, CDM          Right                         1
# 7924       3000           CF, RM          Right                         1
# 8896       1000               GK          Right                         1
# 10038      2000               ST          Right                         1
# 12178      1000          LW, CAM          Right                         1
# 14051      2000              CAM          Right                         1
# 14720      1000       RM, ST, LM          Right                         1
# 15363      1000               CB          Right                         1
# 15390      1000      RM, CM, CAM          Right                         1
#
#        weak_foot  skill_moves      work_rate body_type real_face  \
# 614            4            4       High/Low    Normal       Yes
# 1739           4            3  Medium/Medium      Lean        No
# 2141           3            3  Medium/Medium    Normal        No
# 2662           5            2    Medium/High      Lean        No
# 2756           4            3    High/Medium      Lean       Yes
# 3428           3            3    High/Medium      Lean       Yes
# 4212           4            3  Medium/Medium      Lean        No
# 4245           3            3     Medium/Low      Lean        No
# 4757           4            4    High/Medium      Lean        No
# 4780           3            3    High/Medium      Lean        No
# 4959           5            3      High/High      Lean        No
# 5886           3            2    Medium/High    Normal        No
# 5887           3            2    Medium/High    Normal        No
# 5888           2            3  Medium/Medium    Normal        No
# 5900           2            2  Medium/Medium      Lean        No
# 6709           4            3    High/Medium    Stocky        No
# 6756           4            4  Medium/Medium      Lean       Yes
# 6782           4            3  Medium/Medium      Lean        No
# 6838           4            3    High/Medium      Lean        No
# 6843           3            2    Medium/High      Lean        No
# 7857           3            3  Medium/Medium    Normal        No
# 7898           3            3  Medium/Medium    Normal        No
# 7900           2            2  Medium/Medium      Lean        No
# 7924           3            3     Medium/Low    Normal        No
# 8896           2            1  Medium/Medium    Normal        No
# 10038          3            2     Medium/Low      Lean        No
# 12178          3            4    High/Medium      Lean        No
# 14051          3            3  Medium/Medium      Lean        No
# 14720          3            2  Medium/Medium      Lean        No
# 15363          2            2       Low/High    Normal        No
# 15390          3            3     Medium/Low      Lean        No
#
#        release_clause_eur           player_tags team_position  \
# 614            35300000.0  #Speedster, #Acrobat           SUB
# 1739           14200000.0                   NaN            RM
# 2141           14900000.0                   NaN           CAM
# 2662           12400000.0                   NaN           SUB
# 2756           10500000.0                   NaN            LF
# 3428            7100000.0                   NaN           SUB
# 4212            5000000.0              #Acrobat           SUB
# 4245            4900000.0                   NaN           LAM
# 4757            9800000.0                   NaN           RES
# 4780            9100000.0            #Speedster           RES
# 4959            5000000.0            #Speedster            RB
# 5886            1900000.0                   NaN           RCB
# 5887            1900000.0                   NaN           RDM
# 5888            2100000.0                   NaN           RDM
# 5900            2000000.0                   NaN           SUB
# 6709            2100000.0                   NaN            LM
# 6756            2500000.0              #Acrobat           SUB
# 6782            1900000.0                   NaN           SUB
# 6838            1900000.0            #Speedster           SUB
# 6843            1600000.0                   NaN           RCB
# 7857            1700000.0                   NaN            LM
# 7898            1500000.0                   NaN           SUB
# 7900            1700000.0                   NaN           LCB
# 7924                  NaN            #Speedster           SUB
# 8896            1200000.0                   NaN            GK
# 10038           1400000.0                   NaN           SUB
# 12178                 NaN                   NaN            LW
# 14051           1300000.0                   NaN           RES
# 14720            797000.0                   NaN           RES
# 15363            563000.0                   NaN           RES
# 15390            609000.0                   NaN           RCM
#
#        team_jersey_number       loaned_from      joined  contract_valid_until  \
# 614                  10.0               NaN  2019-07-05                2024.0
# 1739                 18.0               NaN  2015-01-07                2021.0
# 2141                  7.0               NaN  2018-04-23                2021.0
# 2662                 14.0               NaN  2019-07-09                2024.0
# 2756                 15.0               NaN  2017-07-17                2021.0
# 3428                  9.0               NaN  2019-07-16                2023.0
# 4212                 37.0               NaN  2015-07-01                2020.0
# 4245                 20.0               NaN  2018-01-19                2020.0
# 4757                 26.0               NaN  2019-07-01                2025.0
# 4780                 32.0               NaN  2019-07-15                2023.0
# 4959                 22.0               NaN  2019-07-17                2022.0
# 5886                 20.0               NaN  2018-07-01                2021.0
# 5887                  8.0               NaN  2013-01-01                2022.0
# 5888                 20.0               NaN  2016-01-12                2022.0
# 5900                  6.0               NaN  2018-01-01                2022.0
# 6709                  4.0               NaN  2017-01-01                2022.0
# 6756                 15.0               NaN  2017-09-20                2021.0
# 6782                 11.0               NaN  2016-01-01                2022.0
# 6838                 42.0               NaN  2015-01-01                2021.0
# 6843                  3.0               NaN  2015-01-01                2022.0
# 7857                 22.0               NaN  2018-01-05                2022.0
# 7898                 15.0               NaN  2019-08-05                2022.0
# 7900                 17.0               NaN  2019-01-15                2022.0
# 7924                 13.0  Matsumoto Yamaga         NaN                2020.0
# 8896                 38.0               NaN  2018-01-01                2019.0
# 10038                36.0               NaN  2019-07-26                2023.0
# 12178                13.0       Gamba Osaka         NaN                2021.0
# 14051                36.0               NaN  2019-07-01                2021.0
# 14720                34.0               NaN  2019-01-01                2022.0
# 15363                33.0               NaN  2019-01-01                2022.0
# 15390                41.0               NaN  2019-03-02                2022.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 614               NaN                   NaN  90.0      73.0     72.0
# 1739              NaN                   NaN  89.0      72.0     67.0
# 2141              NaN                   NaN  76.0      69.0     71.0
# 2662              NaN                   NaN  66.0      28.0     57.0
# 2756              NaN                   NaN  75.0      69.0     71.0
# 3428              NaN                   NaN  72.0      67.0     67.0
# 4212              NaN                   NaN  85.0      61.0     60.0
# 4245              NaN                   NaN  80.0      70.0     55.0
# 4757              NaN                   NaN  82.0      60.0     62.0
# 4780              NaN                   NaN  90.0      61.0     57.0
# 4959              NaN                   NaN  91.0      55.0     64.0
# 5886              NaN                   NaN  74.0      24.0     39.0
# 5887              NaN                   NaN  71.0      43.0     60.0
# 5888              NaN                   NaN  72.0      43.0     71.0
# 5900              NaN                   NaN  68.0      46.0     61.0
# 6709              NaN                   NaN  69.0      56.0     66.0
# 6756              NaN                   NaN  81.0      49.0     59.0
# 6782              NaN                   NaN  79.0      48.0     65.0
# 6838              NaN                   NaN  92.0      61.0     63.0
# 6843              NaN                   NaN  66.0      52.0     48.0
# 7857              NaN                   NaN  79.0      60.0     67.0
# 7898              NaN                   NaN  70.0      60.0     64.0
# 7900              NaN                   NaN  75.0      30.0     52.0
# 7924              NaN                   NaN  90.0      62.0     58.0
# 8896              NaN                   NaN   NaN       NaN      NaN
# 10038             NaN                   NaN  79.0      60.0     48.0
# 12178             NaN                   NaN  76.0      54.0     53.0
# 14051             NaN                   NaN  66.0      45.0     60.0
# 14720             NaN                   NaN  67.0      52.0     54.0
# 15363             NaN                   NaN  56.0      31.0     31.0
# 15390             NaN                   NaN  60.0      43.0     57.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 614         83.0       37.0    50.0        NaN          NaN         NaN
# 1739        80.0       41.0    65.0        NaN          NaN         NaN
# 2141        78.0       39.0    56.0        NaN          NaN         NaN
# 2662        63.0       72.0    76.0        NaN          NaN         NaN
# 2756        76.0       36.0    60.0        NaN          NaN         NaN
# 3428        68.0       45.0    80.0        NaN          NaN         NaN
# 4212        80.0       28.0    49.0        NaN          NaN         NaN
# 4245        70.0       22.0    50.0        NaN          NaN         NaN
# 4757        78.0       39.0    52.0        NaN          NaN         NaN
# 4780        78.0       33.0    59.0        NaN          NaN         NaN
# 4959        68.0       63.0    57.0        NaN          NaN         NaN
# 5886        45.0       68.0    73.0        NaN          NaN         NaN
# 5887        60.0       61.0    80.0        NaN          NaN         NaN
# 5888        71.0       66.0    75.0        NaN          NaN         NaN
# 5900        65.0       66.0    69.0        NaN          NaN         NaN
# 6709        68.0       58.0    66.0        NaN          NaN         NaN
# 6756        81.0       22.0    34.0        NaN          NaN         NaN
# 6782        68.0       47.0    68.0        NaN          NaN         NaN
# 6838        70.0       35.0    59.0        NaN          NaN         NaN
# 6843        45.0       67.0    74.0        NaN          NaN         NaN
# 7857        70.0       42.0    69.0        NaN          NaN         NaN
# 7898        66.0       63.0    67.0        NaN          NaN         NaN
# 7900        60.0       64.0    74.0        NaN          NaN         NaN
# 7924        69.0       30.0    61.0        NaN          NaN         NaN
# 8896         NaN        NaN     NaN       67.0         66.0        65.0
# 10038       62.0       26.0    61.0        NaN          NaN         NaN
# 12178       71.0       31.0    64.0        NaN          NaN         NaN
# 14051       68.0       35.0    39.0        NaN          NaN         NaN
# 14720       64.0       31.0    49.0        NaN          NaN         NaN
# 15363       42.0       58.0    65.0        NaN          NaN         NaN
# 15390       64.0       38.0    56.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 614            NaN       NaN             NaN
# 1739           NaN       NaN             NaN
# 2141           NaN       NaN             NaN
# 2662           NaN       NaN             NaN
# 2756           NaN       NaN             NaN
# 3428           NaN       NaN             NaN
# 4212           NaN       NaN             NaN
# 4245           NaN       NaN             NaN
# 4757           NaN       NaN             NaN
# 4780           NaN       NaN             NaN
# 4959           NaN       NaN             NaN
# 5886           NaN       NaN             NaN
# 5887           NaN       NaN             NaN
# 5888           NaN       NaN             NaN
# 5900           NaN       NaN             NaN
# 6709           NaN       NaN             NaN
# 6756           NaN       NaN             NaN
# 6782           NaN       NaN             NaN
# 6838           NaN       NaN             NaN
# 6843           NaN       NaN             NaN
# 7857           NaN       NaN             NaN
# 7898           NaN       NaN             NaN
# 7900           NaN       NaN             NaN
# 7924           NaN       NaN             NaN
# 8896          69.0      30.0            63.0
# 10038          NaN       NaN             NaN
# 12178          NaN       NaN             NaN
# 14051          NaN       NaN             NaN
# 14720          NaN       NaN             NaN
# 15363          NaN       NaN             NaN
# 15390          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 614    Beat Offside Trap, Selfish, Early Crosser, Cro...                  66
# 1739                                               Diver                  64
# 2141                               Argues with Officials                  70
# 2662                                                 NaN                  47
# 2756                       Finesse Shot, Crowd Favourite                  71
# 3428                           Long Passer (CPU AI Only)                  67
# 4212                            Selfish, Crowd Favourite                  60
# 4245                                                 NaN                  45
# 4757                                     Crowd Favourite                  55
# 4780                                                 NaN                  61
# 4959                                                 NaN                  70
# 5886                                        Injury Prone                  22
# 5887                                                 NaN                  53
# 5888                                                 NaN                  69
# 5900                                                 NaN                  53
# 6709                                                 NaN                  70
# 6756                              Selfish, Early Crosser                  65
# 6782                                                 NaN                  69
# 6838         Beat Offside Trap, Selfish, Crowd Favourite                  58
# 6843                                                 NaN                  34
# 7857                                                 NaN                  59
# 7898                                                 NaN                  63
# 7900                                                 NaN                  30
# 7924                                                 NaN                  58
# 8896                                                 NaN                  14
# 10038                                                NaN                  38
# 12178      Speed Dribbler (CPU AI Only), Crowd Favourite                  49
# 14051                                                NaN                  58
# 14720                                                NaN                  55
# 15363                                                NaN                  15
# 15390                                                NaN                  55
#
#        attacking_finishing  attacking_heading_accuracy  \
# 614                     72                          40
# 1739                    75                          51
# 2141                    66                          45
# 2662                    27                          70
# 2756                    75                          53
# 3428                    70                          82
# 4212                    61                          49
# 4245                    73                          71
# 4757                    64                          39
# 4780                    62                          56
# 4959                    58                          47
# 5886                    18                          73
# 5887                    39                          49
# 5888                    40                          56
# 5900                    37                          47
# 6709                    58                          54
# 6756                    45                          27
# 6782                    45                          48
# 6838                    61                          37
# 6843                    60                          72
# 7857                    58                          46
# 7898                    62                          43
# 7900                    16                          67
# 7924                    65                          56
# 8896                     7                          10
# 10038                   66                          63
# 12178                   59                          43
# 14051                   49                          31
# 14720                   60                          40
# 15363                   26                          61
# 15390                   43                          38
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 614                         75                 76               83
# 1739                        71                 66               80
# 2141                        72                 59               75
# 2662                        68                 22               60
# 2756                        73                 38               77
# 3428                        73                 67               68
# 4212                        64                 56               80
# 4245                        66                 70               66
# 4757                        67                 57               79
# 4780                        62                 64               81
# 4959                        64                 41               68
# 5886                        57                 47               31
# 5887                        70                 31               48
# 5888                        76                 40               69
# 5900                        73                 24               62
# 6709                        69                 58               68
# 6756                        60                 55               82
# 6782                        69                 37               67
# 6838                        65                 61               68
# 6843                        63                 38               40
# 7857                        72                 58               71
# 7898                        68                 33               66
# 7900                        66                 24               55
# 7924                        63                 58               65
# 8896                        18                  7               12
# 10038                       59                 42               60
# 12178                       54                 47               74
# 14051                       64                 46               67
# 14720                       60                 45               70
# 15363                       49                 22               32
# 15390                       64                 44               64
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 614             79                 64                  68                  78
# 1739            67                 65                  64                  78
# 2141            67                 67                  68                  78
# 2662            43                 35                  65                  67
# 2756            67                 66                  65                  77
# 3428            47                 40                  64                  68
# 4212            57                 39                  51                  76
# 4245            69                 72                  28                  67
# 4757            68                 72                  54                  78
# 4780            53                 32                  42                  73
# 4959            69                 57                  68                  68
# 5886            22                 23                  34                  56
# 5887            33                 45                  64                  70
# 5888            58                 44                  72                  75
# 5900            29                 38                  64                  69
# 6709            65                 56                  63                  67
# 6756            67                 44                  43                  75
# 6782            68                 44                  63                  71
# 6838            67                 50                  59                  67
# 6843            27                 28                  51                  39
# 7857            55                 50                  70                  70
# 7898            37                 55                  66                  67
# 7900            30                 40                  64                  65
# 7924            64                 57                  49                  70
# 8896            10                 10                  19                  20
# 10038           42                 22                  38                  63
# 12178           69                 69                  46                  67
# 14051           55                 42                  62                  66
# 14720           45                 45                  52                  62
# 15363           18                 26                  34                  51
# 15390           46                 44                  54                  60
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 614                       93                     87                94
# 1739                      90                     88                87
# 2141                      78                     74                86
# 2662                      67                     66                65
# 2756                      76                     74                77
# 3428                      72                     72                69
# 4212                      87                     84                90
# 4245                      85                     76                89
# 4757                      89                     77                83
# 4780                      91                     90                81
# 4959                      92                     90                69
# 5886                      71                     76                70
# 5887                      70                     72                78
# 5888                      70                     74                67
# 5900                      71                     66                68
# 6709                      67                     71                67
# 6756                      93                     72                95
# 6782                      79                     79                64
# 6838                      94                     91                85
# 6843                      64                     67                69
# 7857                      83                     76                69
# 7898                      66                     74                64
# 7900                      74                     76                68
# 7924                      91                     90                88
# 8896                      28                     32                27
# 10038                     80                     79                70
# 12178                     75                     76                72
# 14051                     69                     64                77
# 14720                     64                     69                57
# 15363                     57                     56                54
# 15390                     63                     58                76
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 614                    83                94                76             70
# 1739                   73                82                71             76
# 2141                   70                93                76             41
# 2662                   62                58                37             69
# 2756                   70                72                69             68
# 3428                   64                66                69             87
# 4212                   64                90                63             48
# 4245                   72                84                69             89
# 4757                   61                83                61             54
# 4780                   57                84                66             68
# 4959                   64                78                58             73
# 5886                   64                50                35             78
# 5887                   62                86                47             85
# 5888                   69                70                59             69
# 5900                   67                68                63             62
# 6709                   65                74                61             61
# 6756                   72                96                62             47
# 6782                   62                75                58             80
# 6838                   68                84                66             89
# 6843                   66                67                48             77
# 7857                   58                71                67             70
# 7898                   63                75                58             71
# 7900                   65                49                64             82
# 7924                   66                72                63             72
# 8896                   59                38                49             42
# 10038                  52                71                55             72
# 12178                  61                63                55             63
# 14051                  51                79                37             61
# 14720                  40                63                36             35
# 15363                  45                53                46             73
# 15390                  56                80                47             72
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 614               75              33                71                    55
# 1739              83              57                70                    61
# 2141              75              54                74                    41
# 2662              68              81                24                    74
# 2756              70              59                62                    48
# 3428              83              82                57                    68
# 4212              68              47                62                    31
# 4245              71              42                67                    33
# 4757              72              45                52                    43
# 4780              74              60                55                    33
# 4959              82              43                51                    56
# 5886              72              80                19                    54
# 5887              93              72                50                    84
# 5888              73              79                36                    68
# 5900              69              71                50                    68
# 6709              81              68                54                    44
# 6756              52              28                46                    21
# 6782              71              69                44                    58
# 6838              71              57                59                    43
# 6843              75              72                42                    76
# 7857              65              75                58                    57
# 7898              83              62                67                    58
# 7900              84              72                24                    64
# 7924              80              56                54                    45
# 8896              22              68                 7                    19
# 10038             70              58                55                    53
# 12178             70              71                43                    41
# 14051             51              31                41                    36
# 14720             56              50                51                    41
# 15363             59              70                32                    58
# 15390             62              58                38                    41
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 614                         43                     75                77
# 1739                        49                     73                65
# 2141                        41                     61                76
# 2662                        69                     23                51
# 2756                        28                     74                72
# 3428                        38                     71                69
# 4212                        16                     65                66
# 4245                        16                     75                59
# 4757                        29                     62                60
# 4780                        17                     62                65
# 4959                        60                     53                57
# 5886                        67                     21                36
# 5887                        66                     46                58
# 5888                        63                     45                71
# 5900                        66                     62                57
# 6709                        55                     58                63
# 6756                        25                     55                66
# 6782                        36                     66                58
# 6838                        26                     50                69
# 6843                        67                     59                42
# 7857                        47                     59                70
# 7898                        67                     57                65
# 7900                        68                     41                50
# 7924                        31                     64                57
# 8896                         8                      7                38
# 10038                       20                     75                54
# 12178                       31                     55                54
# 14051                       35                     54                59
# 14720                       18                     57                48
# 15363                       48                     23                20
# 15390                       34                     50                57
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 614                     67                   81                 28
# 1739                    59                   62                 35
# 2141                    58                   72                 39
# 2662                    37                   59                 72
# 2756                    71                   80                 30
# 3428                    68                   68                 40
# 4212                    53                   58                 28
# 4245                    56                   72                 19
# 4757                    61                   64                 40
# 4780                    58                   62                 51
# 4959                    48                   59                 69
# 5886                    37                   58                 64
# 5887                    42                   65                 61
# 5888                    42                   64                 67
# 5900                    45                   61                 67
# 6709                    30                   64                 63
# 6756                    41                   60                 17
# 6782                    46                   51                 40
# 6838                    56                   57                 38
# 6843                    35                   58                 66
# 7857                    63                   66                 28
# 7898                    44                   57                 66
# 7900                    38                   62                 62
# 7924                    60                   65                 28
# 8896                    15                   45                 12
# 10038                   55                   55                 22
# 12178                   54                   64                 21
# 14051                   46                   57                 37
# 14720                   40                   50                 25
# 15363                   31                   39                 56
# 15390                   42                   57                 40
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 614                           41                        36
# 1739                          39                        34
# 2141                          36                        42
# 2662                          75                        74
# 2756                          42                        34
# 3428                          48                        25
# 4212                          29                        24
# 4245                          13                        19
# 4757                          43                        48
# 4780                          25                        15
# 4959                          65                        62
# 5886                          70                        67
# 5887                          62                        58
# 5888                          70                        65
# 5900                          71                        63
# 6709                          58                        48
# 6756                          24                        22
# 6782                          59                        51
# 6838                          35                        44
# 6843                          69                        61
# 7857                          49                        46
# 7898                          64                        61
# 7900                          65                        58
# 7924                          24                        21
# 8896                          14                        11
# 10038                         22                        22
# 12178                         36                        30
# 14051                         32                        37
# 14720                         41                        34
# 15363                         64                        58
# 15390                         38                        35
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 614                     7                    10                   10
# 1739                    9                    12                    8
# 2141                    8                     5                    6
# 2662                    9                    14                    6
# 2756                    6                    10                   11
# 3428                   14                     5                    8
# 4212                    6                     8                   14
# 4245                   13                     7                    8
# 4757                    6                     7                   15
# 4780                   12                    12                    9
# 4959                    7                     8                   14
# 5886                    7                     9                   13
# 5887                    9                     7                    5
# 5888                   14                     6                   13
# 5900                    6                    10                   13
# 6709                    8                     6                   10
# 6756                   10                    13                    5
# 6782                   15                     9                    9
# 6838                    8                     9                   15
# 6843                    6                    13                   11
# 7857                    6                    12                   11
# 7898                   13                    12                    8
# 7900                   13                     6                    9
# 7924                    5                     9                    5
# 8896                   67                    66                   65
# 10038                   7                    12                   14
# 12178                   7                    13                   15
# 14051                  10                     9                   11
# 14720                  10                    14                    7
# 15363                   7                    13                   13
# 15390                   7                    10                   14
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 614                          8                     6  71+2  71+2  71+2  78+2
# 1739                        15                    14  72+2  72+2  72+2  75+2
# 2141                        13                    14  67+2  67+2  67+2  72+2
# 2662                         5                    11  49+2  49+2  49+2  53+2
# 2756                         6                    11  69+2  69+2  69+2  73+2
# 3428                         8                     8  70+2  70+2  70+2  68+2
# 4212                        13                    13  65+2  65+2  65+2  71+2
# 4245                         9                     6  69+2  69+2  69+2  68+2
# 4757                        10                    10  63+2  63+2  63+2  69+2
# 4780                         8                     7  66+2  66+2  66+2  70+2
# 4959                        12                    10  60+2  60+2  60+2  66+2
# 5886                        14                    13  44+2  44+2  44+2  42+2
# 5887                        14                     9  53+2  53+2  53+2  57+2
# 5888                        10                    11  58+2  58+2  58+2  64+2
# 5900                         7                     8  57+2  57+2  57+2  61+2
# 6709                         5                     7  61+2  61+2  61+2  65+2
# 6756                        12                    13  57+2  57+2  57+2  68+2
# 6782                        11                    13  60+2  60+2  60+2  65+2
# 6838                         7                    10  62+2  62+2  62+2  67+2
# 6843                         6                     7  57+2  57+2  57+2  51+2
# 7857                         9                     8  63+2  63+2  63+2  67+2
# 7898                        10                    13  60+2  60+2  60+2  65+2
# 7900                        10                    12  51+2  51+2  51+2  52+2
# 7924                         9                    12  65+2  65+2  65+2  67+2
# 8896                        63                    69   NaN   NaN   NaN   NaN
# 10038                       15                     6  63+2  63+2  63+2  62+2
# 12178                        8                     7  59+2  59+2  59+2  62+2
# 14051                       12                    10  50+2  50+2  50+2  60+2
# 14720                        5                     6  54+2  54+2  54+2  59+2
# 15363                       11                     7  41+2  41+2  41+2  37+2
# 15390                       10                    13  51+2  51+2  51+2  57+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 614    77+2  77+2  77+2  78+2  78+2  78+2  78+2  77+2  72+2  72+2  72+2  77+2
# 1739   75+2  75+2  75+2  75+2  74+2  74+2  74+2  75+2  69+2  69+2  69+2  75+2
# 2141   71+2  71+2  71+2  72+2  72+2  72+2  72+2  72+2  69+2  69+2  69+2  72+2
# 2662   51+2  51+2  51+2  53+2  54+2  54+2  54+2  56+2  59+2  59+2  59+2  56+2
# 2756   73+2  73+2  73+2  73+2  73+2  73+2  73+2  73+2  68+2  68+2  68+2  73+2
# 3428   69+2  69+2  69+2  68+2  68+2  68+2  68+2  69+2  66+2  66+2  66+2  69+2
# 4212   69+2  69+2  69+2  71+2  69+2  69+2  69+2  69+2  61+2  61+2  61+2  69+2
# 4245   69+2  69+2  69+2  68+2  67+2  67+2  67+2  65+2  56+2  56+2  56+2  65+2
# 4757   68+2  68+2  68+2  69+2  68+2  68+2  68+2  69+2  62+2  62+2  62+2  69+2
# 4780   68+2  68+2  68+2  70+2  67+2  67+2  67+2  69+2  58+2  58+2  58+2  69+2
# 4959   64+2  64+2  64+2  66+2  64+2  64+2  64+2  68+2  64+2  64+2  64+2  68+2
# 5886   42+2  42+2  42+2  42+2  43+2  43+2  43+2  44+2  47+2  47+2  47+2  44+2
# 5887   56+2  56+2  56+2  57+2  59+2  59+2  59+2  60+2  63+2  63+2  63+2  60+2
# 5888   62+2  62+2  62+2  64+2  65+2  65+2  65+2  67+2  68+2  68+2  68+2  67+2
# 5900   61+2  61+2  61+2  61+2  62+2  62+2  62+2  63+2  64+2  64+2  64+2  63+2
# 6709   63+2  63+2  63+2  65+2  64+2  64+2  64+2  66+2  64+2  64+2  64+2  66+2
# 6756   65+2  65+2  65+2  68+2  66+2  66+2  66+2  67+2  57+2  57+2  57+2  67+2
# 6782   63+2  63+2  63+2  65+2  64+2  64+2  64+2  67+2  62+2  62+2  62+2  67+2
# 6838   65+2  65+2  65+2  67+2  66+2  66+2  66+2  67+2  61+2  61+2  61+2  67+2
# 6843   52+2  52+2  52+2  51+2  51+2  51+2  51+2  52+2  54+2  54+2  54+2  52+2
# 7857   66+2  66+2  66+2  67+2  67+2  67+2  67+2  67+2  65+2  65+2  65+2  67+2
# 7898   63+2  63+2  63+2  65+2  65+2  65+2  65+2  66+2  66+2  66+2  66+2  66+2
# 7900   53+2  53+2  53+2  52+2  54+2  54+2  54+2  56+2  59+2  59+2  59+2  56+2
# 7924   66+2  66+2  66+2  67+2  65+2  65+2  65+2  67+2  58+2  58+2  58+2  67+2
# 8896    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10038  63+2  63+2  63+2  62+2  61+2  61+2  61+2  60+2  53+2  53+2  53+2  60+2
# 12178  61+2  61+2  61+2  62+2  60+2  60+2  60+2  62+2  55+2  55+2  55+2  62+2
# 14051  57+2  57+2  57+2  60+2  60+2  60+2  60+2  60+2  56+2  56+2  56+2  60+2
# 14720  57+2  57+2  57+2  59+2  57+2  57+2  57+2  59+2  52+2  52+2  52+2  59+2
# 15363  38+2  38+2  38+2  37+2  38+2  38+2  38+2  38+2  40+2  40+2  40+2  38+2
# 15390  55+2  55+2  55+2  57+2  57+2  57+2  57+2  58+2  55+2  55+2  55+2  58+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 614    62+2  57+2  57+2  57+2  62+2  58+2  46+2  46+2  46+2  58+2
# 1739   62+2  58+2  58+2  58+2  62+2  59+2  50+2  50+2  50+2  59+2
# 2141   60+2  57+2  57+2  57+2  60+2  57+2  46+2  46+2  46+2  57+2
# 2662   66+2  68+2  68+2  68+2  66+2  67+2  72+2  72+2  72+2  67+2
# 2756   57+2  54+2  54+2  54+2  57+2  54+2  46+2  46+2  46+2  54+2
# 3428   58+2  58+2  58+2  58+2  58+2  56+2  55+2  55+2  55+2  56+2
# 4212   52+2  45+2  45+2  45+2  52+2  48+2  37+2  37+2  37+2  48+2
# 4245   47+2  40+2  40+2  40+2  47+2  44+2  36+2  36+2  36+2  44+2
# 4757   57+2  52+2  52+2  52+2  57+2  55+2  45+2  45+2  45+2  55+2
# 4780   52+2  45+2  45+2  45+2  52+2  49+2  41+2  41+2  41+2  49+2
# 4959   69+2  64+2  64+2  64+2  69+2  68+2  60+2  60+2  60+2  68+2
# 5886   59+2  60+2  60+2  60+2  59+2  62+2  67+2  67+2  67+2  62+2
# 5887   65+2  67+2  67+2  67+2  65+2  65+2  64+2  64+2  64+2  65+2
# 5888   69+2  70+2  70+2  70+2  69+2  68+2  68+2  68+2  68+2  68+2
# 5900   65+2  67+2  67+2  67+2  65+2  65+2  65+2  65+2  65+2  65+2
# 6709   64+2  62+2  62+2  62+2  64+2  62+2  58+2  58+2  58+2  62+2
# 6756   50+2  42+2  42+2  42+2  50+2  46+2  31+2  31+2  31+2  46+2
# 6782   60+2  57+2  57+2  57+2  60+2  59+2  54+2  54+2  54+2  59+2
# 6838   56+2  51+2  51+2  51+2  56+2  54+2  45+2  45+2  45+2  54+2
# 6843   59+2  61+2  61+2  61+2  59+2  61+2  67+2  67+2  67+2  61+2
# 7857   58+2  57+2  57+2  57+2  58+2  56+2  51+2  51+2  51+2  56+2
# 7898   67+2  66+2  66+2  66+2  67+2  65+2  62+2  62+2  62+2  65+2
# 7900   62+2  65+2  65+2  65+2  62+2  63+2  65+2  65+2  65+2  63+2
# 7924   53+2  47+2  47+2  47+2  53+2  50+2  41+2  41+2  41+2  50+2
# 8896    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10038  45+2  41+2  41+2  41+2  45+2  43+2  39+2  39+2  39+2  43+2
# 12178  50+2  46+2  46+2  46+2  50+2  47+2  42+2  42+2  42+2  47+2
# 14051  50+2  47+2  47+2  47+2  50+2  47+2  39+2  39+2  39+2  47+2
# 14720  46+2  43+2  43+2  43+2  46+2  44+2  37+2  37+2  37+2  44+2
# 15363  48+2  50+2  50+2  50+2  48+2  51+2  57+2  57+2  57+2  51+2
# 15390  50+2  49+2  49+2  49+2  50+2  48+2  44+2  44+2  44+2  48+2

# %%
df.query('age <= 24 & 80 <= potential').query("nationality == 'Japan'")
# Out:
#        sofifa_id                                         player_url  \
# 614       232862  https://sofifa.com/player/232862/shoya-nakajim...
# 1739      226627  https://sofifa.com/player/226627/takumi-minami...
# 2141      232639  https://sofifa.com/player/232639/ritsu-doan/20...
# 2662      232938  https://sofifa.com/player/232938/takehiro-tomi...
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 4780      237823  https://sofifa.com/player/237823/hiroki-abe/20...
# 12178     242914  https://sofifa.com/player/242914/keito-nakamur...
#
#         short_name long_name  age         dob  height_cm  weight_kg  \
# 614    S. Nakajima     中島 翔哉   24  1994-08-23        164         64
# 1739   T. Minamino     南野 拓実   24  1995-01-16        174         67
# 2141       R. Doan      堂安 律   21  1998-06-16        172         70
# 2662   T. Tomiyasu     冨安 健洋   20  1998-11-05        188         84
# 4757       T. Kubo     久保 建英   18  2001-06-04        173         67
# 4780        H. Abe     安部 裕葵   20  1999-01-28        171         65
# 12178  K. Nakamura     中村 敬斗   18  2000-07-28        180         75
#
#       nationality                  club  overall  potential  value_eur  \
# 614         Japan              FC Porto       79         84   17000000
# 1739        Japan  FC Red Bull Salzburg       75         80    9000000
# 2141        Japan          FC Groningen       74         84    9000000
# 2662        Japan               Bologna       73         84    6500000
# 4757        Japan           Real Madrid       70         87    3700000
# 4780        Japan          FC Barcelona       70         83    3400000
# 12178       Japan             FC Twente       63         81     750000
#
#        wage_eur player_positions preferred_foot  international_reputation  \
# 614       15000           LM, CF          Right                         1
# 1739      29000      CAM, ST, LM          Right                         1
# 2141       8000          CAM, RM           Left                         1
# 2662      16000          CB, CDM          Right                         1
# 4757      21000           RM, CF           Left                         1
# 4780      44000           LM, RM          Right                         1
# 12178      1000          LW, CAM          Right                         1
#
#        weak_foot  skill_moves      work_rate body_type real_face  \
# 614            4            4       High/Low    Normal       Yes
# 1739           4            3  Medium/Medium      Lean        No
# 2141           3            3  Medium/Medium    Normal        No
# 2662           5            2    Medium/High      Lean        No
# 4757           4            4    High/Medium      Lean        No
# 4780           3            3    High/Medium      Lean        No
# 12178          3            4    High/Medium      Lean        No
#
#        release_clause_eur           player_tags team_position  \
# 614            35300000.0  #Speedster, #Acrobat           SUB
# 1739           14200000.0                   NaN            RM
# 2141           14900000.0                   NaN           CAM
# 2662           12400000.0                   NaN           SUB
# 4757            9800000.0                   NaN           RES
# 4780            9100000.0            #Speedster           RES
# 12178                 NaN                   NaN            LW
#
#        team_jersey_number  loaned_from      joined  contract_valid_until  \
# 614                  10.0          NaN  2019-07-05                2024.0
# 1739                 18.0          NaN  2015-01-07                2021.0
# 2141                  7.0          NaN  2018-04-23                2021.0
# 2662                 14.0          NaN  2019-07-09                2024.0
# 4757                 26.0          NaN  2019-07-01                2025.0
# 4780                 32.0          NaN  2019-07-15                2023.0
# 12178                13.0  Gamba Osaka         NaN                2021.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 614               NaN                   NaN  90.0      73.0     72.0
# 1739              NaN                   NaN  89.0      72.0     67.0
# 2141              NaN                   NaN  76.0      69.0     71.0
# 2662              NaN                   NaN  66.0      28.0     57.0
# 4757              NaN                   NaN  82.0      60.0     62.0
# 4780              NaN                   NaN  90.0      61.0     57.0
# 12178             NaN                   NaN  76.0      54.0     53.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 614         83.0       37.0    50.0        NaN          NaN         NaN
# 1739        80.0       41.0    65.0        NaN          NaN         NaN
# 2141        78.0       39.0    56.0        NaN          NaN         NaN
# 2662        63.0       72.0    76.0        NaN          NaN         NaN
# 4757        78.0       39.0    52.0        NaN          NaN         NaN
# 4780        78.0       33.0    59.0        NaN          NaN         NaN
# 12178       71.0       31.0    64.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 614            NaN       NaN             NaN
# 1739           NaN       NaN             NaN
# 2141           NaN       NaN             NaN
# 2662           NaN       NaN             NaN
# 4757           NaN       NaN             NaN
# 4780           NaN       NaN             NaN
# 12178          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 614    Beat Offside Trap, Selfish, Early Crosser, Cro...                  66
# 1739                                               Diver                  64
# 2141                               Argues with Officials                  70
# 2662                                                 NaN                  47
# 4757                                     Crowd Favourite                  55
# 4780                                                 NaN                  61
# 12178      Speed Dribbler (CPU AI Only), Crowd Favourite                  49
#
#        attacking_finishing  attacking_heading_accuracy  \
# 614                     72                          40
# 1739                    75                          51
# 2141                    66                          45
# 2662                    27                          70
# 4757                    64                          39
# 4780                    62                          56
# 12178                   59                          43
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 614                         75                 76               83
# 1739                        71                 66               80
# 2141                        72                 59               75
# 2662                        68                 22               60
# 4757                        67                 57               79
# 4780                        62                 64               81
# 12178                       54                 47               74
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 614             79                 64                  68                  78
# 1739            67                 65                  64                  78
# 2141            67                 67                  68                  78
# 2662            43                 35                  65                  67
# 4757            68                 72                  54                  78
# 4780            53                 32                  42                  73
# 12178           69                 69                  46                  67
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 614                       93                     87                94
# 1739                      90                     88                87
# 2141                      78                     74                86
# 2662                      67                     66                65
# 4757                      89                     77                83
# 4780                      91                     90                81
# 12178                     75                     76                72
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 614                    83                94                76             70
# 1739                   73                82                71             76
# 2141                   70                93                76             41
# 2662                   62                58                37             69
# 4757                   61                83                61             54
# 4780                   57                84                66             68
# 12178                  61                63                55             63
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 614               75              33                71                    55
# 1739              83              57                70                    61
# 2141              75              54                74                    41
# 2662              68              81                24                    74
# 4757              72              45                52                    43
# 4780              74              60                55                    33
# 12178             70              71                43                    41
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 614                         43                     75                77
# 1739                        49                     73                65
# 2141                        41                     61                76
# 2662                        69                     23                51
# 4757                        29                     62                60
# 4780                        17                     62                65
# 12178                       31                     55                54
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 614                     67                   81                 28
# 1739                    59                   62                 35
# 2141                    58                   72                 39
# 2662                    37                   59                 72
# 4757                    61                   64                 40
# 4780                    58                   62                 51
# 12178                   54                   64                 21
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 614                           41                        36
# 1739                          39                        34
# 2141                          36                        42
# 2662                          75                        74
# 4757                          43                        48
# 4780                          25                        15
# 12178                         36                        30
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 614                     7                    10                   10
# 1739                    9                    12                    8
# 2141                    8                     5                    6
# 2662                    9                    14                    6
# 4757                    6                     7                   15
# 4780                   12                    12                    9
# 12178                   7                    13                   15
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 614                          8                     6  71+2  71+2  71+2  78+2
# 1739                        15                    14  72+2  72+2  72+2  75+2
# 2141                        13                    14  67+2  67+2  67+2  72+2
# 2662                         5                    11  49+2  49+2  49+2  53+2
# 4757                        10                    10  63+2  63+2  63+2  69+2
# 4780                         8                     7  66+2  66+2  66+2  70+2
# 12178                        8                     7  59+2  59+2  59+2  62+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 614    77+2  77+2  77+2  78+2  78+2  78+2  78+2  77+2  72+2  72+2  72+2  77+2
# 1739   75+2  75+2  75+2  75+2  74+2  74+2  74+2  75+2  69+2  69+2  69+2  75+2
# 2141   71+2  71+2  71+2  72+2  72+2  72+2  72+2  72+2  69+2  69+2  69+2  72+2
# 2662   51+2  51+2  51+2  53+2  54+2  54+2  54+2  56+2  59+2  59+2  59+2  56+2
# 4757   68+2  68+2  68+2  69+2  68+2  68+2  68+2  69+2  62+2  62+2  62+2  69+2
# 4780   68+2  68+2  68+2  70+2  67+2  67+2  67+2  69+2  58+2  58+2  58+2  69+2
# 12178  61+2  61+2  61+2  62+2  60+2  60+2  60+2  62+2  55+2  55+2  55+2  62+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 614    62+2  57+2  57+2  57+2  62+2  58+2  46+2  46+2  46+2  58+2
# 1739   62+2  58+2  58+2  58+2  62+2  59+2  50+2  50+2  50+2  59+2
# 2141   60+2  57+2  57+2  57+2  60+2  57+2  46+2  46+2  46+2  57+2
# 2662   66+2  68+2  68+2  68+2  66+2  67+2  72+2  72+2  72+2  67+2
# 4757   57+2  52+2  52+2  52+2  57+2  55+2  45+2  45+2  45+2  55+2
# 4780   52+2  45+2  45+2  45+2  52+2  49+2  41+2  41+2  41+2  49+2
# 12178  50+2  46+2  46+2  46+2  50+2  47+2  42+2  42+2  42+2  47+2

# %%
df.query('age <= 23 & 75 <= potential').query("nationality == 'Japan'")
# Out:
#        sofifa_id                                         player_url  \
# 2141      232639  https://sofifa.com/player/232639/ritsu-doan/20...
# 2662      232938  https://sofifa.com/player/232938/takehiro-tomi...
# 2756      232730  https://sofifa.com/player/232730/daichi-kamada...
# 3428      233250  https://sofifa.com/player/233250/yuma-suzuki/2...
# 4212      239712  https://sofifa.com/player/239712/masaya-okugaw...
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 4780      237823  https://sofifa.com/player/237823/hiroki-abe/20...
# 5886      232571  https://sofifa.com/player/232571/shinnosuke-na...
# 5888      232882  https://sofifa.com/player/232882/kento-misao/2...
# 6709      237749  https://sofifa.com/player/237749/daiki-suga/20...
# 6756      241240  https://sofifa.com/player/241240/tatsuya-ito/2...
# 6782      232786  https://sofifa.com/player/232786/keita-endo/20...
# 6838      233151  https://sofifa.com/player/233151/koji-miyoshi/...
# 6843      237739  https://sofifa.com/player/237739/ryosuke-shind...
# 7857      232985  https://sofifa.com/player/232985/takahiro-kuni...
# 7898      232623  https://sofifa.com/player/232623/yosuke-ideguc...
# 7900      233152  https://sofifa.com/player/233152/ko-itakura/20...
# 7924      246321  https://sofifa.com/player/246321/daizen-maeda/...
# 8896      244654  https://sofifa.com/player/244654/keisuke-osako...
# 10038     252162  https://sofifa.com/player/252162/ayase-ueda/20...
# 12178     242914  https://sofifa.com/player/242914/keito-nakamur...
# 14051     252903  https://sofifa.com/player/252903/shinta-appelk...
# 14720     246854  https://sofifa.com/player/246854/kotaro-arima/...
# 15363     246852  https://sofifa.com/player/246852/ikuma-sekigaw...
# 15390     247730  https://sofifa.com/player/247730/daiki-matsuok...
#
#          short_name         long_name  age         dob  height_cm  weight_kg  \
# 2141        R. Doan              堂安 律   21  1998-06-16        172         70
# 2662    T. Tomiyasu             冨安 健洋   20  1998-11-05        188         84
# 2756      D. Kamada             鎌田 大地   22  1996-08-05        184         73
# 3428      Y. Suzuki             鈴木 優磨   23  1996-04-26        182         75
# 4212     M. Okugawa             奥川 雅也   23  1996-04-14        176         62
# 4757        T. Kubo             久保 建英   18  2001-06-04        173         67
# 4780         H. Abe             安部 裕葵   20  1999-01-28        171         65
# 5886    S. Nakatani            中谷 进之介   23  1996-03-24        184         79
# 5888       K. Misao             三竿 健斗   23  1996-04-16        181         73
# 6709        D. Suga              菅 大輝   20  1998-09-10        171         69
# 6756         T. Itō             伊藤 達哉   22  1997-06-26        163         59
# 6782        K. Endo             遠藤 渓太   21  1997-11-22        175         66
# 6838     K. Miyoshi             三好 康児   22  1997-03-26        167         64
# 6843      R. Shindo             近藤 亮祐   23  1996-06-07        183         74
# 7857    T. Kunimoto             邦本 宜裕   21  1997-10-08        174         70
# 7898    Y. Ideguchi            井手 口陽介   22  1996-08-23        171         71
# 7900     K. Itakura              板仓 晃   22  1997-01-27        186         75
# 7924       D. Maeda      Daizen Maeda   21  1997-10-20        173         67
# 8896       K. Osako             大迫 圭介   19  1999-07-28        186         86
# 10038       A. Ueda             上田 綺世   20  1998-08-28        180         72
# 12178   K. Nakamura             中村 敬斗   18  2000-07-28        180         75
# 14051  S. Appelkamp  Shinta Appelkamp   18  2000-11-01        175         61
# 14720      K. Arima            有馬 幸太郎   18  2000-09-03        181         71
# 15363   I. Sekigawa             関川 郁万   18  2000-09-13        182         72
# 15390   D. Matsuoka             松岡 大起   18  2001-06-01        170         65
#
#       nationality                        club  overall  potential  value_eur  \
# 2141        Japan                FC Groningen       74         84    9000000
# 2662        Japan                     Bologna       73         84    6500000
# 2756        Japan         Eintracht Frankfurt       73         79    5500000
# 3428        Japan           Sint-Truidense VV       72         78    4300000
# 4212        Japan        FC Red Bull Salzburg       71         76    3200000
# 4757        Japan                 Real Madrid       70         87    3700000
# 4780        Japan                FC Barcelona       70         83    3400000
# 5886        Japan              Nagoya Grampus       69         75    1300000
# 5888        Japan             Kashima Antlers       69         75    1400000
# 6709        Japan  Hokkaido Consadole Sapporo       68         78    1500000
# 6756        Japan                Hamburger SV       68         77    1400000
# 6782        Japan         Yokohama F. Marinos       68         76    1300000
# 6838        Japan           Kawasaki Frontale       68         75    1300000
# 6843        Japan  Hokkaido Consadole Sapporo       68         75    1100000
# 7857        Japan                Gyeongnam FC       67         76    1200000
# 7898        Japan                 Gamba Osaka       67         75    1000000
# 7900        Japan                FC Groningen       67         75    1000000
# 7924        Japan        Clube Sport Marítimo       67         75    1100000
# 8896        Japan         Sanfrecce Hiroshima       66         76     800000
# 10038       Japan             Kashima Antlers       65         76     950000
# 12178       Japan                   FC Twente       63         81     750000
# 14051       Japan          Fortuna Düsseldorf       61         76     525000
# 14720       Japan             Kashima Antlers       60         76     425000
# 15363       Japan             Kashima Antlers       59         77     300000
# 15390       Japan                  Sagan Tosu       59         75     325000
#
#        wage_eur player_positions preferred_foot  international_reputation  \
# 2141       8000          CAM, RM           Left                         1
# 2662      16000          CB, CDM          Right                         1
# 2756      25000          CF, CAM          Right                         1
# 3428       9000       ST, LM, RM          Right                         1
# 4212      19000       RM, ST, LM           Left                         1
# 4757      21000           RM, CF           Left                         1
# 4780      44000           LM, RM          Right                         1
# 5886       3000               CB          Right                         1
# 5888       4000          CM, CDM          Right                         1
# 6709       2000      LM, LWB, LB           Left                         1
# 6756       5000           LM, RM           Left                         1
# 6782       2000           LM, RM          Right                         1
# 6838       4000      CAM, CM, CF           Left                         1
# 6843       2000               CB          Right                         1
# 7857       2000       CM, LM, ST           Left                         1
# 7898       4000          CDM, CM          Right                         1
# 7900       3000          CB, CDM          Right                         1
# 7924       3000           CF, RM          Right                         1
# 8896       1000               GK          Right                         1
# 10038      2000               ST          Right                         1
# 12178      1000          LW, CAM          Right                         1
# 14051      2000              CAM          Right                         1
# 14720      1000       RM, ST, LM          Right                         1
# 15363      1000               CB          Right                         1
# 15390      1000      RM, CM, CAM          Right                         1
#
#        weak_foot  skill_moves      work_rate body_type real_face  \
# 2141           3            3  Medium/Medium    Normal        No
# 2662           5            2    Medium/High      Lean        No
# 2756           4            3    High/Medium      Lean       Yes
# 3428           3            3    High/Medium      Lean       Yes
# 4212           4            3  Medium/Medium      Lean        No
# 4757           4            4    High/Medium      Lean        No
# 4780           3            3    High/Medium      Lean        No
# 5886           3            2    Medium/High    Normal        No
# 5888           2            3  Medium/Medium    Normal        No
# 6709           4            3    High/Medium    Stocky        No
# 6756           4            4  Medium/Medium      Lean       Yes
# 6782           4            3  Medium/Medium      Lean        No
# 6838           4            3    High/Medium      Lean        No
# 6843           3            2    Medium/High      Lean        No
# 7857           3            3  Medium/Medium    Normal        No
# 7898           3            3  Medium/Medium    Normal        No
# 7900           2            2  Medium/Medium      Lean        No
# 7924           3            3     Medium/Low    Normal        No
# 8896           2            1  Medium/Medium    Normal        No
# 10038          3            2     Medium/Low      Lean        No
# 12178          3            4    High/Medium      Lean        No
# 14051          3            3  Medium/Medium      Lean        No
# 14720          3            2  Medium/Medium      Lean        No
# 15363          2            2       Low/High    Normal        No
# 15390          3            3     Medium/Low      Lean        No
#
#        release_clause_eur player_tags team_position  team_jersey_number  \
# 2141           14900000.0         NaN           CAM                 7.0
# 2662           12400000.0         NaN           SUB                14.0
# 2756           10500000.0         NaN            LF                15.0
# 3428            7100000.0         NaN           SUB                 9.0
# 4212            5000000.0    #Acrobat           SUB                37.0
# 4757            9800000.0         NaN           RES                26.0
# 4780            9100000.0  #Speedster           RES                32.0
# 5886            1900000.0         NaN           RCB                20.0
# 5888            2100000.0         NaN           RDM                20.0
# 6709            2100000.0         NaN            LM                 4.0
# 6756            2500000.0    #Acrobat           SUB                15.0
# 6782            1900000.0         NaN           SUB                11.0
# 6838            1900000.0  #Speedster           SUB                42.0
# 6843            1600000.0         NaN           RCB                 3.0
# 7857            1700000.0         NaN            LM                22.0
# 7898            1500000.0         NaN           SUB                15.0
# 7900            1700000.0         NaN           LCB                17.0
# 7924                  NaN  #Speedster           SUB                13.0
# 8896            1200000.0         NaN            GK                38.0
# 10038           1400000.0         NaN           SUB                36.0
# 12178                 NaN         NaN            LW                13.0
# 14051           1300000.0         NaN           RES                36.0
# 14720            797000.0         NaN           RES                34.0
# 15363            563000.0         NaN           RES                33.0
# 15390            609000.0         NaN           RCM                41.0
#
#             loaned_from      joined  contract_valid_until nation_position  \
# 2141                NaN  2018-04-23                2021.0             NaN
# 2662                NaN  2019-07-09                2024.0             NaN
# 2756                NaN  2017-07-17                2021.0             NaN
# 3428                NaN  2019-07-16                2023.0             NaN
# 4212                NaN  2015-07-01                2020.0             NaN
# 4757                NaN  2019-07-01                2025.0             NaN
# 4780                NaN  2019-07-15                2023.0             NaN
# 5886                NaN  2018-07-01                2021.0             NaN
# 5888                NaN  2016-01-12                2022.0             NaN
# 6709                NaN  2017-01-01                2022.0             NaN
# 6756                NaN  2017-09-20                2021.0             NaN
# 6782                NaN  2016-01-01                2022.0             NaN
# 6838                NaN  2015-01-01                2021.0             NaN
# 6843                NaN  2015-01-01                2022.0             NaN
# 7857                NaN  2018-01-05                2022.0             NaN
# 7898                NaN  2019-08-05                2022.0             NaN
# 7900                NaN  2019-01-15                2022.0             NaN
# 7924   Matsumoto Yamaga         NaN                2020.0             NaN
# 8896                NaN  2018-01-01                2019.0             NaN
# 10038               NaN  2019-07-26                2023.0             NaN
# 12178       Gamba Osaka         NaN                2021.0             NaN
# 14051               NaN  2019-07-01                2021.0             NaN
# 14720               NaN  2019-01-01                2022.0             NaN
# 15363               NaN  2019-01-01                2022.0             NaN
# 15390               NaN  2019-03-02                2022.0             NaN
#
#        nation_jersey_number  pace  shooting  passing  dribbling  defending  \
# 2141                    NaN  76.0      69.0     71.0       78.0       39.0
# 2662                    NaN  66.0      28.0     57.0       63.0       72.0
# 2756                    NaN  75.0      69.0     71.0       76.0       36.0
# 3428                    NaN  72.0      67.0     67.0       68.0       45.0
# 4212                    NaN  85.0      61.0     60.0       80.0       28.0
# 4757                    NaN  82.0      60.0     62.0       78.0       39.0
# 4780                    NaN  90.0      61.0     57.0       78.0       33.0
# 5886                    NaN  74.0      24.0     39.0       45.0       68.0
# 5888                    NaN  72.0      43.0     71.0       71.0       66.0
# 6709                    NaN  69.0      56.0     66.0       68.0       58.0
# 6756                    NaN  81.0      49.0     59.0       81.0       22.0
# 6782                    NaN  79.0      48.0     65.0       68.0       47.0
# 6838                    NaN  92.0      61.0     63.0       70.0       35.0
# 6843                    NaN  66.0      52.0     48.0       45.0       67.0
# 7857                    NaN  79.0      60.0     67.0       70.0       42.0
# 7898                    NaN  70.0      60.0     64.0       66.0       63.0
# 7900                    NaN  75.0      30.0     52.0       60.0       64.0
# 7924                    NaN  90.0      62.0     58.0       69.0       30.0
# 8896                    NaN   NaN       NaN      NaN        NaN        NaN
# 10038                   NaN  79.0      60.0     48.0       62.0       26.0
# 12178                   NaN  76.0      54.0     53.0       71.0       31.0
# 14051                   NaN  66.0      45.0     60.0       68.0       35.0
# 14720                   NaN  67.0      52.0     54.0       64.0       31.0
# 15363                   NaN  56.0      31.0     31.0       42.0       58.0
# 15390                   NaN  60.0      43.0     57.0       64.0       38.0
#
#        physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 2141     56.0        NaN          NaN         NaN          NaN       NaN
# 2662     76.0        NaN          NaN         NaN          NaN       NaN
# 2756     60.0        NaN          NaN         NaN          NaN       NaN
# 3428     80.0        NaN          NaN         NaN          NaN       NaN
# 4212     49.0        NaN          NaN         NaN          NaN       NaN
# 4757     52.0        NaN          NaN         NaN          NaN       NaN
# 4780     59.0        NaN          NaN         NaN          NaN       NaN
# 5886     73.0        NaN          NaN         NaN          NaN       NaN
# 5888     75.0        NaN          NaN         NaN          NaN       NaN
# 6709     66.0        NaN          NaN         NaN          NaN       NaN
# 6756     34.0        NaN          NaN         NaN          NaN       NaN
# 6782     68.0        NaN          NaN         NaN          NaN       NaN
# 6838     59.0        NaN          NaN         NaN          NaN       NaN
# 6843     74.0        NaN          NaN         NaN          NaN       NaN
# 7857     69.0        NaN          NaN         NaN          NaN       NaN
# 7898     67.0        NaN          NaN         NaN          NaN       NaN
# 7900     74.0        NaN          NaN         NaN          NaN       NaN
# 7924     61.0        NaN          NaN         NaN          NaN       NaN
# 8896      NaN       67.0         66.0        65.0         69.0      30.0
# 10038    61.0        NaN          NaN         NaN          NaN       NaN
# 12178    64.0        NaN          NaN         NaN          NaN       NaN
# 14051    39.0        NaN          NaN         NaN          NaN       NaN
# 14720    49.0        NaN          NaN         NaN          NaN       NaN
# 15363    65.0        NaN          NaN         NaN          NaN       NaN
# 15390    56.0        NaN          NaN         NaN          NaN       NaN
#
#        gk_positioning                                  player_traits  \
# 2141              NaN                          Argues with Officials
# 2662              NaN                                            NaN
# 2756              NaN                  Finesse Shot, Crowd Favourite
# 3428              NaN                      Long Passer (CPU AI Only)
# 4212              NaN                       Selfish, Crowd Favourite
# 4757              NaN                                Crowd Favourite
# 4780              NaN                                            NaN
# 5886              NaN                                   Injury Prone
# 5888              NaN                                            NaN
# 6709              NaN                                            NaN
# 6756              NaN                         Selfish, Early Crosser
# 6782              NaN                                            NaN
# 6838              NaN    Beat Offside Trap, Selfish, Crowd Favourite
# 6843              NaN                                            NaN
# 7857              NaN                                            NaN
# 7898              NaN                                            NaN
# 7900              NaN                                            NaN
# 7924              NaN                                            NaN
# 8896             63.0                                            NaN
# 10038             NaN                                            NaN
# 12178             NaN  Speed Dribbler (CPU AI Only), Crowd Favourite
# 14051             NaN                                            NaN
# 14720             NaN                                            NaN
# 15363             NaN                                            NaN
# 15390             NaN                                            NaN
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 2141                   70                   66                          45
# 2662                   47                   27                          70
# 2756                   71                   75                          53
# 3428                   67                   70                          82
# 4212                   60                   61                          49
# 4757                   55                   64                          39
# 4780                   61                   62                          56
# 5886                   22                   18                          73
# 5888                   69                   40                          56
# 6709                   70                   58                          54
# 6756                   65                   45                          27
# 6782                   69                   45                          48
# 6838                   58                   61                          37
# 6843                   34                   60                          72
# 7857                   59                   58                          46
# 7898                   63                   62                          43
# 7900                   30                   16                          67
# 7924                   58                   65                          56
# 8896                   14                    7                          10
# 10038                  38                   66                          63
# 12178                  49                   59                          43
# 14051                  58                   49                          31
# 14720                  55                   60                          40
# 15363                  15                   26                          61
# 15390                  55                   43                          38
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 2141                        72                 59               75
# 2662                        68                 22               60
# 2756                        73                 38               77
# 3428                        73                 67               68
# 4212                        64                 56               80
# 4757                        67                 57               79
# 4780                        62                 64               81
# 5886                        57                 47               31
# 5888                        76                 40               69
# 6709                        69                 58               68
# 6756                        60                 55               82
# 6782                        69                 37               67
# 6838                        65                 61               68
# 6843                        63                 38               40
# 7857                        72                 58               71
# 7898                        68                 33               66
# 7900                        66                 24               55
# 7924                        63                 58               65
# 8896                        18                  7               12
# 10038                       59                 42               60
# 12178                       54                 47               74
# 14051                       64                 46               67
# 14720                       60                 45               70
# 15363                       49                 22               32
# 15390                       64                 44               64
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 2141            67                 67                  68                  78
# 2662            43                 35                  65                  67
# 2756            67                 66                  65                  77
# 3428            47                 40                  64                  68
# 4212            57                 39                  51                  76
# 4757            68                 72                  54                  78
# 4780            53                 32                  42                  73
# 5886            22                 23                  34                  56
# 5888            58                 44                  72                  75
# 6709            65                 56                  63                  67
# 6756            67                 44                  43                  75
# 6782            68                 44                  63                  71
# 6838            67                 50                  59                  67
# 6843            27                 28                  51                  39
# 7857            55                 50                  70                  70
# 7898            37                 55                  66                  67
# 7900            30                 40                  64                  65
# 7924            64                 57                  49                  70
# 8896            10                 10                  19                  20
# 10038           42                 22                  38                  63
# 12178           69                 69                  46                  67
# 14051           55                 42                  62                  66
# 14720           45                 45                  52                  62
# 15363           18                 26                  34                  51
# 15390           46                 44                  54                  60
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 2141                      78                     74                86
# 2662                      67                     66                65
# 2756                      76                     74                77
# 3428                      72                     72                69
# 4212                      87                     84                90
# 4757                      89                     77                83
# 4780                      91                     90                81
# 5886                      71                     76                70
# 5888                      70                     74                67
# 6709                      67                     71                67
# 6756                      93                     72                95
# 6782                      79                     79                64
# 6838                      94                     91                85
# 6843                      64                     67                69
# 7857                      83                     76                69
# 7898                      66                     74                64
# 7900                      74                     76                68
# 7924                      91                     90                88
# 8896                      28                     32                27
# 10038                     80                     79                70
# 12178                     75                     76                72
# 14051                     69                     64                77
# 14720                     64                     69                57
# 15363                     57                     56                54
# 15390                     63                     58                76
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 2141                   70                93                76             41
# 2662                   62                58                37             69
# 2756                   70                72                69             68
# 3428                   64                66                69             87
# 4212                   64                90                63             48
# 4757                   61                83                61             54
# 4780                   57                84                66             68
# 5886                   64                50                35             78
# 5888                   69                70                59             69
# 6709                   65                74                61             61
# 6756                   72                96                62             47
# 6782                   62                75                58             80
# 6838                   68                84                66             89
# 6843                   66                67                48             77
# 7857                   58                71                67             70
# 7898                   63                75                58             71
# 7900                   65                49                64             82
# 7924                   66                72                63             72
# 8896                   59                38                49             42
# 10038                  52                71                55             72
# 12178                  61                63                55             63
# 14051                  51                79                37             61
# 14720                  40                63                36             35
# 15363                  45                53                46             73
# 15390                  56                80                47             72
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 2141              75              54                74                    41
# 2662              68              81                24                    74
# 2756              70              59                62                    48
# 3428              83              82                57                    68
# 4212              68              47                62                    31
# 4757              72              45                52                    43
# 4780              74              60                55                    33
# 5886              72              80                19                    54
# 5888              73              79                36                    68
# 6709              81              68                54                    44
# 6756              52              28                46                    21
# 6782              71              69                44                    58
# 6838              71              57                59                    43
# 6843              75              72                42                    76
# 7857              65              75                58                    57
# 7898              83              62                67                    58
# 7900              84              72                24                    64
# 7924              80              56                54                    45
# 8896              22              68                 7                    19
# 10038             70              58                55                    53
# 12178             70              71                43                    41
# 14051             51              31                41                    36
# 14720             56              50                51                    41
# 15363             59              70                32                    58
# 15390             62              58                38                    41
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 2141                        41                     61                76
# 2662                        69                     23                51
# 2756                        28                     74                72
# 3428                        38                     71                69
# 4212                        16                     65                66
# 4757                        29                     62                60
# 4780                        17                     62                65
# 5886                        67                     21                36
# 5888                        63                     45                71
# 6709                        55                     58                63
# 6756                        25                     55                66
# 6782                        36                     66                58
# 6838                        26                     50                69
# 6843                        67                     59                42
# 7857                        47                     59                70
# 7898                        67                     57                65
# 7900                        68                     41                50
# 7924                        31                     64                57
# 8896                         8                      7                38
# 10038                       20                     75                54
# 12178                       31                     55                54
# 14051                       35                     54                59
# 14720                       18                     57                48
# 15363                       48                     23                20
# 15390                       34                     50                57
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 2141                    58                   72                 39
# 2662                    37                   59                 72
# 2756                    71                   80                 30
# 3428                    68                   68                 40
# 4212                    53                   58                 28
# 4757                    61                   64                 40
# 4780                    58                   62                 51
# 5886                    37                   58                 64
# 5888                    42                   64                 67
# 6709                    30                   64                 63
# 6756                    41                   60                 17
# 6782                    46                   51                 40
# 6838                    56                   57                 38
# 6843                    35                   58                 66
# 7857                    63                   66                 28
# 7898                    44                   57                 66
# 7900                    38                   62                 62
# 7924                    60                   65                 28
# 8896                    15                   45                 12
# 10038                   55                   55                 22
# 12178                   54                   64                 21
# 14051                   46                   57                 37
# 14720                   40                   50                 25
# 15363                   31                   39                 56
# 15390                   42                   57                 40
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 2141                          36                        42
# 2662                          75                        74
# 2756                          42                        34
# 3428                          48                        25
# 4212                          29                        24
# 4757                          43                        48
# 4780                          25                        15
# 5886                          70                        67
# 5888                          70                        65
# 6709                          58                        48
# 6756                          24                        22
# 6782                          59                        51
# 6838                          35                        44
# 6843                          69                        61
# 7857                          49                        46
# 7898                          64                        61
# 7900                          65                        58
# 7924                          24                        21
# 8896                          14                        11
# 10038                         22                        22
# 12178                         36                        30
# 14051                         32                        37
# 14720                         41                        34
# 15363                         64                        58
# 15390                         38                        35
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 2141                    8                     5                    6
# 2662                    9                    14                    6
# 2756                    6                    10                   11
# 3428                   14                     5                    8
# 4212                    6                     8                   14
# 4757                    6                     7                   15
# 4780                   12                    12                    9
# 5886                    7                     9                   13
# 5888                   14                     6                   13
# 6709                    8                     6                   10
# 6756                   10                    13                    5
# 6782                   15                     9                    9
# 6838                    8                     9                   15
# 6843                    6                    13                   11
# 7857                    6                    12                   11
# 7898                   13                    12                    8
# 7900                   13                     6                    9
# 7924                    5                     9                    5
# 8896                   67                    66                   65
# 10038                   7                    12                   14
# 12178                   7                    13                   15
# 14051                  10                     9                   11
# 14720                  10                    14                    7
# 15363                   7                    13                   13
# 15390                   7                    10                   14
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 2141                        13                    14  67+2  67+2  67+2  72+2
# 2662                         5                    11  49+2  49+2  49+2  53+2
# 2756                         6                    11  69+2  69+2  69+2  73+2
# 3428                         8                     8  70+2  70+2  70+2  68+2
# 4212                        13                    13  65+2  65+2  65+2  71+2
# 4757                        10                    10  63+2  63+2  63+2  69+2
# 4780                         8                     7  66+2  66+2  66+2  70+2
# 5886                        14                    13  44+2  44+2  44+2  42+2
# 5888                        10                    11  58+2  58+2  58+2  64+2
# 6709                         5                     7  61+2  61+2  61+2  65+2
# 6756                        12                    13  57+2  57+2  57+2  68+2
# 6782                        11                    13  60+2  60+2  60+2  65+2
# 6838                         7                    10  62+2  62+2  62+2  67+2
# 6843                         6                     7  57+2  57+2  57+2  51+2
# 7857                         9                     8  63+2  63+2  63+2  67+2
# 7898                        10                    13  60+2  60+2  60+2  65+2
# 7900                        10                    12  51+2  51+2  51+2  52+2
# 7924                         9                    12  65+2  65+2  65+2  67+2
# 8896                        63                    69   NaN   NaN   NaN   NaN
# 10038                       15                     6  63+2  63+2  63+2  62+2
# 12178                        8                     7  59+2  59+2  59+2  62+2
# 14051                       12                    10  50+2  50+2  50+2  60+2
# 14720                        5                     6  54+2  54+2  54+2  59+2
# 15363                       11                     7  41+2  41+2  41+2  37+2
# 15390                       10                    13  51+2  51+2  51+2  57+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 2141   71+2  71+2  71+2  72+2  72+2  72+2  72+2  72+2  69+2  69+2  69+2  72+2
# 2662   51+2  51+2  51+2  53+2  54+2  54+2  54+2  56+2  59+2  59+2  59+2  56+2
# 2756   73+2  73+2  73+2  73+2  73+2  73+2  73+2  73+2  68+2  68+2  68+2  73+2
# 3428   69+2  69+2  69+2  68+2  68+2  68+2  68+2  69+2  66+2  66+2  66+2  69+2
# 4212   69+2  69+2  69+2  71+2  69+2  69+2  69+2  69+2  61+2  61+2  61+2  69+2
# 4757   68+2  68+2  68+2  69+2  68+2  68+2  68+2  69+2  62+2  62+2  62+2  69+2
# 4780   68+2  68+2  68+2  70+2  67+2  67+2  67+2  69+2  58+2  58+2  58+2  69+2
# 5886   42+2  42+2  42+2  42+2  43+2  43+2  43+2  44+2  47+2  47+2  47+2  44+2
# 5888   62+2  62+2  62+2  64+2  65+2  65+2  65+2  67+2  68+2  68+2  68+2  67+2
# 6709   63+2  63+2  63+2  65+2  64+2  64+2  64+2  66+2  64+2  64+2  64+2  66+2
# 6756   65+2  65+2  65+2  68+2  66+2  66+2  66+2  67+2  57+2  57+2  57+2  67+2
# 6782   63+2  63+2  63+2  65+2  64+2  64+2  64+2  67+2  62+2  62+2  62+2  67+2
# 6838   65+2  65+2  65+2  67+2  66+2  66+2  66+2  67+2  61+2  61+2  61+2  67+2
# 6843   52+2  52+2  52+2  51+2  51+2  51+2  51+2  52+2  54+2  54+2  54+2  52+2
# 7857   66+2  66+2  66+2  67+2  67+2  67+2  67+2  67+2  65+2  65+2  65+2  67+2
# 7898   63+2  63+2  63+2  65+2  65+2  65+2  65+2  66+2  66+2  66+2  66+2  66+2
# 7900   53+2  53+2  53+2  52+2  54+2  54+2  54+2  56+2  59+2  59+2  59+2  56+2
# 7924   66+2  66+2  66+2  67+2  65+2  65+2  65+2  67+2  58+2  58+2  58+2  67+2
# 8896    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10038  63+2  63+2  63+2  62+2  61+2  61+2  61+2  60+2  53+2  53+2  53+2  60+2
# 12178  61+2  61+2  61+2  62+2  60+2  60+2  60+2  62+2  55+2  55+2  55+2  62+2
# 14051  57+2  57+2  57+2  60+2  60+2  60+2  60+2  60+2  56+2  56+2  56+2  60+2
# 14720  57+2  57+2  57+2  59+2  57+2  57+2  57+2  59+2  52+2  52+2  52+2  59+2
# 15363  38+2  38+2  38+2  37+2  38+2  38+2  38+2  38+2  40+2  40+2  40+2  38+2
# 15390  55+2  55+2  55+2  57+2  57+2  57+2  57+2  58+2  55+2  55+2  55+2  58+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 2141   60+2  57+2  57+2  57+2  60+2  57+2  46+2  46+2  46+2  57+2
# 2662   66+2  68+2  68+2  68+2  66+2  67+2  72+2  72+2  72+2  67+2
# 2756   57+2  54+2  54+2  54+2  57+2  54+2  46+2  46+2  46+2  54+2
# 3428   58+2  58+2  58+2  58+2  58+2  56+2  55+2  55+2  55+2  56+2
# 4212   52+2  45+2  45+2  45+2  52+2  48+2  37+2  37+2  37+2  48+2
# 4757   57+2  52+2  52+2  52+2  57+2  55+2  45+2  45+2  45+2  55+2
# 4780   52+2  45+2  45+2  45+2  52+2  49+2  41+2  41+2  41+2  49+2
# 5886   59+2  60+2  60+2  60+2  59+2  62+2  67+2  67+2  67+2  62+2
# 5888   69+2  70+2  70+2  70+2  69+2  68+2  68+2  68+2  68+2  68+2
# 6709   64+2  62+2  62+2  62+2  64+2  62+2  58+2  58+2  58+2  62+2
# 6756   50+2  42+2  42+2  42+2  50+2  46+2  31+2  31+2  31+2  46+2
# 6782   60+2  57+2  57+2  57+2  60+2  59+2  54+2  54+2  54+2  59+2
# 6838   56+2  51+2  51+2  51+2  56+2  54+2  45+2  45+2  45+2  54+2
# 6843   59+2  61+2  61+2  61+2  59+2  61+2  67+2  67+2  67+2  61+2
# 7857   58+2  57+2  57+2  57+2  58+2  56+2  51+2  51+2  51+2  56+2
# 7898   67+2  66+2  66+2  66+2  67+2  65+2  62+2  62+2  62+2  65+2
# 7900   62+2  65+2  65+2  65+2  62+2  63+2  65+2  65+2  65+2  63+2
# 7924   53+2  47+2  47+2  47+2  53+2  50+2  41+2  41+2  41+2  50+2
# 8896    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10038  45+2  41+2  41+2  41+2  45+2  43+2  39+2  39+2  39+2  43+2
# 12178  50+2  46+2  46+2  46+2  50+2  47+2  42+2  42+2  42+2  47+2
# 14051  50+2  47+2  47+2  47+2  50+2  47+2  39+2  39+2  39+2  47+2
# 14720  46+2  43+2  43+2  43+2  46+2  44+2  37+2  37+2  37+2  44+2
# 15363  48+2  50+2  50+2  50+2  48+2  51+2  57+2  57+2  57+2  51+2
# 15390  50+2  49+2  49+2  49+2  50+2  48+2  44+2  44+2  44+2  48+2

# %%
df.query('age <= 23 & 80 <= potential').query("nationality == 'Japan'")
# Out:
#        sofifa_id                                         player_url  \
# 2141      232639  https://sofifa.com/player/232639/ritsu-doan/20...
# 2662      232938  https://sofifa.com/player/232938/takehiro-tomi...
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 4780      237823  https://sofifa.com/player/237823/hiroki-abe/20...
# 12178     242914  https://sofifa.com/player/242914/keito-nakamur...
#
#         short_name long_name  age         dob  height_cm  weight_kg  \
# 2141       R. Doan      堂安 律   21  1998-06-16        172         70
# 2662   T. Tomiyasu     冨安 健洋   20  1998-11-05        188         84
# 4757       T. Kubo     久保 建英   18  2001-06-04        173         67
# 4780        H. Abe     安部 裕葵   20  1999-01-28        171         65
# 12178  K. Nakamura     中村 敬斗   18  2000-07-28        180         75
#
#       nationality          club  overall  potential  value_eur  wage_eur  \
# 2141        Japan  FC Groningen       74         84    9000000      8000
# 2662        Japan       Bologna       73         84    6500000     16000
# 4757        Japan   Real Madrid       70         87    3700000     21000
# 4780        Japan  FC Barcelona       70         83    3400000     44000
# 12178       Japan     FC Twente       63         81     750000      1000
#
#       player_positions preferred_foot  international_reputation  weak_foot  \
# 2141           CAM, RM           Left                         1          3
# 2662           CB, CDM          Right                         1          5
# 4757            RM, CF           Left                         1          4
# 4780            LM, RM          Right                         1          3
# 12178          LW, CAM          Right                         1          3
#
#        skill_moves      work_rate body_type real_face  release_clause_eur  \
# 2141             3  Medium/Medium    Normal        No          14900000.0
# 2662             2    Medium/High      Lean        No          12400000.0
# 4757             4    High/Medium      Lean        No           9800000.0
# 4780             3    High/Medium      Lean        No           9100000.0
# 12178            4    High/Medium      Lean        No                 NaN
#
#       player_tags team_position  team_jersey_number  loaned_from      joined  \
# 2141          NaN           CAM                 7.0          NaN  2018-04-23
# 2662          NaN           SUB                14.0          NaN  2019-07-09
# 4757          NaN           RES                26.0          NaN  2019-07-01
# 4780   #Speedster           RES                32.0          NaN  2019-07-15
# 12178         NaN            LW                13.0  Gamba Osaka         NaN
#
#        contract_valid_until nation_position  nation_jersey_number  pace  \
# 2141                 2021.0             NaN                   NaN  76.0
# 2662                 2024.0             NaN                   NaN  66.0
# 4757                 2025.0             NaN                   NaN  82.0
# 4780                 2023.0             NaN                   NaN  90.0
# 12178                2021.0             NaN                   NaN  76.0
#
#        shooting  passing  dribbling  defending  physic  gk_diving  \
# 2141       69.0     71.0       78.0       39.0    56.0        NaN
# 2662       28.0     57.0       63.0       72.0    76.0        NaN
# 4757       60.0     62.0       78.0       39.0    52.0        NaN
# 4780       61.0     57.0       78.0       33.0    59.0        NaN
# 12178      54.0     53.0       71.0       31.0    64.0        NaN
#
#        gk_handling  gk_kicking  gk_reflexes  gk_speed  gk_positioning  \
# 2141           NaN         NaN          NaN       NaN             NaN
# 2662           NaN         NaN          NaN       NaN             NaN
# 4757           NaN         NaN          NaN       NaN             NaN
# 4780           NaN         NaN          NaN       NaN             NaN
# 12178          NaN         NaN          NaN       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 2141                           Argues with Officials                  70
# 2662                                             NaN                  47
# 4757                                 Crowd Favourite                  55
# 4780                                             NaN                  61
# 12178  Speed Dribbler (CPU AI Only), Crowd Favourite                  49
#
#        attacking_finishing  attacking_heading_accuracy  \
# 2141                    66                          45
# 2662                    27                          70
# 4757                    64                          39
# 4780                    62                          56
# 12178                   59                          43
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 2141                        72                 59               75
# 2662                        68                 22               60
# 4757                        67                 57               79
# 4780                        62                 64               81
# 12178                       54                 47               74
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 2141            67                 67                  68                  78
# 2662            43                 35                  65                  67
# 4757            68                 72                  54                  78
# 4780            53                 32                  42                  73
# 12178           69                 69                  46                  67
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 2141                      78                     74                86
# 2662                      67                     66                65
# 4757                      89                     77                83
# 4780                      91                     90                81
# 12178                     75                     76                72
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 2141                   70                93                76             41
# 2662                   62                58                37             69
# 4757                   61                83                61             54
# 4780                   57                84                66             68
# 12178                  61                63                55             63
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 2141              75              54                74                    41
# 2662              68              81                24                    74
# 4757              72              45                52                    43
# 4780              74              60                55                    33
# 12178             70              71                43                    41
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 2141                        41                     61                76
# 2662                        69                     23                51
# 4757                        29                     62                60
# 4780                        17                     62                65
# 12178                       31                     55                54
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 2141                    58                   72                 39
# 2662                    37                   59                 72
# 4757                    61                   64                 40
# 4780                    58                   62                 51
# 12178                   54                   64                 21
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 2141                          36                        42
# 2662                          75                        74
# 4757                          43                        48
# 4780                          25                        15
# 12178                         36                        30
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 2141                    8                     5                    6
# 2662                    9                    14                    6
# 4757                    6                     7                   15
# 4780                   12                    12                    9
# 12178                   7                    13                   15
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 2141                        13                    14  67+2  67+2  67+2  72+2
# 2662                         5                    11  49+2  49+2  49+2  53+2
# 4757                        10                    10  63+2  63+2  63+2  69+2
# 4780                         8                     7  66+2  66+2  66+2  70+2
# 12178                        8                     7  59+2  59+2  59+2  62+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 2141   71+2  71+2  71+2  72+2  72+2  72+2  72+2  72+2  69+2  69+2  69+2  72+2
# 2662   51+2  51+2  51+2  53+2  54+2  54+2  54+2  56+2  59+2  59+2  59+2  56+2
# 4757   68+2  68+2  68+2  69+2  68+2  68+2  68+2  69+2  62+2  62+2  62+2  69+2
# 4780   68+2  68+2  68+2  70+2  67+2  67+2  67+2  69+2  58+2  58+2  58+2  69+2
# 12178  61+2  61+2  61+2  62+2  60+2  60+2  60+2  62+2  55+2  55+2  55+2  62+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 2141   60+2  57+2  57+2  57+2  60+2  57+2  46+2  46+2  46+2  57+2
# 2662   66+2  68+2  68+2  68+2  66+2  67+2  72+2  72+2  72+2  67+2
# 4757   57+2  52+2  52+2  52+2  57+2  55+2  45+2  45+2  45+2  55+2
# 4780   52+2  45+2  45+2  45+2  52+2  49+2  41+2  41+2  41+2  49+2
# 12178  50+2  46+2  46+2  46+2  50+2  47+2  42+2  42+2  42+2  47+2

# %%
teens_nationalities
# Out:
# 73       Netherlands
# 108          England
# 411         Portugal
# 568           Brazil
# 1254         England
#             ...
# 15872         France
# 15873          Spain
# 16357        England
# 16717      Argentina
# 17077        England
# Name: nationality, Length: 344, dtype: object

# %%
teens = df.query('age < 20 & 80 <= potential')

# %%
teens
# Out:
#        sofifa_id                                         player_url  \
# 73        235243  https://sofifa.com/player/235243/matthijs-de-l...
# 108       233049  https://sofifa.com/player/233049/jadon-sancho/...
# 411       242444  https://sofifa.com/player/242444/joao-felix-se...
# 568       238794  https://sofifa.com/player/238794/vinicius-jose...
# 1254      237692  https://sofifa.com/player/237692/phil-foden/20...
# ...          ...                                                ...
# 15872     251752  https://sofifa.com/player/251752/lucas-chevali...
# 15873     252276  https://sofifa.com/player/252276/raul-prada-lo...
# 16357     246601  https://sofifa.com/player/246601/james-rowland...
# 16717     252072  https://sofifa.com/player/252072/santiago-ramo...
# 17077     243353  https://sofifa.com/player/243353/bali-mumba/20...
#
#            short_name                         long_name  age         dob  \
# 73         M. de Ligt                  Matthijs de Ligt   19  1999-08-12
# 108         J. Sancho                      Jadon Sancho   19  2000-03-25
# 411        João Félix               João Félix Sequeira   19  1999-11-10
# 568      Vinícius Jr.  Vinícius José de Oliveira Júnior   18  2000-07-12
# 1254         P. Foden                      Philip Foden   19  2000-05-28
# ...               ...                               ...  ...         ...
# 15872    L. Chevalier                   Lucas Chevalier   17  2001-11-06
# 15873      Raúl Prada                 Raúl Prada Lozano   18  2001-01-01
# 16357      J. Rowland                     James Rowland   17  2001-12-03
# 16717  S. Ramos Mingo              Santiago Ramos Mingo   17  2001-11-21
# 17077        B. Mumba                        Bali Mumba   17  2001-10-08
#
#        height_cm  weight_kg  nationality               club  overall  \
# 73           189         89  Netherlands           Juventus       85
# 108          180         76      England  Borussia Dortmund       84
# 411          181         70     Portugal    Atlético Madrid       80
# 568          176         73       Brazil        Real Madrid       79
# 1254         171         69      England    Manchester City       76
# ...          ...        ...          ...                ...      ...
# 15872        187         78       France         LOSC Lille       58
# 15873        180         68        Spain       RCD Mallorca       58
# 16357        165         65      England         Shrewsbury       57
# 16717        185         74    Argentina       Boca Juniors       56
# 17077        163         57      England         Sunderland       55
#
#        potential  value_eur  wage_eur player_positions preferred_foot  \
# 73            93   50000000     76000               CB          Right
# 108           92   44500000     61000           RM, LM          Right
# 411           93   28000000     38000           CF, ST          Right
# 568           92   22500000     60000               LW          Right
# 1254          90   16500000     52000          CAM, CM           Left
# ...          ...        ...       ...              ...            ...
# 15872         82     230000      1000               GK          Right
# 15873         81     270000      1000           CB, LB           Left
# 16357         80     230000      1000              CAM          Right
# 16717         81     180000      1000               CB           Left
# 17077         80     170000      1000               CM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 73                            3          4            2    Medium/High
# 108                           2          4            5     Medium/Low
# 411                           1          4            5    High/Medium
# 568                           2          4            5    High/Medium
# 1254                          1          3            4  Medium/Medium
# ...                         ...        ...          ...            ...
# 15872                         1          3            1  Medium/Medium
# 15873                         1          3            2  Medium/Medium
# 16357                         1          3            2  Medium/Medium
# 16717                         1          2            2       Low/High
# 17077                         1          3            2    Medium/High
#
#       body_type real_face  release_clause_eur  \
# 73       Normal       Yes          92500000.0
# 108        Lean       Yes          82300000.0
# 411        Lean        No          74900000.0
# 568        Lean       Yes          60200000.0
# 1254       Lean       Yes          40800000.0
# ...         ...       ...                 ...
# 15872    Normal        No            667000.0
# 15873      Lean        No            864000.0
# 16357      Lean        No            633000.0
# 16717    Normal        No            432000.0
# 17077      Lean        No            468000.0
#
#                            player_tags team_position  team_jersey_number  \
# 73                           #Strength           SUB                 4.0
# 108                #Dribbler, #Acrobat            RM                 7.0
# 411                                NaN            RS                 7.0
# 568    #Speedster, #Dribbler, #Acrobat            RW                28.0
# 1254                               NaN           SUB                47.0
# ...                                ...           ...                 ...
# 15872                              NaN           RES                30.0
# 15873                              NaN           RES                28.0
# 16357                              NaN           RES                26.0
# 16717                              NaN           RES                26.0
# 17077                              NaN           SUB                46.0
#
#       loaned_from      joined  contract_valid_until nation_position  \
# 73            NaN  2019-07-18                2024.0             RCB
# 108           NaN  2017-08-31                2022.0              RW
# 411           NaN  2019-07-03                2026.0              RS
# 568           NaN  2018-07-12                2025.0             NaN
# 1254          NaN  2016-07-01                2024.0             NaN
# ...           ...         ...                   ...             ...
# 15872         NaN  2018-06-14                2023.0             NaN
# 15873         NaN  2019-06-01                2020.0             NaN
# 16357         NaN  2018-07-01                2021.0             NaN
# 16717         NaN  2019-07-03                2023.0             NaN
# 17077         NaN  2017-07-01                2021.0             NaN
#
#        nation_jersey_number  pace  shooting  passing  dribbling  defending  \
# 73                      3.0  67.0      58.0     66.0       68.0       83.0
# 108                    21.0  88.0      72.0     77.0       90.0       36.0
# 411                    23.0  82.0      80.0     74.0       81.0       40.0
# 568                     NaN  93.0      70.0     71.0       85.0       29.0
# 1254                    NaN  74.0      64.0     74.0       79.0       55.0
# ...                     ...   ...       ...      ...        ...        ...
# 15872                   NaN   NaN       NaN      NaN        NaN        NaN
# 15873                   NaN  63.0      28.0     38.0       43.0       59.0
# 16357                   NaN  72.0      48.0     53.0       59.0       34.0
# 16717                   NaN  55.0      29.0     33.0       35.0       58.0
# 17077                   NaN  61.0      37.0     53.0       54.0       53.0
#
#        physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 73       84.0        NaN          NaN         NaN          NaN       NaN
# 108      60.0        NaN          NaN         NaN          NaN       NaN
# 411      70.0        NaN          NaN         NaN          NaN       NaN
# 568      63.0        NaN          NaN         NaN          NaN       NaN
# 1254     55.0        NaN          NaN         NaN          NaN       NaN
# ...       ...        ...          ...         ...          ...       ...
# 15872     NaN       58.0         56.0        57.0         59.0      24.0
# 15873    62.0        NaN          NaN         NaN          NaN       NaN
# 16357    54.0        NaN          NaN         NaN          NaN       NaN
# 16717    55.0        NaN          NaN         NaN          NaN       NaN
# 17077    57.0        NaN          NaN         NaN          NaN       NaN
#
#        gk_positioning                                      player_traits  \
# 73                NaN  Diver, Avoids Using Weaker Foot, Long Passer (...
# 108               NaN  Beat Offside Trap, Selfish, Speed Dribbler (CP...
# 411               NaN  Selfish, Finesse Shot, Speed Dribbler (CPU AI ...
# 568               NaN  Selfish, Early Crosser, Speed Dribbler (CPU AI...
# 1254              NaN                      Finesse Shot, Crowd Favourite
# ...               ...                                                ...
# 15872            56.0                                                NaN
# 15873             NaN                                                NaN
# 16357             NaN                                                NaN
# 16717             NaN                                                NaN
# 17077             NaN                                                NaN
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 73                     52                   50                          85
# 108                    78                   78                          37
# 411                    73                   79                          69
# 568                    71                   68                          50
# 1254                   68                   66                          47
# ...                   ...                  ...                         ...
# 15872                  12                    5                          12
# 15873                  33                   24                          56
# 16357                  52                   45                          39
# 16717                  31                   20                          52
# 17077                  42                   33                          50
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 73                          76                 40               66
# 108                         83                 80               92
# 411                         76                 79               82
# 568                         73                 70               86
# 1254                        80                 48               77
# ...                        ...                ...              ...
# 15872                       17                  9                6
# 15873                       48                 32               40
# 16357                       56                 51               55
# 16717                       35                 33               29
# 17077                       63                 31               52
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 73              48                 55                  74                  74
# 108             81                 48                  59                  88
# 411             81                 58                  67                  80
# 568             77                 62                  67                  82
# 1254            68                 57                  74                  79
# ...            ...                ...                 ...                 ...
# 15872           13                 14                  15                  16
# 15873           29                 32                  43                  40
# 16357           49                 36                  54                  57
# 16717           26                 33                  35                  34
# 17077           42                 36                  56                  55
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 73                        61                     72                56
# 108                       89                     87                91
# 411                       79                     85                83
# 568                       92                     94                93
# 1254                      77                     72                87
# ...                      ...                    ...               ...
# 15872                     26                     23                31
# 15873                     65                     62                53
# 16357                     70                     73                74
# 16717                     56                     55                48
# 17077                     58                     63                53
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 73                     83                60                82             84
# 108                    84                90                68             51
# 411                    83                80                82             79
# 568                    77                83                74             75
# 1254                   69                89                70             49
# ...                   ...               ...               ...            ...
# 15872                  57                38                43             48
# 15873                  48                58                40             73
# 16357                  56                80                54             50
# 16717                  53                59                44             69
# 17077                  53                66                52             63
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 73                77              88                64                    82
# 108               77              59                62                    43
# 411               79              64                80                    69
# 568               79              60                68                    48
# 1254              72              44                61                    62
# ...              ...             ...               ...                   ...
# 15872             23              40                 8                    23
# 15873             68              60                20                    55
# 16357             65              52                49                    44
# 16717             59              55                28                    46
# 17077             68              49                30                    61
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 73                          82                     44                63
# 108                         29                     78                83
# 411                         38                     84                77
# 568                         26                     76                73
# 1254                        58                     69                76
# ...                        ...                    ...               ...
# 15872                        8                      7                30
# 15873                       57                     28                27
# 16357                       34                     49                54
# 16717                       53                     27                32
# 17077                       47                     42                49
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 73                      40                   82                 86
# 108                     57                   80                 32
# 411                     68                   82                 30
# 568                     65                   77                 32
# 1254                    48                   78                 56
# ...                    ...                  ...                ...
# 15872                   16                   33                  5
# 15873                   36                   41                 60
# 16357                   40                   59                 36
# 16717                   46                   45                 54
# 17077                   48                   57                 55
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 73                            82                        80
# 108                           45                        34
# 411                           42                        35
# 568                           25                        18
# 1254                          58                        47
# ...                          ...                       ...
# 15872                         10                        11
# 15873                         60                        59
# 16357                         31                        30
# 16717                         66                        66
# 17077                         56                        54
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 73                     12                    11                   11
# 108                     7                    11                   10
# 411                    13                    12                   14
# 568                     5                     7                    7
# 1254                    8                    15                    6
# ...                   ...                   ...                  ...
# 15872                  58                    56                   57
# 15873                   8                     8                   10
# 16357                  12                    10                    7
# 16717                   7                    11                    7
# 17077                  14                     9                    8
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 73                          12                    10  67+3  67+3  67+3  63+3
# 108                         11                    13  75+2  75+2  75+2  83+2
# 411                         13                    14  79+2  79+2  79+2  79+2
# 568                          7                    10  73+2  73+2  73+2  79+2
# 1254                        10                    13  67+2  67+2  67+2  73+2
# ...                        ...                   ...   ...   ...   ...   ...
# 15872                       56                    59   NaN   NaN   NaN   NaN
# 15873                        7                    11  40+2  40+2  40+2  39+2
# 16357                        6                    12  52+2  52+2  52+2  56+2
# 16717                        5                    13  37+2  37+2  37+2  35+2
# 17077                       11                    14  47+2  47+2  47+2  49+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 73     65+3  65+3  65+3  63+3  66+3  66+3  66+3  65+3  71+3  71+3  71+3  65+3
# 108    81+2  81+2  81+2  83+2  82+2  82+2  82+2  83+2  75+2  75+2  75+2  83+2
# 411    80+2  80+2  80+2  79+2  79+2  79+2  79+2  78+2  73+2  73+2  73+2  78+2
# 568    77+2  77+2  77+2  79+2  77+2  77+2  77+2  78+2  70+2  70+2  70+2  78+2
# 1254   72+2  72+2  72+2  73+2  74+2  74+2  74+2  74+2  73+2  73+2  73+2  74+2
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 15872   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15873  38+2  38+2  38+2  39+2  38+2  38+2  38+2  42+2  42+2  42+2  42+2  42+2
# 16357  54+2  54+2  54+2  56+2  55+2  55+2  55+2  56+2  52+2  52+2  52+2  56+2
# 16717  35+2  35+2  35+2  35+2  34+2  34+2  34+2  36+2  38+2  38+2  38+2  36+2
# 17077  49+2  49+2  49+2  49+2  51+2  51+2  51+2  52+2  53+2  53+2  53+2  52+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 73     74+3  79+3  79+3  79+3  74+3  76+3  82+3  82+3  82+3  76+3
# 108    64+2  58+2  58+2  58+2  64+2  59+2  47+2  47+2  47+2  59+2
# 411    62+2  59+2  59+2  59+2  62+2  59+2  53+2  53+2  53+2  59+2
# 568    58+2  53+2  53+2  53+2  58+2  53+2  43+2  43+2  43+2  53+2
# 1254   66+2  66+2  66+2  66+2  66+2  63+2  56+2  56+2  56+2  63+2
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 15872   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15873  52+2  52+2  52+2  52+2  52+2  54+2  57+2  57+2  57+2  54+2
# 16357  49+2  46+2  46+2  46+2  49+2  47+2  40+2  40+2  40+2  47+2
# 16717  49+2  48+2  48+2  48+2  49+2  52+2  55+2  55+2  55+2  52+2
# 17077  54+2  55+2  55+2  55+2  54+2  54+2  54+2  54+2  54+2  54+2
#
# [344 rows x 104 columns]

# %%
teens['nationality'].value_counts(sort=True).to_dict()
# Out:
# {'France': 50,
#  'England': 40,
#  'Spain': 31,
#  'Netherlands': 23,
#  'Italy': 21,
#  'Germany': 18,
#  'Argentina': 18,
#  'Portugal': 12,
#  'Belgium': 10,
#  'Brazil': 9,
#  'Colombia': 9,
#  'Scotland': 9,
#  'United States': 8,
#  'Turkey': 6,
#  'Wales': 4,
#  'Republic of Ireland': 4,
#  'Venezuela': 4,
#  'Croatia': 4,
#  'Russia': 4,
#  'Poland': 3,
#  'Norway': 3,
#  'Sweden': 3,
#  'Mexico': 3,
#  'Denmark': 3,
#  'Switzerland': 3,
#  'Georgia': 2,
#  'FYR Macedonia': 2,
#  'Korea Republic': 2,
#  'Mali': 2,
#  'Burkina Faso': 2,
#  'Nigeria': 2,
#  'Czech Republic': 2,
#  'Serbia': 2,
#  'Senegal': 2,
#  'Ivory Coast': 2,
#  'Austria': 2,
#  'Ukraine': 2,
#  'Japan': 2,
#  'Canada': 2,
#  'Luxembourg': 1,
#  'New Zealand': 1,
#  'Australia': 1,
#  'Chile': 1,
#  'Bulgaria': 1,
#  'Hungary': 1,
#  'DR Congo': 1,
#  'Iran': 1,
#  'Ghana': 1,
#  'Romania': 1,
#  'Ecuador': 1,
#  'Israel': 1,
#  'Uruguay': 1,
#  'South Africa': 1}

# %%
twenties= df.query('20 <= age & age < 30 & 80 <= potential')

# %%
twenties
# Out:
#        sofifa_id                                         player_url  \
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# ...          ...                                                ...
# 12191     240245  https://sofifa.com/player/240245/luis-ureta/20...
# 12192     240550  https://sofifa.com/player/240550/oguz-kagan-gu...
# 12193     241036  https://sofifa.com/player/241036/george-marsh/...
# 12194     241037  https://sofifa.com/player/241037/jack-roles/20...
# 13132     246848  https://sofifa.com/player/246848/boubacar-fofa...
#
#           short_name                      long_name  age         dob  \
# 2          Neymar Jr  Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                      Jan Oblak   26  1993-01-07
# 4          E. Hazard                    Eden Hazard   28  1991-01-07
# 5       K. De Bruyne                Kevin De Bruyne   28  1991-06-28
# 6      M. ter Stegen          Marc-André ter Stegen   27  1992-04-30
# ...              ...                            ...  ...         ...
# 12191       L. Ureta      Luis Alfonso Ureta Medina   20  1999-03-08
# 12192    O. Güçtekin            Oğuz Kağan Güçtekin   20  1999-04-06
# 12193       G. Marsh                   George Marsh   20  1998-11-05
# 12194       J. Roles                     Jack Roles   20  1999-02-26
# 13132      B. Fofana                Boubacar Fofana   20  1998-09-07
#
#        height_cm  weight_kg nationality                 club  overall  \
# 2            175         68      Brazil  Paris Saint-Germain       92
# 3            188         87    Slovenia      Atlético Madrid       91
# 4            175         74     Belgium          Real Madrid       91
# 5            181         70     Belgium      Manchester City       91
# 6            187         85     Germany         FC Barcelona       90
# ...          ...        ...         ...                  ...      ...
# 12191        177         77       Chile         CD O'Higgins       63
# 12192        173         71      Turkey      Çaykur Rizespor       63
# 12193        178         68     England    Tottenham Hotspur       63
# 12194        183         67      Cyprus    Tottenham Hotspur       63
# 13132        182         70      France   Olympique Lyonnais       62
#
#        potential  value_eur  wage_eur player_positions preferred_foot  \
# 2             92  105500000    290000          LW, CAM          Right
# 3             93   77500000    125000               GK          Right
# 4             91   90000000    470000           LW, CF          Right
# 5             91   90000000    370000          CAM, CM          Right
# 6             93   67500000    250000               GK          Right
# ...          ...        ...       ...              ...            ...
# 12191         80     675000      1000               GK          Right
# 12192         80     775000      2000              CDM          Right
# 12193         80     775000      9000          CDM, RB          Right
# 12194         80     800000     11000      CAM, CM, LM           Left
# 13132         80     675000      7000               LM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 2                             5          5            5    High/Medium
# 3                             3          3            1  Medium/Medium
# 4                             4          4            4    High/Medium
# 5                             4          5            4      High/High
# 6                             3          4            1  Medium/Medium
# ...                         ...        ...          ...            ...
# 12191                         1          2            1  Medium/Medium
# 12192                         1          2            3  Medium/Medium
# 12193                         1          3            2    Medium/High
# 12194                         1          4            3    High/Medium
# 13132                         1          4            3    High/Medium
#
#       body_type real_face  release_clause_eur  \
# 2        Neymar       Yes         195200000.0
# 3        Normal       Yes         164700000.0
# 4        Normal       Yes         184500000.0
# 5        Normal       Yes         166500000.0
# 6        Normal       Yes         143400000.0
# ...         ...       ...                 ...
# 12191      Lean        No           1300000.0
# 12192    Normal        No                 NaN
# 12193      Lean       Yes           1900000.0
# 12194      Lean        No           2000000.0
# 13132      Lean        No           1700000.0
#
#                                              player_tags team_position  \
# 2      #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                    NaN            GK
# 4                        #Speedster, #Dribbler, #Acrobat            LW
# 5      #Dribbler, #Playmaker  , #Engine, #Distance Sh...           RCM
# 6                                                    NaN            GK
# ...                                                  ...           ...
# 12191                                                NaN           SUB
# 12192                                                NaN           SUB
# 12193                                                NaN           RES
# 12194                                                NaN           RES
# 13132                                                NaN           RES
#
#        team_jersey_number    loaned_from      joined  contract_valid_until  \
# 2                    10.0            NaN  2017-08-03                2022.0
# 3                    13.0            NaN  2014-07-16                2023.0
# 4                     7.0            NaN  2019-07-01                2024.0
# 5                    17.0            NaN  2015-08-30                2023.0
# 6                     1.0            NaN  2014-07-01                2022.0
# ...                   ...            ...         ...                   ...
# 12191                16.0            NaN  2016-06-01                2020.0
# 12192                66.0  Fenerbahçe SK         NaN                2020.0
# 12193                47.0            NaN  2017-07-01                2021.0
# 12194                55.0            NaN  2017-05-30                2021.0
# 13132                35.0            NaN  2019-07-01                2023.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 2                  LW                  10.0  91.0      85.0     87.0
# 3                  GK                   1.0   NaN       NaN      NaN
# 4                  LF                  10.0  91.0      83.0     86.0
# 5                 RCM                   7.0  76.0      86.0     92.0
# 6                 SUB                  22.0   NaN       NaN      NaN
# ...               ...                   ...   ...       ...      ...
# 12191             NaN                   NaN   NaN       NaN      NaN
# 12192             NaN                   NaN  58.0      45.0     64.0
# 12193             NaN                   NaN  61.0      44.0     58.0
# 12194             NaN                   NaN  67.0      59.0     59.0
# 13132             NaN                   NaN  77.0      58.0     53.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 2           95.0       32.0    58.0        NaN          NaN         NaN
# 3            NaN        NaN     NaN       87.0         92.0        78.0
# 4           94.0       35.0    66.0        NaN          NaN         NaN
# 5           86.0       61.0    78.0        NaN          NaN         NaN
# 6            NaN        NaN     NaN       88.0         85.0        88.0
# ...          ...        ...     ...        ...          ...         ...
# 12191        NaN        NaN     NaN       61.0         62.0        60.0
# 12192       66.0       59.0    52.0        NaN          NaN         NaN
# 12193       57.0       61.0    62.0        NaN          NaN         NaN
# 12194       64.0       47.0    52.0        NaN          NaN         NaN
# 13132       69.0       29.0    50.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 2              NaN       NaN             NaN
# 3             89.0      52.0            90.0
# 4              NaN       NaN             NaN
# 5              NaN       NaN             NaN
# 6             90.0      45.0            88.0
# ...            ...       ...             ...
# 12191         67.0      30.0            62.0
# 12192          NaN       NaN             NaN
# 12193          NaN       NaN             NaN
# 12194          NaN       NaN             NaN
# 13132          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 2      Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                             Flair, Acrobatic Clearance                  13
# 4      Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
# 5      Power Free-Kick, Avoids Using Weaker Foot, Div...                  93
# 6         Swerve Pass, Acrobatic Clearance, Flair Passes                  18
# ...                                                  ...                 ...
# 12191                                       Flair Passes                  32
# 12192                                                NaN                  59
# 12193                                                NaN                  51
# 12194                                                NaN                  50
# 13132                                                NaN                  55
#
#        attacking_finishing  attacking_heading_accuracy  \
# 2                       87                          62
# 3                       11                          15
# 4                       84                          61
# 5                       82                          55
# 6                       14                          11
# ...                    ...                         ...
# 12191                   12                          21
# 12192                   37                          48
# 12193                   41                          53
# 12194                   59                          36
# 13132                   57                          45
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 2                           87                 87               96
# 3                           43                 13               12
# 4                           89                 83               95
# 5                           92                 82               86
# 6                           61                 14               21
# ...                        ...                ...              ...
# 12191                       57                 11               12
# 12192                       71                 42               63
# 12193                       64                 36               54
# 12194                       66                 49               64
# 13132                       58                 52               70
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 2               88                 87                  81                  95
# 3               13                 14                  40                  30
# 4               83                 79                  83                  94
# 5               85                 83                  91                  91
# 6               18                 12                  63                  30
# ...            ...                ...                 ...                 ...
# 12191           30                 31                  44                  21
# 12192           59                 42                  68                  66
# 12193           47                 43                  60                  62
# 12194           59                 49                  55                  64
# 13132           53                 63                  39                  67
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 2                         94                     89                96
# 3                         43                     60                67
# 4                         94                     88                95
# 5                         77                     76                78
# 6                         38                     50                37
# ...                      ...                    ...               ...
# 12191                     29                     30                34
# 12192                     58                     58                72
# 12193                     66                     57                57
# 12194                     68                     67                60
# 13132                     78                     77                76
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 2                      92                84                80             61
# 3                      88                49                59             78
# 4                      90                94                82             56
# 5                      91                76                91             63
# 6                      86                43                66             79
# ...                   ...               ...               ...            ...
# 12191                  52                46                45             56
# 12192                  63                79                58             43
# 12193                  58                65                60             65
# 12194                  61                65                60             58
# 13132                  57                78                65             49
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 2                 81              49                84                    51
# 3                 41              78                12                    34
# 4                 84              63                80                    54
# 5                 89              74                90                    76
# 6                 35              78                10                    43
# ...              ...             ...               ...                   ...
# 12191             26              42                20                    27
# 12192             58              48                51                    55
# 12193             69              56                35                    68
# 12194             66              47                59                    44
# 13132             53              52                54                    40
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 2                           36                     87                90
# 3                           19                     11                65
# 4                           41                     87                89
# 5                           61                     88                94
# 6                           22                     11                70
# ...                        ...                    ...               ...
# 12191                       23                     12                48
# 12192                       53                     51                62
# 12193                       58                     39                57
# 12194                       50                     62                59
# 13132                       22                     55                51
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 2                       90                   94                 27
# 3                       11                   68                 27
# 4                       88                   91                 34
# 5                       79                   91                 68
# 6                       25                   70                 25
# ...                    ...                  ...                ...
# 12191                   31                   45                 10
# 12192                   47                   70                 61
# 12193                   49                   54                 59
# 12194                   59                   59                 49
# 13132                   58                   58                 28
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 2                             26                        29
# 3                             12                        18
# 4                             27                        22
# 5                             58                        51
# 6                             13                        10
# ...                          ...                       ...
# 12191                         10                        11
# 12192                         64                        60
# 12193                         68                        63
# 12194                         49                        44
# 13132                         26                        37
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 2                       9                     9                   15
# 3                      87                    92                   78
# 4                      11                    12                    6
# 5                      15                    13                    5
# 6                      88                    85                   88
# ...                   ...                   ...                  ...
# 12191                  61                    62                   60
# 12192                   6                    11                    5
# 12193                   7                    14                    9
# 12194                  12                    14                    9
# 13132                  14                     7                   10
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 2                           15                    11  84+3  84+3  84+3  90+3
# 3                           90                    89   NaN   NaN   NaN   NaN
# 4                            8                     8  83+3  83+3  83+3  89+3
# 5                           10                    13  82+3  82+3  82+3  87+3
# 6                           88                    90   NaN   NaN   NaN   NaN
# ...                        ...                   ...   ...   ...   ...   ...
# 12191                       62                    67   NaN   NaN   NaN   NaN
# 12192                       11                    12  53+2  53+2  53+2  59+2
# 12193                        5                    10  51+2  51+2  51+2  53+2
# 12194                        5                    12  58+2  58+2  58+2  61+2
# 13132                       15                     6  59+2  59+2  59+2  62+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 2      89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3  82+3  82+3  82+3  89+3
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3  83+3  83+3  83+3  89+3
# 5      87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  87+3  87+3  88+3
# 6       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 12191   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12192  58+2  58+2  58+2  59+2  61+2  61+2  61+2  60+2  62+2  62+2  62+2  60+2
# 12193  53+2  53+2  53+2  53+2  55+2  55+2  55+2  56+2  58+2  58+2  58+2  56+2
# 12194  62+2  62+2  62+2  61+2  62+2  62+2  62+2  61+2  60+2  60+2  60+2  61+2
# 13132  61+2  61+2  61+2  62+2  60+2  60+2  60+2  61+2  52+2  52+2  52+2  61+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 2      66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
# 5      77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
# 6       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 12191   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12192  60+2  61+2  61+2  61+2  60+2  60+2  57+2  57+2  57+2  60+2
# 12193  60+2  62+2  62+2  62+2  60+2  60+2  60+2  60+2  60+2  60+2
# 12194  56+2  55+2  55+2  55+2  56+2  54+2  49+2  49+2  49+2  54+2
# 13132  48+2  42+2  42+2  42+2  48+2  46+2  38+2  38+2  38+2  46+2
#
# [1395 rows x 104 columns]

# %%
twenties['nationality'].value_counts(sort=True).to_dict()
# Out:
# {'Spain': 161,
#  'France': 134,
#  'Argentina': 104,
#  'England': 100,
#  'Brazil': 90,
#  'Germany': 78,
#  'Italy': 68,
#  'Portugal': 60,
#  'Netherlands': 43,
#  'Belgium': 34,
#  'Colombia': 30,
#  'Switzerland': 27,
#  'Croatia': 25,
#  'Uruguay': 22,
#  'Serbia': 19,
#  'Nigeria': 19,
#  'Turkey': 18,
#  'Russia': 18,
#  'Ivory Coast': 18,
#  'Senegal': 17,
#  'Mexico': 16,
#  'Denmark': 16,
#  'Poland': 16,
#  'Austria': 14,
#  'Scotland': 14,
#  'Ghana': 12,
#  'Ukraine': 12,
#  'Algeria': 12,
#  'Morocco': 11,
#  'Paraguay': 11,
#  'Czech Republic': 11,
#  'Cameroon': 10,
#  'United States': 10,
#  'Greece': 9,
#  'Romania': 8,
#  'Wales': 8,
#  'Mali': 8,
#  'Slovakia': 7,
#  'Venezuela': 7,
#  'Chile': 7,
#  'Kosovo': 6,
#  'Slovenia': 6,
#  'Guinea': 5,
#  'Japan': 5,
#  'Norway': 5,
#  'Sweden': 4,
#  'Albania': 3,
#  'Gambia': 3,
#  'Australia': 3,
#  'Bosnia Herzegovina': 3,
#  'Burkina Faso': 3,
#  'Hungary': 3,
#  'Republic of Ireland': 2,
#  'Tunisia': 2,
#  'Togo': 2,
#  'DR Congo': 2,
#  'Guinea Bissau': 2,
#  'Korea Republic': 2,
#  'Iceland': 2,
#  'Montenegro': 1,
#  'Cyprus': 1,
#  'Ecuador': 1,
#  'Dominican Republic': 1,
#  'Angola': 1,
#  'Tanzania': 1,
#  'Zimbabwe': 1,
#  'Gabon': 1,
#  'Iran': 1,
#  'South Africa': 1,
#  'Central African Rep.': 1,
#  'Jamaica': 1,
#  'Luxembourg': 1,
#  'Egypt': 1,
#  'Panama': 1,
#  'Peru': 1,
#  'Korea DPR': 1,
#  'Bolivia': 1,
#  'Northern Ireland': 1,
#  'Israel': 1,
#  'Honduras': 1,
#  'China PR': 1,
#  'FYR Macedonia': 1,
#  'Finland': 1,
#  'Mauritania': 1,
#  'Zambia': 1,
#  'Cape Verde': 1,
#  'New Zealand': 1}

# %%
twenties.query("nationality == 'Japan'")
# Out:
#       sofifa_id                                         player_url  \
# 614      232862  https://sofifa.com/player/232862/shoya-nakajim...
# 1739     226627  https://sofifa.com/player/226627/takumi-minami...
# 2141     232639  https://sofifa.com/player/232639/ritsu-doan/20...
# 2662     232938  https://sofifa.com/player/232938/takehiro-tomi...
# 4780     237823  https://sofifa.com/player/237823/hiroki-abe/20...
#
#        short_name long_name  age         dob  height_cm  weight_kg  \
# 614   S. Nakajima     中島 翔哉   24  1994-08-23        164         64
# 1739  T. Minamino     南野 拓実   24  1995-01-16        174         67
# 2141      R. Doan      堂安 律   21  1998-06-16        172         70
# 2662  T. Tomiyasu     冨安 健洋   20  1998-11-05        188         84
# 4780       H. Abe     安部 裕葵   20  1999-01-28        171         65
#
#      nationality                  club  overall  potential  value_eur  \
# 614        Japan              FC Porto       79         84   17000000
# 1739       Japan  FC Red Bull Salzburg       75         80    9000000
# 2141       Japan          FC Groningen       74         84    9000000
# 2662       Japan               Bologna       73         84    6500000
# 4780       Japan          FC Barcelona       70         83    3400000
#
#       wage_eur player_positions preferred_foot  international_reputation  \
# 614      15000           LM, CF          Right                         1
# 1739     29000      CAM, ST, LM          Right                         1
# 2141      8000          CAM, RM           Left                         1
# 2662     16000          CB, CDM          Right                         1
# 4780     44000           LM, RM          Right                         1
#
#       weak_foot  skill_moves      work_rate body_type real_face  \
# 614           4            4       High/Low    Normal       Yes
# 1739          4            3  Medium/Medium      Lean        No
# 2141          3            3  Medium/Medium    Normal        No
# 2662          5            2    Medium/High      Lean        No
# 4780          3            3    High/Medium      Lean        No
#
#       release_clause_eur           player_tags team_position  \
# 614           35300000.0  #Speedster, #Acrobat           SUB
# 1739          14200000.0                   NaN            RM
# 2141          14900000.0                   NaN           CAM
# 2662          12400000.0                   NaN           SUB
# 4780           9100000.0            #Speedster           RES
#
#       team_jersey_number loaned_from      joined  contract_valid_until  \
# 614                 10.0         NaN  2019-07-05                2024.0
# 1739                18.0         NaN  2015-01-07                2021.0
# 2141                 7.0         NaN  2018-04-23                2021.0
# 2662                14.0         NaN  2019-07-09                2024.0
# 4780                32.0         NaN  2019-07-15                2023.0
#
#      nation_position  nation_jersey_number  pace  shooting  passing  \
# 614              NaN                   NaN  90.0      73.0     72.0
# 1739             NaN                   NaN  89.0      72.0     67.0
# 2141             NaN                   NaN  76.0      69.0     71.0
# 2662             NaN                   NaN  66.0      28.0     57.0
# 4780             NaN                   NaN  90.0      61.0     57.0
#
#       dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 614        83.0       37.0    50.0        NaN          NaN         NaN
# 1739       80.0       41.0    65.0        NaN          NaN         NaN
# 2141       78.0       39.0    56.0        NaN          NaN         NaN
# 2662       63.0       72.0    76.0        NaN          NaN         NaN
# 4780       78.0       33.0    59.0        NaN          NaN         NaN
#
#       gk_reflexes  gk_speed  gk_positioning  \
# 614           NaN       NaN             NaN
# 1739          NaN       NaN             NaN
# 2141          NaN       NaN             NaN
# 2662          NaN       NaN             NaN
# 4780          NaN       NaN             NaN
#
#                                           player_traits  attacking_crossing  \
# 614   Beat Offside Trap, Selfish, Early Crosser, Cro...                  66
# 1739                                              Diver                  64
# 2141                              Argues with Officials                  70
# 2662                                                NaN                  47
# 4780                                                NaN                  61
#
#       attacking_finishing  attacking_heading_accuracy  \
# 614                    72                          40
# 1739                   75                          51
# 2141                   66                          45
# 2662                   27                          70
# 4780                   62                          56
#
#       attacking_short_passing  attacking_volleys  skill_dribbling  \
# 614                        75                 76               83
# 1739                       71                 66               80
# 2141                       72                 59               75
# 2662                       68                 22               60
# 4780                       62                 64               81
#
#       skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 614            79                 64                  68                  78
# 1739           67                 65                  64                  78
# 2141           67                 67                  68                  78
# 2662           43                 35                  65                  67
# 4780           53                 32                  42                  73
#
#       movement_acceleration  movement_sprint_speed  movement_agility  \
# 614                      93                     87                94
# 1739                     90                     88                87
# 2141                     78                     74                86
# 2662                     67                     66                65
# 4780                     91                     90                81
#
#       movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 614                   83                94                76             70
# 1739                  73                82                71             76
# 2141                  70                93                76             41
# 2662                  62                58                37             69
# 4780                  57                84                66             68
#
#       power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 614              75              33                71                    55
# 1739             83              57                70                    61
# 2141             75              54                74                    41
# 2662             68              81                24                    74
# 4780             74              60                55                    33
#
#       mentality_interceptions  mentality_positioning  mentality_vision  \
# 614                        43                     75                77
# 1739                       49                     73                65
# 2141                       41                     61                76
# 2662                       69                     23                51
# 4780                       17                     62                65
#
#       mentality_penalties  mentality_composure  defending_marking  \
# 614                    67                   81                 28
# 1739                   59                   62                 35
# 2141                   58                   72                 39
# 2662                   37                   59                 72
# 4780                   58                   62                 51
#
#       defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 614                          41                        36                   7
# 1739                         39                        34                   9
# 2141                         36                        42                   8
# 2662                         75                        74                   9
# 4780                         25                        15                  12
#
#       goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 614                     10                   10                        8
# 1739                    12                    8                       15
# 2141                     5                    6                       13
# 2662                    14                    6                        5
# 4780                    12                    9                        8
#
#       goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw  \
# 614                      6  71+2  71+2  71+2  78+2  77+2  77+2  77+2  78+2
# 1739                    14  72+2  72+2  72+2  75+2  75+2  75+2  75+2  75+2
# 2141                    14  67+2  67+2  67+2  72+2  71+2  71+2  71+2  72+2
# 2662                    11  49+2  49+2  49+2  53+2  51+2  51+2  51+2  53+2
# 4780                     7  66+2  66+2  66+2  70+2  68+2  68+2  68+2  70+2
#
#        lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm  \
# 614   78+2  78+2  78+2  77+2  72+2  72+2  72+2  77+2  62+2  57+2  57+2  57+2
# 1739  74+2  74+2  74+2  75+2  69+2  69+2  69+2  75+2  62+2  58+2  58+2  58+2
# 2141  72+2  72+2  72+2  72+2  69+2  69+2  69+2  72+2  60+2  57+2  57+2  57+2
# 2662  54+2  54+2  54+2  56+2  59+2  59+2  59+2  56+2  66+2  68+2  68+2  68+2
# 4780  67+2  67+2  67+2  69+2  58+2  58+2  58+2  69+2  52+2  45+2  45+2  45+2
#
#        rwb    lb   lcb    cb   rcb    rb
# 614   62+2  58+2  46+2  46+2  46+2  58+2
# 1739  62+2  59+2  50+2  50+2  50+2  59+2
# 2141  60+2  57+2  46+2  46+2  46+2  57+2
# 2662  66+2  67+2  72+2  72+2  72+2  67+2
# 4780  52+2  49+2  41+2  41+2  41+2  49+2

# %%
twenties_countries = list(twenties.value_counts(sort=True).to_dict().keys())[:10]
twenties_numbers = twenties.value_counts(sort=True).to_list()[:10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-d41bcc414933> in <module>
# ----> 1 twenties_countries = list(twenties.value_counts(sort=True).to_dict().keys())[:10]
#       2 twenties_numbers = twenties.value_counts(sort=True).to_list()[:10]
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
twenties.value_counts(sort=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-3639879b901c> in <module>
# ----> 1 twenties.value_counts(sort=True)
#
# ~/.local/share/virtualenvs/football-data-analysis-EtsPdb68/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
twenties
# Out:
#        sofifa_id                                         player_url  \
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# ...          ...                                                ...
# 12191     240245  https://sofifa.com/player/240245/luis-ureta/20...
# 12192     240550  https://sofifa.com/player/240550/oguz-kagan-gu...
# 12193     241036  https://sofifa.com/player/241036/george-marsh/...
# 12194     241037  https://sofifa.com/player/241037/jack-roles/20...
# 13132     246848  https://sofifa.com/player/246848/boubacar-fofa...
#
#           short_name                      long_name  age         dob  \
# 2          Neymar Jr  Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                      Jan Oblak   26  1993-01-07
# 4          E. Hazard                    Eden Hazard   28  1991-01-07
# 5       K. De Bruyne                Kevin De Bruyne   28  1991-06-28
# 6      M. ter Stegen          Marc-André ter Stegen   27  1992-04-30
# ...              ...                            ...  ...         ...
# 12191       L. Ureta      Luis Alfonso Ureta Medina   20  1999-03-08
# 12192    O. Güçtekin            Oğuz Kağan Güçtekin   20  1999-04-06
# 12193       G. Marsh                   George Marsh   20  1998-11-05
# 12194       J. Roles                     Jack Roles   20  1999-02-26
# 13132      B. Fofana                Boubacar Fofana   20  1998-09-07
#
#        height_cm  weight_kg nationality                 club  overall  \
# 2            175         68      Brazil  Paris Saint-Germain       92
# 3            188         87    Slovenia      Atlético Madrid       91
# 4            175         74     Belgium          Real Madrid       91
# 5            181         70     Belgium      Manchester City       91
# 6            187         85     Germany         FC Barcelona       90
# ...          ...        ...         ...                  ...      ...
# 12191        177         77       Chile         CD O'Higgins       63
# 12192        173         71      Turkey      Çaykur Rizespor       63
# 12193        178         68     England    Tottenham Hotspur       63
# 12194        183         67      Cyprus    Tottenham Hotspur       63
# 13132        182         70      France   Olympique Lyonnais       62
#
#        potential  value_eur  wage_eur player_positions preferred_foot  \
# 2             92  105500000    290000          LW, CAM          Right
# 3             93   77500000    125000               GK          Right
# 4             91   90000000    470000           LW, CF          Right
# 5             91   90000000    370000          CAM, CM          Right
# 6             93   67500000    250000               GK          Right
# ...          ...        ...       ...              ...            ...
# 12191         80     675000      1000               GK          Right
# 12192         80     775000      2000              CDM          Right
# 12193         80     775000      9000          CDM, RB          Right
# 12194         80     800000     11000      CAM, CM, LM           Left
# 13132         80     675000      7000               LM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 2                             5          5            5    High/Medium
# 3                             3          3            1  Medium/Medium
# 4                             4          4            4    High/Medium
# 5                             4          5            4      High/High
# 6                             3          4            1  Medium/Medium
# ...                         ...        ...          ...            ...
# 12191                         1          2            1  Medium/Medium
# 12192                         1          2            3  Medium/Medium
# 12193                         1          3            2    Medium/High
# 12194                         1          4            3    High/Medium
# 13132                         1          4            3    High/Medium
#
#       body_type real_face  release_clause_eur  \
# 2        Neymar       Yes         195200000.0
# 3        Normal       Yes         164700000.0
# 4        Normal       Yes         184500000.0
# 5        Normal       Yes         166500000.0
# 6        Normal       Yes         143400000.0
# ...         ...       ...                 ...
# 12191      Lean        No           1300000.0
# 12192    Normal        No                 NaN
# 12193      Lean       Yes           1900000.0
# 12194      Lean        No           2000000.0
# 13132      Lean        No           1700000.0
#
#                                              player_tags team_position  \
# 2      #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                    NaN            GK
# 4                        #Speedster, #Dribbler, #Acrobat            LW
# 5      #Dribbler, #Playmaker  , #Engine, #Distance Sh...           RCM
# 6                                                    NaN            GK
# ...                                                  ...           ...
# 12191                                                NaN           SUB
# 12192                                                NaN           SUB
# 12193                                                NaN           RES
# 12194                                                NaN           RES
# 13132                                                NaN           RES
#
#        team_jersey_number    loaned_from      joined  contract_valid_until  \
# 2                    10.0            NaN  2017-08-03                2022.0
# 3                    13.0            NaN  2014-07-16                2023.0
# 4                     7.0            NaN  2019-07-01                2024.0
# 5                    17.0            NaN  2015-08-30                2023.0
# 6                     1.0            NaN  2014-07-01                2022.0
# ...                   ...            ...         ...                   ...
# 12191                16.0            NaN  2016-06-01                2020.0
# 12192                66.0  Fenerbahçe SK         NaN                2020.0
# 12193                47.0            NaN  2017-07-01                2021.0
# 12194                55.0            NaN  2017-05-30                2021.0
# 13132                35.0            NaN  2019-07-01                2023.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 2                  LW                  10.0  91.0      85.0     87.0
# 3                  GK                   1.0   NaN       NaN      NaN
# 4                  LF                  10.0  91.0      83.0     86.0
# 5                 RCM                   7.0  76.0      86.0     92.0
# 6                 SUB                  22.0   NaN       NaN      NaN
# ...               ...                   ...   ...       ...      ...
# 12191             NaN                   NaN   NaN       NaN      NaN
# 12192             NaN                   NaN  58.0      45.0     64.0
# 12193             NaN                   NaN  61.0      44.0     58.0
# 12194             NaN                   NaN  67.0      59.0     59.0
# 13132             NaN                   NaN  77.0      58.0     53.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 2           95.0       32.0    58.0        NaN          NaN         NaN
# 3            NaN        NaN     NaN       87.0         92.0        78.0
# 4           94.0       35.0    66.0        NaN          NaN         NaN
# 5           86.0       61.0    78.0        NaN          NaN         NaN
# 6            NaN        NaN     NaN       88.0         85.0        88.0
# ...          ...        ...     ...        ...          ...         ...
# 12191        NaN        NaN     NaN       61.0         62.0        60.0
# 12192       66.0       59.0    52.0        NaN          NaN         NaN
# 12193       57.0       61.0    62.0        NaN          NaN         NaN
# 12194       64.0       47.0    52.0        NaN          NaN         NaN
# 13132       69.0       29.0    50.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 2              NaN       NaN             NaN
# 3             89.0      52.0            90.0
# 4              NaN       NaN             NaN
# 5              NaN       NaN             NaN
# 6             90.0      45.0            88.0
# ...            ...       ...             ...
# 12191         67.0      30.0            62.0
# 12192          NaN       NaN             NaN
# 12193          NaN       NaN             NaN
# 12194          NaN       NaN             NaN
# 13132          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 2      Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                             Flair, Acrobatic Clearance                  13
# 4      Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
# 5      Power Free-Kick, Avoids Using Weaker Foot, Div...                  93
# 6         Swerve Pass, Acrobatic Clearance, Flair Passes                  18
# ...                                                  ...                 ...
# 12191                                       Flair Passes                  32
# 12192                                                NaN                  59
# 12193                                                NaN                  51
# 12194                                                NaN                  50
# 13132                                                NaN                  55
#
#        attacking_finishing  attacking_heading_accuracy  \
# 2                       87                          62
# 3                       11                          15
# 4                       84                          61
# 5                       82                          55
# 6                       14                          11
# ...                    ...                         ...
# 12191                   12                          21
# 12192                   37                          48
# 12193                   41                          53
# 12194                   59                          36
# 13132                   57                          45
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 2                           87                 87               96
# 3                           43                 13               12
# 4                           89                 83               95
# 5                           92                 82               86
# 6                           61                 14               21
# ...                        ...                ...              ...
# 12191                       57                 11               12
# 12192                       71                 42               63
# 12193                       64                 36               54
# 12194                       66                 49               64
# 13132                       58                 52               70
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 2               88                 87                  81                  95
# 3               13                 14                  40                  30
# 4               83                 79                  83                  94
# 5               85                 83                  91                  91
# 6               18                 12                  63                  30
# ...            ...                ...                 ...                 ...
# 12191           30                 31                  44                  21
# 12192           59                 42                  68                  66
# 12193           47                 43                  60                  62
# 12194           59                 49                  55                  64
# 13132           53                 63                  39                  67
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 2                         94                     89                96
# 3                         43                     60                67
# 4                         94                     88                95
# 5                         77                     76                78
# 6                         38                     50                37
# ...                      ...                    ...               ...
# 12191                     29                     30                34
# 12192                     58                     58                72
# 12193                     66                     57                57
# 12194                     68                     67                60
# 13132                     78                     77                76
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 2                      92                84                80             61
# 3                      88                49                59             78
# 4                      90                94                82             56
# 5                      91                76                91             63
# 6                      86                43                66             79
# ...                   ...               ...               ...            ...
# 12191                  52                46                45             56
# 12192                  63                79                58             43
# 12193                  58                65                60             65
# 12194                  61                65                60             58
# 13132                  57                78                65             49
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 2                 81              49                84                    51
# 3                 41              78                12                    34
# 4                 84              63                80                    54
# 5                 89              74                90                    76
# 6                 35              78                10                    43
# ...              ...             ...               ...                   ...
# 12191             26              42                20                    27
# 12192             58              48                51                    55
# 12193             69              56                35                    68
# 12194             66              47                59                    44
# 13132             53              52                54                    40
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 2                           36                     87                90
# 3                           19                     11                65
# 4                           41                     87                89
# 5                           61                     88                94
# 6                           22                     11                70
# ...                        ...                    ...               ...
# 12191                       23                     12                48
# 12192                       53                     51                62
# 12193                       58                     39                57
# 12194                       50                     62                59
# 13132                       22                     55                51
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 2                       90                   94                 27
# 3                       11                   68                 27
# 4                       88                   91                 34
# 5                       79                   91                 68
# 6                       25                   70                 25
# ...                    ...                  ...                ...
# 12191                   31                   45                 10
# 12192                   47                   70                 61
# 12193                   49                   54                 59
# 12194                   59                   59                 49
# 13132                   58                   58                 28
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 2                             26                        29
# 3                             12                        18
# 4                             27                        22
# 5                             58                        51
# 6                             13                        10
# ...                          ...                       ...
# 12191                         10                        11
# 12192                         64                        60
# 12193                         68                        63
# 12194                         49                        44
# 13132                         26                        37
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 2                       9                     9                   15
# 3                      87                    92                   78
# 4                      11                    12                    6
# 5                      15                    13                    5
# 6                      88                    85                   88
# ...                   ...                   ...                  ...
# 12191                  61                    62                   60
# 12192                   6                    11                    5
# 12193                   7                    14                    9
# 12194                  12                    14                    9
# 13132                  14                     7                   10
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 2                           15                    11  84+3  84+3  84+3  90+3
# 3                           90                    89   NaN   NaN   NaN   NaN
# 4                            8                     8  83+3  83+3  83+3  89+3
# 5                           10                    13  82+3  82+3  82+3  87+3
# 6                           88                    90   NaN   NaN   NaN   NaN
# ...                        ...                   ...   ...   ...   ...   ...
# 12191                       62                    67   NaN   NaN   NaN   NaN
# 12192                       11                    12  53+2  53+2  53+2  59+2
# 12193                        5                    10  51+2  51+2  51+2  53+2
# 12194                        5                    12  58+2  58+2  58+2  61+2
# 13132                       15                     6  59+2  59+2  59+2  62+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 2      89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3  82+3  82+3  82+3  89+3
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3  83+3  83+3  83+3  89+3
# 5      87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  87+3  87+3  88+3
# 6       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 12191   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12192  58+2  58+2  58+2  59+2  61+2  61+2  61+2  60+2  62+2  62+2  62+2  60+2
# 12193  53+2  53+2  53+2  53+2  55+2  55+2  55+2  56+2  58+2  58+2  58+2  56+2
# 12194  62+2  62+2  62+2  61+2  62+2  62+2  62+2  61+2  60+2  60+2  60+2  61+2
# 13132  61+2  61+2  61+2  62+2  60+2  60+2  60+2  61+2  52+2  52+2  52+2  61+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 2      66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
# 5      77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
# 6       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 12191   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12192  60+2  61+2  61+2  61+2  60+2  60+2  57+2  57+2  57+2  60+2
# 12193  60+2  62+2  62+2  62+2  60+2  60+2  60+2  60+2  60+2  60+2
# 12194  56+2  55+2  55+2  55+2  56+2  54+2  49+2  49+2  49+2  54+2
# 13132  48+2  42+2  42+2  42+2  48+2  46+2  38+2  38+2  38+2  46+2
#
# [1395 rows x 104 columns]

# %%
twenties_countries = list(twenties['nationality'].value_counts(sort=True).to_dict().keys())[:10]
twenties_numbers = twenties['nationality'].value_counts(sort=True).to_list()[:10]

# %%
twenties_countries
# Out:
# ['Spain',
#  'France',
#  'Argentina',
#  'England',
#  'Brazil',
#  'Germany',
#  'Italy',
#  'Portugal',
#  'Netherlands',
#  'Belgium']

# %%
twenties_numbers
# Out:
# [161, 134, 104, 100, 90, 78, 68, 60, 43, 34]

# %%
left = np.array(countries)
height = np.array(numbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-5d5900e8d4c4> in <module>
# ----> 1 left = np.array(countries)
#       2 height = np.array(numbers)
#
# NameError: name 'countries' is not defined

# %%
left = np.array(twenties_countries)
height = np.array(twenties_numbers)

# %%
plt.bar(left, height)
plt.title('Players count')
plt.xlabel('Countries')
plt.ylabel('Players count')
plt.grid(True)
